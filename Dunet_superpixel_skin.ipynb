# %%
from skimage.color import label2rgb, rgb2gray
from skimage.segmentation import mark_boundaries
import numpy as np
import tensorflow as tf
import os
import cv2
import glob
import matplotlib.pyplot as plt
from keras.layers import *
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from skimage.morphology import binary_erosion, disk
import keras.backend as K
from skimage.segmentation import felzenszwalb, slic, quickshift, watershed
from keras.callbacks import TensorBoard
from keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate
from keras.models import Model
from keras.applications import VGG19
# Out:
# 2023-10-30 10:35:13.275317: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-30 10:35:13.699731: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-10-30 10:35:15.150762: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-10-30 10:35:15.150921: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-10-30 10:35:15.150927: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
image_paths = glob.glob("/home/somayeh/PycharmProjects/superpixel_segmentation/ISIC2018_SKIN_DATA/ISIC2018_Task1-2_Training_Input/*.png")
mask_paths = glob.glob("/home/somayeh/PycharmProjects/superpixel_segmentation/ISIC2018_SKIN_DATA/ISIC2018_Task1_Training_GroundTruth/*.png")

# %%
# initialize empty arrays to hold the images and masks
images = []
masks = []
images_superpixel = []
binary_masks = []
masks_superpixel = []
masks_result = []
binary = []

# %%
def create_superpixel_ground_truth(img, ground_truth):

    # Perform superpixel segmentation
    num_segments = 800
    segments = slic(img, n_segments=num_segments, compactness=10)

    image_superpixel = label2rgb(segments, img, kind='avg')
    image_superpixel = rgb2gray(image_superpixel)
    num_superpixels = len(np.unique(segments))

    image_boundaries = mark_boundaries(img, segments, color=(255, 0, 0))
    labels = segments.astype(np.int32)

    # Overlay superpixels with ground truth
    inside_mask = (ground_truth == 255)  # White pixels in ground truth are inside the region
    outside_mask = (ground_truth == 0)  # Black pixels in ground truth are outside the region
    boundary_mask = cv2.morphologyEx(ground_truth, cv2.MORPH_GRADIENT, np.ones((3, 3), np.uint8)) > 0

    inside_superpixels = set(np.unique(labels[inside_mask]))
    outside_superpixels = set(np.unique(labels[outside_mask]))
    boundary_superpixels = set(np.unique(labels[boundary_mask]))

    # Exclude boundary superpixels
    valid_superpixels = list(outside_superpixels.union(inside_superpixels) - boundary_superpixels)

    for label in boundary_superpixels:
        mask = (labels == label)
        # Check if the superpixel intersects with the boundary
        if np.any(mask[0, :]) or np.any(mask[-1, :]) or np.any(mask[:, 0]) or np.any(mask[:, -1]):
            boundary_mask_ = binary_erosion(boundary_mask, disk(3))
            valid_superpixels = list(outside_superpixels.union(inside_superpixels) - set(labels[boundary_mask_]))

    num_segments_result = len(np.unique(valid_superpixels))

    # Assign labels and color superpixels
    result = np.zeros_like(img)
    inside_labels = []
    outside_labels = []
    for label in valid_superpixels:
        mask = (labels == label)
        if label in inside_superpixels:
            color = (255, 255, 255)  # Yellow for inside superpixels
            inside_labels.append(label)
        else:
            color = (128, 128, 128)  # Blue for outside superpixels
            outside_labels.append(label)
        result[mask] = color

    # Count superpixels that intersect with the boundary
    boundary_intersecting_superpixels = np.unique(labels[boundary_mask])
    num_boundary_intersecting_superpixels = len(boundary_intersecting_superpixels)

    return result

# %%
def dice_coef_one_class(y_true, y_pred, smooth=1e-7):
    y_true_inside = K.cast(y_true == 1, 'float32')
    y_pred_inside = y_pred[..., 1]  # Assuming class 1 is the one inside the boundaries.

    intersection = K.sum(y_true_inside * y_pred_inside)
    denom = K.sum(y_true_inside) + K.sum(y_pred_inside)

    return (2. * intersection + smooth) / (denom + smooth)

def iou_one_class(y_true, y_pred, class_index=1, smooth=1):
    y_true_inside = K.cast(y_true == class_index, 'float32')
    y_pred_inside = y_pred[..., class_index]

    intersection = K.sum(y_true_inside * y_pred_inside)
    union = K.sum(y_true_inside) + K.sum(y_pred_inside) - intersection
    iou_score = (intersection + smooth) / (union + smooth)

    return iou_score

def precision_one_class(y_true, y_pred):
    y_true_inside = K.cast(y_true == 1, 'float32')
    y_pred_inside = y_pred[..., 1]  # Assuming class 1 is the one inside the boundaries.

    true_positives = K.sum(K.round(K.clip(y_true_inside * y_pred_inside, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred_inside, 0, 1)))
    
    precision = true_positives / (predicted_positives + K.epsilon())

    return precision

def sensitivity_one_class(gt_mask, pred_mask, class_index=1):
    gt_mask_class = K.cast(gt_mask == class_index, 'float32')
    pred_mask_class = pred_mask [..., 1]

    TP = K.sum(gt_mask_class * pred_mask_class)
    FN = K.sum(gt_mask_class * (1 - pred_mask_class))

    if TP + FN == 0:
        sensitivity_score = 0.0
    else:
        sensitivity_score = TP / (TP + FN)

    return sensitivity_score

# %%
def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)

    return (2.0 * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %%
def iou(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    iou_score = (intersection + smooth) / (union + smooth)
    return iou_score

# %%
def precision(y_true, y_pred):
    y_true_flat = K.flatten(y_true)
    y_pred_flat = K.flatten(y_pred)
    true_positives = K.sum(K.round(K.clip(y_true_flat * y_pred_flat, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred_flat, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())

    return precision

# %%
def sensitivity(gt_mask, pred_mask):

    gt_mask_flat = K.flatten(gt_mask)
    pred_mask_flat = K.flatten(pred_mask)

    # compute true positive (TP) and false negative (FN) counts
    TP = K.sum(gt_mask_flat * pred_mask_flat)
    FN = K.sum(gt_mask_flat * (1 - pred_mask_flat))

    # compute sensitivity (recall)
    if TP + FN == 0:
        sensitivity_score = 0.0
    else:
        sensitivity_score = TP / (TP + FN)

    return sensitivity_score

# %%
def dice_loss(y_true, y_pred):
    return 1 - dice_coef_one_class(y_true, y_pred, smooth=1e-7)

# %%
batch_size = 8
threshold_value = 128
from tqdm import tqdm
def data_generator(image_paths, mask_paths, batch_size):

    assert len(image_paths) == len(mask_paths), "Number of images and masks must be the same."

    num_samples = len(image_paths)
    print("Number of images:", num_samples)
    num_masks = len(mask_paths)
    print("Number of masks:", num_masks)

    while True:
        indices = np.arange(num_samples)
        np.random.shuffle(indices)

        for i in range(0, num_samples, batch_size):
            batch_indices = indices[i : i + batch_size]
            batch_images = []
            batch_masks = []

            for index in batch_indices:
                image_path = image_paths[index]
                mask_path = mask_paths[index]

                img = cv2.imread(image_path)
                img = cv2.resize(img, (128, 128))

                filename = os.path.join("/home/somayeh/PycharmProjects/superpixel_segmentation/"
                                        "newgt/newgt_superpixel_skin_slic800", os.path.basename(mask_path))
                if not os.path.exists(filename):

                    mask = cv2.imread(mask_path,0)
                    mask = cv2.resize(mask, (128, 128))

                    result = create_superpixel_ground_truth(img, mask)
                    # result = ground_truth_superpixel_3(img, mask)

                    # result = cv2.cvtColor(result, cv2.COLOR_BGR2GRAY)
                    # plt.subplot(1, 2, 2)
                    # plt.imshow(result)
                    # plt.title("hggh")

                    # soft_label = binary_to_soft_label(result, threshold_value=threshold_value)
                    # cv2.imshow("kjkj",soft_label)
                    # cv2.waitKey(0)
                    # result = cv2.cvtColor(result, cv2.COLOR_BGR2GRAY)

                    cv2.imwrite(filename, result)

                else:
                    result = cv2.imread(filename, 0)
                # print(result.type)
                # img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                # soft_label = binary_to_soft_label(result)

                # normalize the image and mask to have values between 0 and 1
                # img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                img = img / 255.0
                result= result/ 255.0
                # result = result / 255.0
                # print(soft_label.shape)
                # cv2.imshow("dfg", soft_label)
                # cv2.waitKey(0)
                # Append the preprocessed data to the respective lists

                batch_images.append(img)
                batch_masks.append(result)

            # Yield the batch data
            batch_images = np.array(batch_images)
            batch_masks = np.array(batch_masks)

            # Visualize the images and masks in the batch
            # for j in range(batch_images.shape[0]):
            #     plt.subplot(1, 2, 1)
            #     plt.imshow(batch_images[j])
            #     plt.title("Image")
            #
            #     plt.subplot(1, 2, 2)
            #     plt.imshow(batch_masks[j])
            #     plt.title("Mask")
            #
            #     plt.show()

            yield batch_images, batch_masks


# generator = data_generator(image_paths, mask_paths, 1)
# 
# for _,imgpath in tqdm(enumerate(image_paths)):
#    batch = next(generator)

# %%
# # Specify the path to the images
# image_folder = "/home/somayeh/PycharmProjects/superpixel_segmentation/newgt/newgt_superpixel_skin_slic800/"
# 
# # List all image files in the folder
# image_paths = glob.glob(os.path.join(image_folder, "*.png"))
# 
# # Process and overwrite each image in the same folder
# for image_path in image_paths:
#     # Load the image in color
#     image = cv2.imread(image_path)
# 
#     # Convert the image to grayscale
#     grayscale_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# 
#     # Overwrite the original image with the grayscale version
#     cv2.imwrite(image_path, grayscale_image)
# 
# print("Image conversion and overwriting complete.")

# %%
mask_path_superpixel_label = glob.glob("/home/somayeh/PycharmProjects/superpixel_segmentation/newgt/newgt_superpixel_skin_slic800/*.png")

# # Load one of the images
# image_path = mask_path_superpixel_label[0]  # Use the path to one of the images
# image = cv2.imread(image_path)  # Load as grayscale
# image_shape = image.shape
# 
# print("Image shape:", image_shape)

# %%
assert len(image_paths) == len(mask_path_superpixel_label), "Number of images and masks must be the same."
# Split the data into training and validation sets
train_image_paths, val_image_paths, train_mask_paths, val_mask_paths = train_test_split(
    image_paths, mask_path_superpixel_label, test_size=0.2, random_state=2023
)

# Define the batch size
batch_size = 8

# Create separate generators for training and validation sets
train_generator = data_generator(train_image_paths, train_mask_paths, batch_size)
val_generator = data_generator(val_image_paths, val_mask_paths, batch_size)

# batch_size = 5  # Number of batches to visualize

# for _ in range(batch_size):
#     batch = next(train_generator)

# Determine the number of steps per epoch for training and validation
train_steps_per_epoch = len(train_image_paths) // batch_size
val_steps_per_epoch = len(val_image_paths) // batch_size

print(train_steps_per_epoch)
print(val_steps_per_epoch)
# Out:
# 259
# 64

# %%
def squeeze_excite_block(inputs, ratio=8):
    init = inputs
    channel_axis = -1
    filters = init.shape[channel_axis]
    se_shape = (1, 1, filters)

    se = GlobalAveragePooling2D()(init)
    se = Reshape(se_shape)(se)
    se = Dense(filters // ratio, activation='relu', kernel_initializer='he_normal', use_bias=False)(se)
    se = Dense(filters, activation='sigmoid', kernel_initializer='he_normal', use_bias=False)(se)

    x = Multiply()([init, se])
    return x

def conv_block(inputs, filters):
    x = inputs

    x = Conv2D(filters, (3, 3), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(filters, (3, 3), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = squeeze_excite_block(x)

    return x

def encoder1(inputs):
    skip_connections = []

    model = VGG19(include_top=False, weights='imagenet', input_tensor=inputs)
    names = ["block1_conv2", "block2_conv2", "block3_conv4", "block4_conv4"]
    for name in names:
        skip_connections.append(model.get_layer(name).output)

    output = model.get_layer("block5_conv4").output
    return output, skip_connections

def decoder1(inputs, skip_connections):
    num_filters = [256, 128, 64, 32]
    skip_connections.reverse()
    x = inputs

    for i, f in enumerate(num_filters):
        x = UpSampling2D((2, 2), interpolation='bilinear')(x)
        x = Concatenate()([x, skip_connections[i]])
        x = conv_block(x, f)

    return x

# def encoder2(inputs):
#     skip_connections = []
#
#     output = DenseNet121(include_top=False, weights='imagenet')(inputs)
#     model = tf.keras.models.Model(inputs, output)
#
#     names = ["input_2", "conv1/relu", "pool2_conv", "pool3_conv"]
#     for name in names:
#         skip_connections.append(model.get_layer(name).output)
#     output = model.get_layer("pool4_conv").output
#
#     return output, skip_connections

def encoder2(inputs):
    num_filters = [32, 64, 128, 256]
    skip_connections = []
    x = inputs

    for i, f in enumerate(num_filters):
        x = conv_block(x, f)
        skip_connections.append(x)
        x = MaxPool2D((2, 2))(x)

    return x, skip_connections

def decoder2(inputs, skip_1, skip_2):
    num_filters = [256, 128, 64, 32]
    skip_2.reverse()
    x = inputs

    for i, f in enumerate(num_filters):
        x = UpSampling2D((2, 2), interpolation='bilinear')(x)
        x = Concatenate()([x, skip_1[i], skip_2[i]])
        x = conv_block(x, f)

    return x

def output_block(inputs, num_classes=3):
    x = Conv2D(num_classes, (1, 1), padding="same")(inputs)
    x = Activation('softmax')(x)
    return x

def Upsample(tensor, size):
    """Bilinear upsampling"""
    def _upsample(x, size):
        return tf.image.resize(images=x, size=size)
    return Lambda(lambda x: _upsample(x, size), output_shape=size)(tensor)

def ASPP(x, filter):
    shape = x.shape

    y1 = AveragePooling2D(pool_size=(shape[1], shape[2]))(x)
    y1 = Conv2D(filter, 1, padding="same")(y1)
    y1 = BatchNormalization()(y1)
    y1 = Activation("relu")(y1)
    y1 = UpSampling2D((shape[1], shape[2]), interpolation='bilinear')(y1)

    y2 = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(x)
    y2 = BatchNormalization()(y2)
    y2 = Activation("relu")(y2)

    y3 = Conv2D(filter, 3, dilation_rate=6, padding="same", use_bias=False)(x)
    y3 = BatchNormalization()(y3)
    y3 = Activation("relu")(y3)

    y4 = Conv2D(filter, 3, dilation_rate=12, padding="same", use_bias=False)(x)
    y4 = BatchNormalization()(y4)
    y4 = Activation("relu")(y4)

    y5 = Conv2D(filter, 3, dilation_rate=18, padding="same", use_bias=False)(x)
    y5 = BatchNormalization()(y5)
    y5 = Activation("relu")(y5)

    y = Concatenate()([y1, y2, y3, y4, y5])

    y = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(y)
    y = BatchNormalization()(y)
    y = Activation("relu")(y)

    return y

# Modify the U-Net model to output 3 channels
def build_model(shape, num_classes=3):
    inputs = Input(shape)
    x, skip_1 = encoder1(inputs)
    x = ASPP(x, 64)
    x = decoder1(x, skip_1)
    outputs1 = output_block(x, num_classes)

    x = inputs * outputs1

    x, skip_2 = encoder2(x)
    x = ASPP(x, 64)
    x = decoder2(x, skip_1, skip_2)
    outputs2 = output_block(x, num_classes)

    model = Model(inputs, outputs2)
    return model

# %%
log_folder = '/home/somayeh/PycharmProjects/superpixel_segmentation/tensor_board'

# %%
weight_path="{}_Dunet_superpixel_skin.best.hdf5".format('cxr_reg')

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1,
                             save_best_only=True, mode='min', save_weights_only = True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                                   patience=3,
                                   verbose=1, mode='min', epsilon=0.0001, cooldown=2, min_lr=1e-5)
early = EarlyStopping(monitor="val_loss",
                      mode="min",
                      patience=10) # probably needs to be more patient, but kaggle time is limited

tbcallback = TensorBoard(log_dir=log_folder,
                         histogram_freq=1,
                         write_graph=True,
                         write_images=True,
                         update_freq='epoch',
                         profile_batch=2,
                         embeddings_freq=1)

callbacks_list = [checkpoint, early, reduceLROnPlat, tbcallback]
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# 2023-10-30 10:35:58.785455: I tensorflow/core/profiler/lib/profiler_session.cc:101] Profiler session initializing.
# 2023-10-30 10:35:58.785540: I tensorflow/core/profiler/lib/profiler_session.cc:116] Profiler session started.
# 2023-10-30 10:35:58.834769: I tensorflow/core/profiler/backends/gpu/cupti_tracer.cc:1664] Profiler found 1 GPUs
# 2023-10-30 10:35:58.835161: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcupti.so.11.2'; dlerror: libcupti.so.11.2: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/somayeh/PycharmProjects/superpixel_segmentation/venv/lib/python3.8/site-packages/cv2/../../lib64:
# 2023-10-30 10:35:58.872520: I tensorflow/core/profiler/lib/profiler_session.cc:128] Profiler session tear down.
# 2023-10-30 10:35:58.872821: I tensorflow/core/profiler/backends/gpu/cupti_tracer.cc:1798] CUPTI activity buffer flushed

# %%
shape = (128, 128, 3)  # Adjust the input shape to match your data
num_classes = 3  # Assuming you have 3 classes in your ground truth masks

# Create the double U-Net model
model = build_model(shape, num_classes=3)

opt = tf.keras.optimizers.experimental.AdamW(learning_rate=0.0001)
model.compile(optimizer=opt, loss=dice_loss, metrics= [dice_coef_one_class, precision_one_class, iou_one_class, sensitivity_one_class],  run_eagerly=True)

model.summary()
# Out:
# 2023-10-30 10:36:02.285128: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-30 10:36:02.404696: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-30 10:36:02.404954: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-30 10:36:02.406725: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-30 10:36:02.407535: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-30 10:36:02.407789: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-30 10:36:02.407937: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-30 10:36:03.824870: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-30 10:36:03.825253: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-30 10:36:03.825413: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-10-30 10:36:03.825688: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2111 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 128, 128, 64  1792        ['input_1[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 128, 128, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 64, 64, 64)   0           ['block1_conv2[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 64, 64, 128)  73856       ['block1_pool[0][0]']
#
#  block2_conv2 (Conv2D)          (None, 64, 64, 128)  147584      ['block2_conv1[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 32, 32, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 32, 32, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_conv4 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv3[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 16, 16, 256)  0           ['block3_conv4[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 16, 16, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_conv4 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv3[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 8, 8, 512)    0           ['block4_conv4[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 8, 8, 512)    2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv2[0][0]']
#
#  block5_conv4 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv3[0][0]']
#
#  average_pooling2d (AveragePool  (None, 1, 1, 512)   0           ['block5_conv4[0][0]']
#  ing2D)
#
#  conv2d (Conv2D)                (None, 1, 1, 64)     32832       ['average_pooling2d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 1, 1, 64)    256         ['conv2d[0][0]']
#  alization)
#
#  conv2d_1 (Conv2D)              (None, 8, 8, 64)     32768       ['block5_conv4[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 8, 8, 64)     294912      ['block5_conv4[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 8, 8, 64)     294912      ['block5_conv4[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 8, 8, 64)     294912      ['block5_conv4[0][0]']
#
#  activation (Activation)        (None, 1, 1, 64)     0           ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 8, 8, 64)    256         ['conv2d_1[0][0]']
#  rmalization)
#
#  batch_normalization_2 (BatchNo  (None, 8, 8, 64)    256         ['conv2d_2[0][0]']
#  rmalization)
#
#  batch_normalization_3 (BatchNo  (None, 8, 8, 64)    256         ['conv2d_3[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 8, 8, 64)    256         ['conv2d_4[0][0]']
#  rmalization)
#
#  up_sampling2d (UpSampling2D)   (None, 8, 8, 64)     0           ['activation[0][0]']
#
#  activation_1 (Activation)      (None, 8, 8, 64)     0           ['batch_normalization_1[0][0]']
#
#  activation_2 (Activation)      (None, 8, 8, 64)     0           ['batch_normalization_2[0][0]']
#
#  activation_3 (Activation)      (None, 8, 8, 64)     0           ['batch_normalization_3[0][0]']
#
#  activation_4 (Activation)      (None, 8, 8, 64)     0           ['batch_normalization_4[0][0]']
#
#  concatenate (Concatenate)      (None, 8, 8, 320)    0           ['up_sampling2d[0][0]',
#                                                                   'activation_1[0][0]',
#                                                                   'activation_2[0][0]',
#                                                                   'activation_3[0][0]',
#                                                                   'activation_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 8, 8, 64)     20480       ['concatenate[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 8, 8, 64)    256         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 8, 8, 64)     0           ['batch_normalization_5[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 64)  0           ['activation_5[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 16, 16, 576)  0           ['up_sampling2d_1[0][0]',
#                                                                   'block4_conv4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 256)  1327360     ['concatenate_1[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 16, 16, 256)  1024       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 16, 16, 256)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 256)  590080      ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 16, 16, 256)  1024       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 16, 16, 256)  0           ['batch_normalization_7[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['activation_7[0][0]']
#  alAveragePooling2D)
#
#  reshape (Reshape)              (None, 1, 1, 256)    0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 1, 1, 32)     8192        ['reshape[0][0]']
#
#  dense_1 (Dense)                (None, 1, 1, 256)    8192        ['dense[0][0]']
#
#  multiply (Multiply)            (None, 16, 16, 256)  0           ['activation_7[0][0]',
#                                                                   'dense_1[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 256)  0          ['multiply[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 32, 32, 512)  0           ['up_sampling2d_2[0][0]',
#                                                                   'block3_conv4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 128)  589952      ['concatenate_2[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 128)  512        ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 32, 32, 128)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 128)  147584      ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 128)  512        ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 32, 32, 128)  0           ['batch_normalization_9[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 128)         0           ['activation_9[0][0]']
#  obalAveragePooling2D)
#
#  reshape_1 (Reshape)            (None, 1, 1, 128)    0           ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_2 (Dense)                (None, 1, 1, 16)     2048        ['reshape_1[0][0]']
#
#  dense_3 (Dense)                (None, 1, 1, 128)    2048        ['dense_2[0][0]']
#
#  multiply_1 (Multiply)          (None, 32, 32, 128)  0           ['activation_9[0][0]',
#                                                                   'dense_3[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 128)  0          ['multiply_1[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 64, 64, 256)  0           ['up_sampling2d_3[0][0]',
#                                                                   'block2_conv2[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 64)   147520      ['concatenate_3[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 64)  256         ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 64)  256         ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_11[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 64)          0           ['activation_11[0][0]']
#  obalAveragePooling2D)
#
#  reshape_2 (Reshape)            (None, 1, 1, 64)     0           ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  dense_4 (Dense)                (None, 1, 1, 8)      512         ['reshape_2[0][0]']
#
#  dense_5 (Dense)                (None, 1, 1, 64)     512         ['dense_4[0][0]']
#
#  multiply_2 (Multiply)          (None, 64, 64, 64)   0           ['activation_11[0][0]',
#                                                                   'dense_5[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 128, 128, 64  0          ['multiply_2[0][0]']
#                                 )
#
#  concatenate_4 (Concatenate)    (None, 128, 128, 12  0           ['up_sampling2d_4[0][0]',
#                                 8)                                'block1_conv2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 32  36896       ['concatenate_4[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 128, 128, 32  128        ['conv2d_12[0][0]']
#  ormalization)                  )
#
#  activation_12 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_12[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 32  9248        ['activation_12[0][0]']
#                                 )
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 32  128        ['conv2d_13[0][0]']
#  ormalization)                  )
#
#  activation_13 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_13[0][0]']
#                                 )
#
#  global_average_pooling2d_3 (Gl  (None, 32)          0           ['activation_13[0][0]']
#  obalAveragePooling2D)
#
#  reshape_3 (Reshape)            (None, 1, 1, 32)     0           ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
#  dense_6 (Dense)                (None, 1, 1, 4)      128         ['reshape_3[0][0]']
#
#  dense_7 (Dense)                (None, 1, 1, 32)     128         ['dense_6[0][0]']
#
#  multiply_3 (Multiply)          (None, 128, 128, 32  0           ['activation_13[0][0]',
#                                 )                                 'dense_7[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 3)  99          ['multiply_3[0][0]']
#
#  activation_14 (Activation)     (None, 128, 128, 3)  0           ['conv2d_14[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 128, 128, 3)  0           ['input_1[0][0]',
#                                                                   'activation_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 32  896         ['tf.math.multiply[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 128, 128, 32  128        ['conv2d_15[0][0]']
#  ormalization)                  )
#
#  activation_15 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_14[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 32  9248        ['activation_15[0][0]']
#                                 )
#
#  batch_normalization_15 (BatchN  (None, 128, 128, 32  128        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_15[0][0]']
#                                 )
#
#  global_average_pooling2d_4 (Gl  (None, 32)          0           ['activation_16[0][0]']
#  obalAveragePooling2D)
#
#  reshape_4 (Reshape)            (None, 1, 1, 32)     0           ['global_average_pooling2d_4[0][0
#                                                                  ]']
#
#  dense_8 (Dense)                (None, 1, 1, 4)      128         ['reshape_4[0][0]']
#
#  dense_9 (Dense)                (None, 1, 1, 32)     128         ['dense_8[0][0]']
#
#  multiply_4 (Multiply)          (None, 128, 128, 32  0           ['activation_16[0][0]',
#                                 )                                 'dense_9[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 32)   0           ['multiply_4[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 64, 64, 64)   18496       ['max_pooling2d[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 64, 64, 64)  256         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_17[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 64, 64, 64)  256         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_17[0][0]']
#
#  global_average_pooling2d_5 (Gl  (None, 64)          0           ['activation_18[0][0]']
#  obalAveragePooling2D)
#
#  reshape_5 (Reshape)            (None, 1, 1, 64)     0           ['global_average_pooling2d_5[0][0
#                                                                  ]']
#
#  dense_10 (Dense)               (None, 1, 1, 8)      512         ['reshape_5[0][0]']
#
#  dense_11 (Dense)               (None, 1, 1, 64)     512         ['dense_10[0][0]']
#
#  multiply_5 (Multiply)          (None, 64, 64, 64)   0           ['activation_18[0][0]',
#                                                                   'dense_11[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)  0           ['multiply_5[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 128)  512        ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 128)  147584      ['activation_19[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 32, 32, 128)  512        ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_19[0][0]']
#
#  global_average_pooling2d_6 (Gl  (None, 128)         0           ['activation_20[0][0]']
#  obalAveragePooling2D)
#
#  reshape_6 (Reshape)            (None, 1, 1, 128)    0           ['global_average_pooling2d_6[0][0
#                                                                  ]']
#
#  dense_12 (Dense)               (None, 1, 1, 16)     2048        ['reshape_6[0][0]']
#
#  dense_13 (Dense)               (None, 1, 1, 128)    2048        ['dense_12[0][0]']
#
#  multiply_6 (Multiply)          (None, 32, 32, 128)  0           ['activation_20[0][0]',
#                                                                   'dense_13[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 128)  0          ['multiply_6[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 16, 16, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 16, 16, 256)  590080      ['activation_21[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_21[0][0]']
#
#  global_average_pooling2d_7 (Gl  (None, 256)         0           ['activation_22[0][0]']
#  obalAveragePooling2D)
#
#  reshape_7 (Reshape)            (None, 1, 1, 256)    0           ['global_average_pooling2d_7[0][0
#                                                                  ]']
#
#  dense_14 (Dense)               (None, 1, 1, 32)     8192        ['reshape_7[0][0]']
#
#  dense_15 (Dense)               (None, 1, 1, 256)    8192        ['dense_14[0][0]']
#
#  multiply_7 (Multiply)          (None, 16, 16, 256)  0           ['activation_22[0][0]',
#                                                                   'dense_15[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 256)   0           ['multiply_7[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 1, 1, 256)   0           ['max_pooling2d_3[0][0]']
#  oling2D)
#
#  conv2d_23 (Conv2D)             (None, 1, 1, 64)     16448       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 1, 1, 64)    256         ['conv2d_23[0][0]']
#  ormalization)
#
#  conv2d_24 (Conv2D)             (None, 8, 8, 64)     16384       ['max_pooling2d_3[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 8, 8, 64)     147456      ['max_pooling2d_3[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 8, 8, 64)     147456      ['max_pooling2d_3[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 8, 8, 64)     147456      ['max_pooling2d_3[0][0]']
#
#  activation_23 (Activation)     (None, 1, 1, 64)     0           ['batch_normalization_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 8, 8, 64)    256         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 8, 8, 64)    256         ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 8, 8, 64)    256         ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 8, 8, 64)    256         ['conv2d_27[0][0]']
#  ormalization)
#
#  up_sampling2d_5 (UpSampling2D)  (None, 8, 8, 64)    0           ['activation_23[0][0]']
#
#  activation_24 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_23[0][0]']
#
#  activation_25 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_24[0][0]']
#
#  activation_26 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_25[0][0]']
#
#  activation_27 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_26[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 8, 8, 320)    0           ['up_sampling2d_5[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]',
#                                                                   'activation_26[0][0]',
#                                                                   'activation_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 8, 8, 64)     20480       ['concatenate_5[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 8, 8, 64)    256         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_27[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 16, 16, 64)  0           ['activation_28[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 16, 16, 832)  0           ['up_sampling2d_6[0][0]',
#                                                                   'block4_conv4[0][0]',
#                                                                   'multiply_7[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 16, 16, 256)  1917184     ['concatenate_6[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 16, 16, 256)  590080      ['activation_29[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_29[0][0]']
#
#  global_average_pooling2d_8 (Gl  (None, 256)         0           ['activation_30[0][0]']
#  obalAveragePooling2D)
#
#  reshape_8 (Reshape)            (None, 1, 1, 256)    0           ['global_average_pooling2d_8[0][0
#                                                                  ]']
#
#  dense_16 (Dense)               (None, 1, 1, 32)     8192        ['reshape_8[0][0]']
#
#  dense_17 (Dense)               (None, 1, 1, 256)    8192        ['dense_16[0][0]']
#
#  multiply_8 (Multiply)          (None, 16, 16, 256)  0           ['activation_30[0][0]',
#                                                                   'dense_17[0][0]']
#
#  up_sampling2d_7 (UpSampling2D)  (None, 32, 32, 256)  0          ['multiply_8[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 32, 32, 640)  0           ['up_sampling2d_7[0][0]',
#                                                                   'block3_conv4[0][0]',
#                                                                   'multiply_6[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 32, 32, 128)  737408      ['concatenate_7[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 32, 32, 128)  512        ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 32, 32, 128)  147584      ['activation_31[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 32, 32, 128)  512        ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_31[0][0]']
#
#  global_average_pooling2d_9 (Gl  (None, 128)         0           ['activation_32[0][0]']
#  obalAveragePooling2D)
#
#  reshape_9 (Reshape)            (None, 1, 1, 128)    0           ['global_average_pooling2d_9[0][0
#                                                                  ]']
#
#  dense_18 (Dense)               (None, 1, 1, 16)     2048        ['reshape_9[0][0]']
#
#  dense_19 (Dense)               (None, 1, 1, 128)    2048        ['dense_18[0][0]']
#
#  multiply_9 (Multiply)          (None, 32, 32, 128)  0           ['activation_32[0][0]',
#                                                                   'dense_19[0][0]']
#
#  up_sampling2d_8 (UpSampling2D)  (None, 64, 64, 128)  0          ['multiply_9[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 64, 64, 320)  0           ['up_sampling2d_8[0][0]',
#                                                                   'block2_conv2[0][0]',
#                                                                   'multiply_5[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 64, 64, 64)   184384      ['concatenate_8[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 64, 64, 64)  256         ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_32[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_33[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 64, 64, 64)  256         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_33[0][0]']
#
#  global_average_pooling2d_10 (G  (None, 64)          0           ['activation_34[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_10 (Reshape)           (None, 1, 1, 64)     0           ['global_average_pooling2d_10[0][
#                                                                  0]']
#
#  dense_20 (Dense)               (None, 1, 1, 8)      512         ['reshape_10[0][0]']
#
#  dense_21 (Dense)               (None, 1, 1, 64)     512         ['dense_20[0][0]']
#
#  multiply_10 (Multiply)         (None, 64, 64, 64)   0           ['activation_34[0][0]',
#                                                                   'dense_21[0][0]']
#
#  up_sampling2d_9 (UpSampling2D)  (None, 128, 128, 64  0          ['multiply_10[0][0]']
#                                 )
#
#  concatenate_9 (Concatenate)    (None, 128, 128, 16  0           ['up_sampling2d_9[0][0]',
#                                 0)                                'block1_conv2[0][0]',
#                                                                   'multiply_4[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 128, 128, 32  46112       ['concatenate_9[0][0]']
#                                 )
#
#  batch_normalization_34 (BatchN  (None, 128, 128, 32  128        ['conv2d_35[0][0]']
#  ormalization)                  )
#
#  activation_35 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_34[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 128, 128, 32  9248        ['activation_35[0][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 128, 128, 32  128        ['conv2d_36[0][0]']
#  ormalization)                  )
#
#  activation_36 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_35[0][0]']
#                                 )
#
#  global_average_pooling2d_11 (G  (None, 32)          0           ['activation_36[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_11 (Reshape)           (None, 1, 1, 32)     0           ['global_average_pooling2d_11[0][
#                                                                  0]']
#
#  dense_22 (Dense)               (None, 1, 1, 4)      128         ['reshape_11[0][0]']
#
#  dense_23 (Dense)               (None, 1, 1, 32)     128         ['dense_22[0][0]']
#
#  multiply_11 (Multiply)         (None, 128, 128, 32  0           ['activation_36[0][0]',
#                                 )                                 'dense_23[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 128, 128, 3)  99          ['multiply_11[0][0]']
#
#  activation_37 (Activation)     (None, 128, 128, 3)  0           ['conv2d_37[0][0]']
#
# ==================================================================================================
# Total params: 29,297,702
# Trainable params: 29,290,406
# Non-trainable params: 7,296
# __________________________________________________________________________________________________

# %%
loss_history = model.fit_generator(
    train_generator,
    steps_per_epoch=train_steps_per_epoch,
    validation_data=val_generator,
    validation_steps=val_steps_per_epoch,
    epochs=50,
    callbacks =callbacks_list
)
model.save("Dunet_superpixel_skin_slic800.h5")
# Out:
# /tmp/ipykernel_188996/1726412529.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   loss_history = model.fit_generator(
# Number of images: 2075
# Number of masks: 2075
# Epoch 1/50
# 2023-10-29 22:56:14.875252: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8902
# 2023-10-29 22:56:16.465969: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-29 22:56:16.470072: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:234] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.6
# 2023-10-29 22:56:16.470125: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:237] Used ptxas at ptxas
# 2023-10-29 22:56:16.470294: W tensorflow/compiler/xla/stream_executor/gpu/redzone_allocator.cc:318] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2023-10-29 22:56:16.582103: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-29 22:56:16.582720: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-29 22:56:16.767530: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.17GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-29 22:56:16.767641: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.17GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-29 22:56:16.926912: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.14GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-29 22:56:16.926997: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.14GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-29 22:56:17.111369: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.18GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-29 22:56:17.111481: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.18GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-29 22:56:17.285740: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-10-29 22:56:17.849762: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.21GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-29 22:56:17.849835: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.21GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-29 22:56:23.953837: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x88446450 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-29 22:56:23.953902: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6
# 2023-10-29 22:56:23.970619: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-29 22:56:24.176511: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-29 22:56:24.181927: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-10-29 22:56:24.436210: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-29 22:56:24.702986: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7f95a053a3a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7f95a053a3a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2023-10-29 22:56:25.479741: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-29 22:56:26.309928: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-29 22:56:26.580779: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-29 22:56:26.884257: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-29 22:56:28.527056: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-29 22:56:28.789109: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-29 22:56:29.062582: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-29 22:56:37.478354: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-29 22:56:45.660593: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-29 22:56:48.077963: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-29 22:56:48.344477: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-29 22:56:48.618096: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-29 22:57:04.408045: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-29 22:57:07.121694: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
#   1/259 [..............................] - ETA: 4:31:55 - loss: 0.8373 - dice_coef_one_class: 0.1627 - precision_one_class: 0.0234 - iou_one_class: 0.0886 - sensitivity_one_class: 0.2793
# 2023-10-29 22:57:15.603478: I tensorflow/core/profiler/lib/profiler_session.cc:101] Profiler session initializing.
# 2023-10-29 22:57:15.603512: I tensorflow/core/profiler/lib/profiler_session.cc:116] Profiler session started.
#   2/259 [..............................] - ETA: 5:16 - loss: 0.7723 - dice_coef_one_class: 0.2277 - precision_one_class: 0.3857 - iou_one_class: 0.1300 - sensitivity_one_class: 0.3034
# 2023-10-29 22:57:16.683007: I tensorflow/core/profiler/lib/profiler_session.cc:67] Profiler session collecting data.
# 2023-10-29 22:57:16.719544: I tensorflow/core/profiler/backends/gpu/cupti_tracer.cc:1798] CUPTI activity buffer flushed
# 2023-10-29 22:57:16.790823: I tensorflow/core/profiler/backends/gpu/cupti_collector.cc:522]  GpuTracer has collected 2813 callback api events and 2902 activity events.
# 2023-10-29 22:57:16.815460: I tensorflow/core/profiler/lib/profiler_session.cc:128] Profiler session tear down.
# 2023-10-29 22:57:16.816800: I tensorflow/core/profiler/rpc/client/save_profile.cc:164] Collecting XSpace to repository: /home/somayeh/PycharmProjects/superpixel_segmentation/tensor_board/plugins/profile/2023_10_29_22_57_16/somayeh-ASUS-TUF-Gaming-F15-FX506HCB-FX506HCB.xplane.pb
# 259/259 [==============================] - ETA: 0s - loss: 0.4068 - dice_coef_one_class: 0.5932 - precision_one_class: 0.7432 - iou_one_class: 0.4350 - sensitivity_one_class: 0.7356Number of images: 519
# Number of masks: 519
#
# Epoch 1: val_loss improved from inf to 0.36295, saving model to cxr_reg_Dunet_superpixel_skin.best.hdf5
# 259/259 [==============================] - 807s 3s/step - loss: 0.4068 - dice_coef_one_class: 0.5932 - precision_one_class: 0.7432 - iou_one_class: 0.4350 - sensitivity_one_class: 0.7356 - val_loss: 0.3630 - val_dice_coef_one_class: 0.6370 - val_precision_one_class: 0.9174 - val_iou_one_class: 0.4753 - val_sensitivity_one_class: 0.6682 - lr: 1.0000e-04
# Epoch 2/50
# 259/259 [==============================] - ETA: 0s - loss: 0.2761 - dice_coef_one_class: 0.7237 - precision_one_class: 0.7848 - iou_one_class: 0.5770 - sensitivity_one_class: 0.8167
# Epoch 2: val_loss improved from 0.36295 to 0.29303, saving model to cxr_reg_Dunet_superpixel_skin.best.hdf5
# 259/259 [==============================] - 738s 3s/step - loss: 0.2761 - dice_coef_one_class: 0.7237 - precision_one_class: 0.7848 - iou_one_class: 0.5770 - sensitivity_one_class: 0.8167 - val_loss: 0.2930 - val_dice_coef_one_class: 0.7070 - val_precision_one_class: 0.9298 - val_iou_one_class: 0.5561 - val_sensitivity_one_class: 0.6457 - lr: 1.0000e-04
# Epoch 3/50
# 259/259 [==============================] - ETA: 0s - loss: 0.2246 - dice_coef_one_class: 0.7752 - precision_one_class: 0.8179 - iou_one_class: 0.6424 - sensitivity_one_class: 0.8284
# Epoch 3: val_loss improved from 0.29303 to 0.28724, saving model to cxr_reg_Dunet_superpixel_skin.best.hdf5
# 259/259 [==============================] -
saving model to cxr_reg_Dunet_superpixel_skin.best.hdf5
# 259/259 [==============================] - 760s 3s/step - loss: 0.0947 - dice_coef_one_class: 0.9053 - precision_one_class: 0.9058 - iou_one_class: 0.8293 - sensitivity_one_class: 0.9108 - val_loss: 0.1346 - val_dice_coef_one_class: 0.8654 - val_precision_one_class: 0.8910 - val_iou_one_class: 0.7685 - val_sensitivity_one_class: 0.8496 - lr: 5.0000e-05
# Epoch 20/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0959 - dice_coef_one_class: 0.9041 - precision_one_class: 0.9076 - iou_one_class: 0.8275 - sensitivity_one_class: 0.9075
# Epoch 20: val_loss improved from 0.13457 to 0.12718, saving model to cxr_reg_Dunet_superpixel_skin.best.hdf5
# 259/259 [==============================] - 757s 3s/step - loss: 0.0959 - dice_coef_one_class: 0.9041 - precision_one_class: 0.9076 - iou_one_class: 0.8275 - sensitivity_one_class: 0.9075 - val_loss: 0.1272 - val_dice_coef_one_class: 0.8728 - val_precision_one_class: 0.8735 - val_iou_one_class: 0.7784 - val_sensitivity_one_class: 0.8815 - lr: 5.0000e-05
# Epoch 21/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0961 - dice_coef_one_class: 0.9039 - precision_one_class: 0.9062 - iou_one_class: 0.8281 - sensitivity_one_class: 0.9092
# Epoch 21: val_loss did not improve from 0.12718
# 259/259 [==============================] - 754s 3s/step - loss: 0.0961 - dice_coef_one_class: 0.9039 - precision_one_class: 0.9062 - iou_one_class: 0.8281 - sensitivity_one_class: 0.9092 - val_loss: 0.1460 - val_dice_coef_one_class: 0.8540 - val_precision_one_class: 0.8699 - val_iou_one_class: 0.7542 - val_sensitivity_one_class: 0.8517 - lr: 5.0000e-05
# Epoch 22/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0942 - dice_coef_one_class: 0.9058 - precision_one_class: 0.9075 - iou_one_class: 0.8308 - sensitivity_one_class: 0.9109
# Epoch 22: val_loss did not improve from 0.12718
# 259/259 [==============================] - 755s 3s/step - loss: 0.0942 - dice_coef_one_class: 0.9058 - precision_one_class: 0.9075 - iou_one_class: 0.8308 - sensitivity_one_class: 0.9109 - val_loss: 0.1354 - val_dice_coef_one_class: 0.8646 - val_precision_one_class: 0.8548 - val_iou_one_class: 0.7675 - val_sensitivity_one_class: 0.8866 - lr: 5.0000e-05
# Epoch 23/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0927 - dice_coef_one_class: 0.9073 - precision_one_class: 0.9106 - iou_one_class: 0.8333 - sensitivity_one_class: 0.9111
# Epoch 23: val_loss did not improve from 0.12718
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 259/259 [==============================] - 753s 3s/step - loss: 0.0927 - dice_coef_one_class: 0.9073 - precision_one_class: 0.9106 - iou_one_class: 0.8333 - sensitivity_one_class: 0.9111 - val_loss: 0.1376 - val_dice_coef_one_class: 0.8624 - val_precision_one_class: 0.8367 - val_iou_one_class: 0.7643 - val_sensitivity_one_class: 0.9013 - lr: 5.0000e-05
# Epoch 24/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0879 - dice_coef_one_class: 0.9120 - precision_one_class: 0.9147 - iou_one_class: 0.8415 - sensitivity_one_class: 0.9162
# Epoch 24: val_loss improved from 0.12718 to 0.12238, saving model to cxr_reg_Dunet_superpixel_skin.best.hdf5
# 259/259 [==============================] - 761s 3s/step - loss: 0.0879 - dice_coef_one_class: 0.9120 - precision_one_class: 0.9147 - iou_one_class: 0.8415 - sensitivity_one_class: 0.9162 - val_loss: 0.1224 - val_dice_coef_one_class: 0.8776 - val_precision_one_class: 0.8863 - val_iou_one_class: 0.7855 - val_sensitivity_one_class: 0.8780 - lr: 2.5000e-05
# Epoch 25/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0844 - dice_coef_one_class: 0.9155 - precision_one_class: 0.9166 - iou_one_class: 0.8465 - sensitivity_one_class: 0.9194
# Epoch 25: val_loss did not improve from 0.12238
# 259/259 [==============================] - 741s 3s/step - loss: 0.0844 - dice_coef_one_class: 0.9155 - precision_one_class: 0.9166 - iou_one_class: 0.8465 - sensitivity_one_class: 0.9194 - val_loss: 0.1332 - val_dice_coef_one_class: 0.8668 - val_precision_one_class: 0.8673 - val_iou_one_class: 0.7692 - val_sensitivity_one_class: 0.8784 - lr: 2.5000e-05
# Epoch 26/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0832 - dice_coef_one_class: 0.9168 - precision_one_class: 0.9168 - iou_one_class: 0.8489 - sensitivity_one_class: 0.9219
# Epoch 26: val_loss did not improve from 0.12238
# 259/259 [==============================] - 764s 3s/step - loss: 0.0832 - dice_coef_one_class: 0.9168 - precision_one_class: 0.9168 - iou_one_class: 0.8489 - sensitivity_one_class: 0.9219 - val_loss: 0.1313 - val_dice_coef_one_class: 0.8687 - val_precision_one_class: 0.8485 - val_iou_one_class: 0.7722 - val_sensitivity_one_class: 0.8985 - lr: 2.5000e-05
# Epoch 27/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0783 - dice_coef_one_class: 0.9216 - precision_one_class: 0.9205 - iou_one_class: 0.8565 - sensitivity_one_class: 0.9267
# Epoch 27: val_loss did not improve from 0.12238
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 259/259 [==============================] - 754s 3s/step - loss: 0.0783 - dice_coef_one_class: 0.9216 - precision_one_class: 0.9205 - iou_one_class: 0.8565 - sensitivity_one_class: 0.9267 - val_loss: 0.1380 - val_dice_coef_one_class: 0.8620 - val_precision_one_class: 0.8766 - val_iou_one_class: 0.7640 - val_sensitivity_one_class: 0.8595 - lr: 2.5000e-05
# Epoch 28/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0795 - dice_coef_one_class: 0.9205 - precision_one_class: 0.9234 - iou_one_class: 0.8556 - sensitivity_one_class: 0.9228
# Epoch 28: val_loss did not improve from 0.12238
# 259/259 [==============================] - 750s 3s/step - loss: 0.0795 - dice_coef_one_class: 0.9205 - precision_one_class: 0.9234 - iou_one_class: 0.8556 - sensitivity_one_class: 0.9228 - val_loss: 0.1334 - val_dice_coef_one_class: 0.8666 - val_precision_one_class: 0.8714 - val_iou_one_class: 0.7712 - val_sensitivity_one_class: 0.8747 - lr: 1.2500e-05
# Epoch 29/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0773 - dice_coef_one_class: 0.9225 - precision_one_class: 0.9217 - iou_one_class: 0.8585 - sensitivity_one_class: 0.9278
# Epoch 29: val_loss did not improve from 0.12238
# 259/259 [==============================] - 762s 3s/step - loss: 0.0773 - dice_coef_one_class: 0.9225 - precision_one_class: 0.9217 - iou_one_class: 0.8585 - sensitivity_one_class: 0.9278 - val_loss: 0.1367 - val_dice_coef_one_class: 0.8633 - val_precision_one_class: 0.8758 - val_iou_one_class: 0.7659 - val_sensitivity_one_class: 0.8626 - lr: 1.2500e-05
# Epoch 30/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0767 - dice_coef_one_class: 0.9234 - precision_one_class: 0.9235 - iou_one_class: 0.8603 - sensitivity_one_class: 0.9276
# Epoch 30: val_loss did not improve from 0.12238
# 259/259 [==============================] - 751s 3s/step - loss: 0.0767 - dice_coef_one_class: 0.9234 - precision_one_class: 0.9235 - iou_one_class: 0.8603 - sensitivity_one_class: 0.9276 - val_loss: 0.1349 - val_dice_coef_one_class: 0.8651 - val_precision_one_class: 0.8760 - val_iou_one_class: 0.7686 - val_sensitivity_one_class: 0.8693 - lr: 1.2500e-05
# Epoch 31/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0731 - dice_coef_one_class: 0.9269 - precision_one_class: 0.9259 - iou_one_class: 0.8655 - sensitivity_one_class: 0.9316
# Epoch 31: val_loss did not improve from 0.12238
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1e-05.
# 259/259 [==============================] - 744s 3s/step - loss: 0.0731 - dice_coef_one_class: 0.9269 - precision_one_class: 0.9259 - iou_one_class: 0.8655 - sensitivity_one_class: 0.9316 - val_loss: 0.1298 - val_dice_coef_one_class: 0.8702 - val_precision_one_class: 0.8682 - val_iou_one_class: 0.7750 - val_sensitivity_one_class: 0.8835 - lr: 1.2500e-05
# Epoch 32/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0736 - dice_coef_one_class: 0.9264 - precision_one_class: 0.9269 - iou_one_class: 0.8644 - sensitivity_one_class: 0.9295
# Epoch 32: val_loss did not improve from 0.12238
# 259/259 [==============================] - 752s 3s/step - loss: 0.0736 - dice_coef_one_class: 0.9264 - precision_one_class: 0.9269 - iou_one_class: 0.8644 - sensitivity_one_class: 0.9295 - val_loss: 0.1297 - val_dice_coef_one_class: 0.8703 - val_precision_one_class: 0.8638 - val_iou_one_class: 0.7748 - val_sensitivity_one_class: 0.8907 - lr: 1.0000e-05
# Epoch 33/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0723 - dice_coef_one_class: 0.9277 - precision_one_class: 0.9262 - iou_one_class: 0.8666 - sensitivity_one_class: 0.9324
# Epoch 33: val_loss did not improve from 0.12238
# 259/259 [==============================] - 752s 3s/step - loss: 0.0723 - dice_coef_one_class: 0.9277 - precision_one_class: 0.9262 - iou_one_class: 0.8666 - sensitivity_one_class: 0.9324 - val_loss: 0.1313 - val_dice_coef_one_class: 0.8687 - val_precision_one_class: 0.8610 - val_iou_one_class: 0.7733 - val_sensitivity_one_class: 0.8862 - lr: 1.0000e-05
# Epoch 34/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0699 - dice_coef_one_class: 0.9301 - precision_one_class: 0.9291 - iou_one_class: 0.8705 - sensitivity_one_class: 0.9342
# Epoch 34: val_loss did not improve from 0.12238
# 259/259 [==============================] - 767s 3s/step - loss: 0.0699 - dice_coef_one_class: 0.9301 - precision_one_class: 0.9291 - iou_one_class: 0.8705 - sensitivity_one_class: 0.9342 - val_loss: 0.1333 - val_dice_coef_one_class: 0.8667 - val_precision_one_class: 0.8597 - val_iou_one_class: 0.7696 - val_sensitivity_one_class: 0.8855 - lr: 1.0000e-05

# %%
test_images = []
ground_truth_test_images = []

# define the paths to the images and their ground truths
test_paths = glob.glob('/home/somayeh/PycharmProjects/superpixel_segmentation/ISIC2018_SKIN_DATA/ISIC2018_Task1-2_Test_Input/*.png')
test_mask_paths = glob.glob("/home/somayeh/PycharmProjects/superpixel_segmentation/ISIC2018_SKIN_DATA/ISIC2018_Task1_Test_GroundTruth/*.png")

# %%
model.load_weights("{}_Dunet_superpixel_skin.best.hdf5".format('cxr_reg'))

# %%
import random
dice_scores = []
import matplotlib.colors as mcolors

for test_path, test_mask_path in zip(test_paths, test_mask_paths):
    # read the image and mask using OpenCV
    test_image = cv2.imread(test_path)
    ground_truth_test_image = cv2.imread(test_mask_path, 0)  # read the mask as grayscale

    # resize the image and mask to the desired dimensions
    test_image = cv2.resize(test_image, (128, 128))
    ground_truth_test_image = cv2.resize(ground_truth_test_image, (128, 128))

    # normalize the image and mask to have values between 0 and 1
    test_image = test_image / 255.0
    ground_truth_test_image = ground_truth_test_image / 255.0

    # add the image and mask to the corresponding arrays
    test_images.append(test_image)
    ground_truth_test_images.append(ground_truth_test_image)

# Convert the images and masks to numpy arrays
test_images = np.array(test_images)
ground_truth_test_images = np.array(ground_truth_test_images)




# Make predictions
predicted_masks = model.predict(test_images)

threshold = 0.5  # You can adjust this threshold as needed

# Create an empty list to store the binary masks
binary_masks = []

# Convert the predicted masks to grayscale
# grayscale_mask = np.mean(predicted_masks, axis=-1)

# Apply the threshold to each predicted mask
for i in range(len(predicted_masks)):
    binary_mask = (predicted_masks[i] > threshold).astype(np.uint8)
    binary_masks.append(binary_mask)

# Convert the list of binary masks to a numpy array
binary_masks = np.array(binary_masks)


print("predicted mask grayscale shape:",binary_masks.shape)  # Shape after conversion
print("predicted mask shape:", predicted_masks.shape)
print("test images shape :", test_images.shape)
print ("ground truth test images shape:", ground_truth_test_images.shape)

dice_scores = []  # List to store the dice coefficients
precision_scores = []
sensitivity_scores = []
iou_scores = []

# Iterate over the images and calculate the dice coefficient
for i in range(len(ground_truth_test_images)):
    y_true = ground_truth_test_images[i]
    y_pred = predicted_masks[i]

    dice = dice_coef_one_class(y_true, y_pred)
    dice_scores.append(dice)

# Compute the average dice coefficient
average_dice = np.mean(dice_scores)


for i in range(len(ground_truth_test_images)):
    y_true = ground_truth_test_images[i]
    y_pred = predicted_masks[i]

    precision_value = precision_one_class(y_true, y_pred)
    precision_scores.append(precision_value)

# Compute the average dice coefficient
average_precision = np.mean(precision_scores)

for i in range(len(ground_truth_test_images)):
    y_true = ground_truth_test_images[i]
    y_pred = predicted_masks[i]

    sensitivity_value = sensitivity_one_class(y_true, y_pred)
    sensitivity_scores.append(sensitivity_value)

# Compute the average dice coefficient
average_sensitivity = np.mean(sensitivity_scores)

for i in range(len(ground_truth_test_images)):
    y_true = ground_truth_test_images[i]
    y_pred = predicted_masks[i]

    iou_value = iou_one_class(y_true, y_pred)
    iou_scores.append(iou_value)

# Compute the average dice coefficient
average_iou = np.mean(iou_scores)

print("Dices:", dice_scores)
print("Dice coefficient:", average_dice)
print("Precision:", average_precision)
print("Sensitivity:", average_sensitivity)
print("IoU:", average_iou)


# Define a custom colormap
cmap_binary = mcolors.ListedColormap(['white', 'black'])  # 'black' for foreground, 'white' for background
n = 15
# Visualize the results for a subset of images

for i in range(n):

    fig, ax = plt.subplots(1, 4, figsize=(10, 5))
    ax[0].imshow(test_images[i])
    ax[0].set_title('Original Image')
    ax[1].imshow(ground_truth_test_images[i], cmap='gray')
    ax[1].set_title('Original Mask')
    ax[2].imshow(predicted_masks[i], cmap="gray")
    ax[2].set_title('Predicted Mask')
    ax[3].imshow(binary_masks[i], cmap="gray")
    ax[3].set_title('Predicted Mask binary')
    plt.show()
# Out:
# 32/32 [==============================] - 9s 284ms/step
# predicted mask grayscale shape: (1000, 128, 128, 3)
# predicted mask shape: (1000, 128, 128, 3)
# test images shape : (1000, 128, 128, 3)
# ground truth test images shape: (1000, 128, 128)
# Dices: [<tf.Tensor: shape=(), dtype=float32, numpy=0.88039607>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8148629>, <tf.Tensor: shape=(), dtype=float32, numpy=0.667278>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8898366>, <tf.Tensor: shape=(), dtype=float32, numpy=0.92005646>, <tf.Tensor: shape=(), dtype=float32, numpy=0.95574725>, <tf.Tensor: shape=(), dtype=float32, numpy=0.83153176>, <tf.Tensor: shape=(), dtype=float32, numpy=0.76755655>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8342812>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9104916>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9382511>, <tf.Tensor: shape=(), dtype=float32, numpy=0.88372266>, <tf.Tensor: shape=(), dtype=float32, numpy=0.94162345>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8003651>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8759423>, <tf.Tensor: shape=(), dtype=float32, numpy=0.7047668>, <tf.Tensor: shape=(), dtype=float32, numpy=0.92673886>, <tf.Tensor: shape=(), dtype=float32, numpy=0.85465527>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9284414>, <tf.Tensor: shape=(), dtype=float32, numpy=0.95543957>, <tf.Tensor: shape=(), dtype=float32, numpy=0.97214997>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8514777>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9006331>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9221578>, <tf.Tensor: shape=(), dtype=float32, numpy=0.93391114>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8952146>, <tf.Tensor: shape=(), dtype=float32, numpy=0.88666177>, <tf.Tensor: shape=(), dtype=float32, numpy=0.85558134>, <tf.Tensor: shape=(), dtype=float32, numpy=0.77820474>, <tf.Tensor: shape=(), dtype=float32, numpy=0.95170933>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9236414>, <tf.Tensor: shape=(), dtype=float32, numpy=0.89375335>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8258521>, <tf.Tensor: shape=(), dtype=float32, numpy=0.943727>, <tf.Tensor: shape=(), dtype=float32, numpy=0.88750356>, <tf.Tensor: shape=(), dtype=float32, numpy=0.72208273>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9750486>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8736911>, <tf.Tensor: shape=(), dtype=float32, numpy=0.7832585>, <tf.Tensor: shape=(), dtype=float32, numpy=0.87421167>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9688029>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9315211>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9336686>, <tf.Tensor: shape=(), dtype=float32, numpy=0.935742>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8438393>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8989882>, <tf.Tensor: shape=(), dtype=float32, numpy=0.83683324>, <tf.Tensor: shape=(), dtype=float32, numpy=0.87432766>, <tf.Tensor: shape=(), dtype=float32, numpy=0.68443054>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8915555>, <tf.Tensor: shape=(), dtype=float32, numpy=0.92862046>, <tf.Tensor: shape=(), dtype=float32, numpy=0.93167436>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9409056>, <tf.Tensor: shape=(), dtype=float32, numpy=0.87065905>, <tf.Tensor: shape=(), dtype=float32, numpy=0.94902396>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9271526>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9147859>, <tf.Tensor: shape=(), dtype=float32, numpy=0.7773669>, <tf.Tensor: shape=(), dtype=float32, numpy=0.95378625>, <tf.Tensor: shape=(), dtype=float32, numpy=0.94800323>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8493867>, <tf.Tensor: shape=(), dtype=float32, numpy=0.89543617>, <tf.Tensor: shape=(), dtype=float32, numpy=0.6595809>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8427043>, <tf.Tensor: shape=(), dtype=float32, numpy=0.96274686>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8502252>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8753432>, <tf.Tensor: shape=(), dtype=float32, numpy=0.91655475>, <tf.Tensor: shape=(), dtype=float32, numpy=0.5058151>, <tf.Tensor: shape=(), dtype=float32, numpy=0.91917455>, <tf.Tensor: shape=(), dtype=float32, numpy=0.6933938>, <tf.Tensor: shape=(), dtype=float32, numpy=0.7339198>, <t ...
# Dice coefficient: 0.8562333
# Precision: 0.9152932
# Sensitivity: 0.844515
# IoU: 0.7703888

# %%
from skimage.color import label2rgb, rgb2gray
from skimage.segmentation import mark_boundaries
import numpy as np
import tensorflow as tf
import os
import cv2
import glob
import matplotlib.pyplot as plt
from keras.layers import *
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from skimage.morphology import binary_erosion, disk
import keras.backend as K
from skimage.segmentation import felzenszwalb, slic, quickshift, watershed
from keras.callbacks import TensorBoard
from keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate
from keras.models import Model
from tqdm import tqdm
# Out:
# 2024-01-23 15:30:06.387019: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-23 15:30:06.556174: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-01-23 15:30:07.273333: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-01-23 15:30:07.273381: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-01-23 15:30:07.273386: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
image_paths = glob.glob('/home/somayeh/PycharmProjects/superpixel_segmentation/archive (3)/data/Lung Segmentation/train_validation_original/*.png' )
mask_paths = glob.glob('/home/somayeh/PycharmProjects/superpixel_segmentation/newgt/newgt_extended_superpixel_chest_SEEDS/*.png')

# %%
def iou(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    iou_score = (intersection + smooth) / (union + smooth)
    return iou_score

def precision(y_true, y_pred):
    y_true_flat = K.flatten(y_true)
    y_pred_flat = K.flatten(y_pred)
    true_positives = K.sum(K.round(K.clip(y_true_flat * y_pred_flat, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred_flat, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())

    return precision

def sensitivity(gt_mask, pred_mask):

    gt_mask_flat = K.flatten(gt_mask)
    pred_mask_flat = K.flatten(pred_mask)

    # compute true positive (TP) and false negative (FN) counts
    TP = K.sum(gt_mask_flat * pred_mask_flat)
    FN = K.sum(gt_mask_flat * (1 - pred_mask_flat))

    # compute sensitivity (recall)
    if TP + FN == 0:
        sensitivity_score = 0.0
    else:
        sensitivity_score = TP / (TP + FN)

    return sensitivity_score

def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %%
def dice_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred, smooth=1)

# %%
batch_size = 8
threshold_value = 128
def data_generator(image_paths, mask_paths, batch_size):

    assert len(image_paths) == len(mask_paths), "Number of images and masks must be the same."

    num_samples = len(image_paths)
    print("Number of images:", num_samples)
    num_masks = len(mask_paths)
    print("Number of masks:", num_masks)

    while True:
        indices = np.arange(num_samples)
        np.random.shuffle(indices)

        for i in range(0, num_samples, batch_size):
            batch_indices = indices[i : i + batch_size]
            batch_images = []
            batch_masks = []

            for index in batch_indices:
                image_path = image_paths[index]
                mask_path = mask_paths[index]

                img = cv2.imread(image_path)
                img = cv2.resize(img, (128, 128))

                mask = cv2.imread(mask_path,0)
                mask = cv2.resize(mask, (128, 128))


                # normalize the image and mask to have values between 0 and 1
                img = img / 255.0
                mask= mask/ 255.0


                batch_images.append(img)
                batch_masks.append(mask)

            # Yield the batch data
            batch_images = np.array(batch_images)
            batch_masks = np.array(batch_masks)


            yield batch_images, batch_masks
# #
generator = data_generator(image_paths, mask_paths, 1)

for _,imgpath in tqdm(enumerate(image_paths)):
   batch = next(generator)
# Out:
# 2it [00:00, 13.78it/s]
# Number of images: 634
# Number of masks: 634
# 634it [00:50, 12.45it/s]

# %%
assert len(image_paths) == len(mask_paths), "Number of images and masks must be the same."
# Split the data into training and validation sets
train_image_paths, val_image_paths, train_mask_paths, val_mask_paths = train_test_split(
    image_paths, mask_paths, test_size=0.2, random_state=2023
)


# Create separate generators for training and validation sets
train_generator = data_generator(train_image_paths, train_mask_paths, batch_size)
val_generator = data_generator(val_image_paths, val_mask_paths, batch_size)

# batch_size = 5  # Number of batches to visualize

# for _ in range(batch_size):
#     batch = next(train_generator)

# Determine the number of steps per epoch for training and validation
train_steps_per_epoch = len(train_image_paths) // batch_size
val_steps_per_epoch = len(val_image_paths) // batch_size

print(train_steps_per_epoch)
print(val_steps_per_epoch)
# Out:
# 63
# 15

# %%
from keras.applications import MobileNetV2

IMAGE_SIZE = 128
# Function for conv2d_block (to be used for building decoder of unet)
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size), kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def unet(n_filters=16, batchnorm=True, dropout=0.1, num_classes=1):
    # Contracting Path (encoder)
    inputs = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3), name="input_image")
    encoder = MobileNetV2(input_tensor=inputs, include_top=False)

    BASE_WEIGHT_PATH = ('https://github.com/fchollet/deep-learning-models/releases/download/v0.6/')
    model_name = 'mobilenet_%s_%d_tf_no_top.h5' % ('1_0', 224)
    weight_path = BASE_WEIGHT_PATH + model_name
    weights_path = tf.keras.utils.get_file(model_name, weight_path)

    encoder.load_weights(weights_path, by_name=True, skip_mismatch=True)

    skip_connection_names = ["input_image", "block_1_expand_relu", "block_3_expand_relu", "block_6_expand_relu"]
    encoder_output = encoder.get_layer("block_13_expand_relu").output

    x = encoder_output
    x_skip_1 = encoder.get_layer(skip_connection_names[-1]).output
    x_skip_2 = encoder.get_layer(skip_connection_names[-2]).output
    x_skip_3 = encoder.get_layer(skip_connection_names[-3]).output
    x_skip_4 = encoder.get_layer(skip_connection_names[-4]).output

    # Expansive Path (decoder)
    u6 = Conv2DTranspose(n_filters * 13, (3, 3), strides=(2, 2), padding='same')(x)
    u6 = concatenate([u6, x_skip_1])
    c6 = conv2d_block(u6, n_filters * 13, kernel_size=3, batchnorm=batchnorm)
    p6 = Dropout(dropout)(c6)

    u7 = Conv2DTranspose(n_filters * 12, (3, 3), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, x_skip_2])
    c7 = conv2d_block(u7, n_filters * 12, kernel_size=3, batchnorm=batchnorm)
    p7 = Dropout(dropout)(c7)

    u8 = Conv2DTranspose(n_filters * 11, (3, 3), strides=(2, 2), padding='same')(p7)
    u8 = concatenate([u8, x_skip_3])
    c8 = conv2d_block(u8, n_filters * 11, kernel_size=3, batchnorm=batchnorm)
    p7 = Dropout(dropout)(c8)

    u9 = Conv2DTranspose(n_filters * 10, (3, 3), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, x_skip_4])
    c9 = conv2d_block(u9, n_filters * 10, kernel_size=3, batchnorm=batchnorm)

    # Output layer with sigmoid activation for binary segmentation
    outputs = Conv2D(num_classes, (1, 1), activation='sigmoid')(c9)

    model = Model(inputs=inputs, outputs=outputs)

    return model

# %%
# !rm -rf '/home/somayeh/PycharmProjects/superpixel_segmentation/tensor_board'

# %%
# %load_ext tensorboard
log_folder = '/home/somayeh/PycharmProjects/superpixel_segmentation/tensor_board'

# %%
weight_path="{}_Unet_extended_superpixel_chest_SEEDS.best.hdf5".format('cxr_reg')


checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1,
                             save_best_only=True, mode='min', save_weights_only = True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                                   patience=3,
                                   verbose=1, mode='min', epsilon=0.0001, cooldown=2, min_lr=1e-5)
early = EarlyStopping(monitor="val_loss",
                      mode="min",
                      patience=10) # probably needs to be more patient, but kaggle time is limited

tbcallback = TensorBoard(log_dir=log_folder,
                         histogram_freq=1,
                         write_graph=True,
                         write_images=True,
                         update_freq='epoch',
                         profile_batch=2,
                         embeddings_freq=1)

callbacks_list = [checkpoint, early, reduceLROnPlat, tbcallback]
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# 2024-01-23 15:31:59.912590: I tensorflow/core/profiler/lib/profiler_session.cc:101] Profiler session initializing.
# 2024-01-23 15:31:59.912615: I tensorflow/core/profiler/lib/profiler_session.cc:116] Profiler session started.
# 2024-01-23 15:31:59.948546: I tensorflow/core/profiler/backends/gpu/cupti_tracer.cc:1664] Profiler found 1 GPUs
# 2024-01-23 15:31:59.991307: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcupti.so.11.2'; dlerror: libcupti.so.11.2: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/somayeh/PycharmProjects/superpixel_segmentation/venv/lib/python3.8/site-packages/cv2/../../lib64:
# 2024-01-23 15:32:00.020819: I tensorflow/core/profiler/lib/profiler_session.cc:128] Profiler session tear down.
# 2024-01-23 15:32:00.021042: I tensorflow/core/profiler/backends/gpu/cupti_tracer.cc:1798] CUPTI activity buffer flushed

# %%
model =unet(n_filters = 8, batchnorm = True, dropout = 0.1, num_classes=1)
opt = tf.keras.optimizers.experimental.AdamW(learning_rate=0.0001)
model.compile(optimizer=opt, loss=dice_loss, metrics= [dice_coef, precision, sensitivity, iou],  run_eagerly=True)
model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# 2024-01-23 15:32:02.572453: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-23 15:32:02.595003: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-23 15:32:02.595193: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-23 15:32:02.595662: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-23 15:32:02.596100: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-23 15:32:02.596251: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-23 15:32:02.596334: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-23 15:32:03.046242: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-23 15:32:03.046589: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-23 15:32:03.046766: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-23 15:32:03.046906: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2111 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_image (InputLayer)       [(None, 128, 128, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 64, 64, 32)   864         ['input_image[0][0]']
#
#  bn_Conv1 (BatchNormalization)  (None, 64, 64, 32)   128         ['Conv1[0][0]']
#
#  Conv1_relu (ReLU)              (None, 64, 64, 32)   0           ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (Depth  (None, 64, 64, 32)  288         ['Conv1_relu[0][0]']
#  wiseConv2D)
#
#  expanded_conv_depthwise_BN (Ba  (None, 64, 64, 32)  128         ['expanded_conv_depthwise[0][0]']
#  tchNormalization)
#
#  expanded_conv_depthwise_relu (  (None, 64, 64, 32)  0           ['expanded_conv_depthwise_BN[0][0
#  ReLU)                                                           ]']
#
#  expanded_conv_project (Conv2D)  (None, 64, 64, 16)  512         ['expanded_conv_depthwise_relu[0]
#                                                                  [0]']
#
#  expanded_conv_project_BN (Batc  (None, 64, 64, 16)  64          ['expanded_conv_project[0][0]']
#  hNormalization)
#
#  block_1_expand (Conv2D)        (None, 64, 64, 96)   1536        ['expanded_conv_project_BN[0][0]'
#                                                                  ]
#
#  block_1_expand_BN (BatchNormal  (None, 64, 64, 96)  384         ['block_1_expand[0][0]']
#  ization)
#
#  block_1_expand_relu (ReLU)     (None, 64, 64, 96)   0           ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D)    (None, 65, 65, 96)   0           ['block_1_expand_relu[0][0]']
#
#  block_1_depthwise (DepthwiseCo  (None, 32, 32, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 32, 32, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 32, 32, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 32, 32, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 32, 32, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 32, 32, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 32, 32, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 32, 32, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 32, 32, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 32, 32, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 32, 32, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 32, 32, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 32, 32, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 32, 32, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 32, 32, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 32, 32, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 32, 32, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 33, 33, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 16, 16, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 16, 16, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 16, 16, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 16, 16, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 16, 16, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 16, 16, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 16, 16, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 16, 16, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 16, 16, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 16, 16, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 16, 16, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 16, 16, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 16, 16, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 16, 16, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 16, 16, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 16, 16, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 16, 16, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 16, 16, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 16, 16, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 16, 16, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 16, 16, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 16, 16, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 16, 16, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 16, 16, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 16, 16, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 16, 16, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 17, 17, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 8, 8, 192)   1728        ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 8, 8, 192)   768         ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 8, 8, 192)    0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 8, 8, 64)     12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 8, 8, 64)    256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 8, 8, 384)    24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 8, 8, 384)   1536        ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 8, 8, 384)    0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 8, 8, 384)   3456        ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 8, 8, 384)   1536        ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 8, 8, 384)    0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 8, 8, 64)     24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 8, 8, 64)    256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 8, 8, 64)     0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 8, 8, 384)    24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 8, 8, 384)   1536        ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 8, 8, 384)    0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 8, 8, 384)   3456        ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 8, 8, 384)   1536        ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 8, 8, 384)    0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 8, 8, 64)     24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 8, 8, 64)    256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 8, 8, 64)     0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 8, 8, 384)    24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 8, 8, 384)   1536        ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 8, 8, 384)    0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 8, 8, 384)   3456        ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 8, 8, 384)   1536        ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 8, 8, 384)    0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 8, 8, 64)     24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 8, 8, 64)    256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 8, 8, 64)     0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 8, 8, 384)    24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 8, 8, 384)   1536        ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 8, 8, 384)    0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 8, 8, 384)   3456        ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 8, 8, 384)   1536        ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 8, 8, 384)   0           ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 8, 8, 96)     36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 8, 8, 96)    384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 8, 8, 576)    55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 8, 8, 576)   2304        ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 8, 8, 576)    0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 8, 8, 576)   5184        ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 8, 8, 576)   2304        ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 8, 8, 576)   0           ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 8, 8, 96)     55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 8, 8, 96)    384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 8, 8, 96)     0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 8, 8, 576)    55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 8, 8, 576)   2304        ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 8, 8, 576)    0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 8, 8, 576)   5184        ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 8, 8, 576)   2304        ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 8, 8, 576)   0           ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 8, 8, 96)     55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 8, 8, 96)    384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 8, 8, 96)     0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 8, 8, 576)    55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 8, 8, 576)   2304        ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 8, 8, 576)    0           ['block_13_expand_BN[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 104)  539240     ['block_13_expand_relu[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 16, 16, 296)  0           ['conv2d_transpose[0][0]',
#                                                                   'block_6_expand_relu[0][0]']
#
#  conv2d (Conv2D)                (None, 16, 16, 104)  277160      ['concatenate[0][0]']
#
#  batch_normalization (BatchNorm  (None, 16, 16, 104)  416        ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 16, 16, 104)  0           ['batch_normalization[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 96)  89952       ['activation[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 240)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'block_3_expand_relu[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 96)   207456      ['concatenate_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 96)  384         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 32, 32, 96)   0           ['batch_normalization_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 32, 32, 96)   0           ['activation_1[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 88)  76120       ['dropout_1[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 184)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'block_1_expand_relu[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 88)   145816      ['concatenate_2[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 88)  352         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 64, 64, 88)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 80  63440      ['activation_2[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 83  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'input_image[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 80  59840       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 80  320        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 128, 128, 80  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 1)  81          ['activation_3[0][0]']
#
# ==================================================================================================
# Total params: 2,076,833
# Trainable params: 2,058,817
# Non-trainable params: 18,016
# __________________________________________________________________________________________________

# %%
loss_history = model.fit_generator(
    train_generator,
    steps_per_epoch=train_steps_per_epoch,
    validation_data=val_generator,
    validation_steps=val_steps_per_epoch,
    epochs=50,
    callbacks =callbacks_list
)

model.save("unet_extended_superpixel_chest_SEEDS.h5")
# Out:
# /tmp/ipykernel_35690/1835363999.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   loss_history = model.fit_generator(
# Number of images: 507
# Number of masks: 507
# Epoch 1/50
# 2024-01-23 15:32:12.068944: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8902
# 2024-01-23 15:32:12.851610: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:12.852931: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:234] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.6
# 2024-01-23 15:32:12.852940: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:237] Used ptxas at ptxas
# 2024-01-23 15:32:12.852989: W tensorflow/compiler/xla/stream_executor/gpu/redzone_allocator.cc:318] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2024-01-23 15:32:12.945799: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-01-23 15:32:13.413599: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.21GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-01-23 15:32:13.413623: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.21GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-01-23 15:32:13.544331: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.61GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-01-23 15:32:13.544358: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.61GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-01-23 15:32:13.697410: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.60GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-01-23 15:32:13.697437: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.60GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-01-23 15:32:13.808815: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-01-23 15:32:13.808842: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-01-23 15:32:13.939021: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.11GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-01-23 15:32:13.939057: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.11GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-01-23 15:32:14.470309: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x87b555d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-01-23 15:32:14.470355: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6
# 2024-01-23 15:32:14.488409: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-01-23 15:32:14.644704: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:14.646951: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2024-01-23 15:32:14.720268: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:14.852383: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7f4934235670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7f4934235670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2024-01-23 15:32:15.065130: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:15.135821: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:15.272845: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:15.346521: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:15.684290: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:15.766271: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:15.923215: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:16.012815: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:16.156640: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:16.960087: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:17.191787: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:17.268627: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:17.424509: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:18.817788: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:19.009569: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:21.438108: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:21.685873: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:22.971306: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:23.034729: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:23.103413: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:23.358443: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:23.496898: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:23.762004: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:23.832804: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:23.897707: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:24.163894: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:24.228749: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:24.295568: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
#  1/63 [..............................] - ETA: 14:21 - loss: 0.6764 - dice_coef: 0.3236 - precision: 0.2537 - sensitivity: 0.5198 - iou: 0.1930
# 2024-01-23 15:32:24.631859: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-23 15:32:24.754180: I tensorflow/core/profiler/lib/profiler_session.cc:101] Profiler session initializing.
# 2024-01-23 15:32:24.754202: I tensorflow/core/profiler/lib/profiler_session.cc:116] Profiler session started.
#  2/63 [..............................] - ETA: 44s - loss: 0.6605 - dice_coef: 0.3395 - precision: 0.2763 - sensitivity: 0.5282 - iou: 0.2046
# 2024-01-23 15:32:25.385187: I tensorflow/core/profiler/lib/profiler_session.cc:67] Profiler session collecting data.
# 2024-01-23 15:32:25.405588: I tensorflow/core/profiler/backends/gpu/cupti_tracer.cc:1798] CUPTI activity buffer flushed
# 2024-01-23 15:32:25.454932: I tensorflow/core/profiler/backends/gpu/cupti_collector.cc:522]  GpuTracer has collected 1645 callback api events and 1742 activity events.
# 2024-01-23 15:32:25.472740: I tensorflow/core/profiler/lib/profiler_session.cc:128] Profiler session tear down.
# 2024-01-23 15:32:25.474332: I tensorflow/core/profiler/rpc/client/save_profile.cc:164] Collecting XSpace to repository: /home/somayeh/PycharmProjects/superpixel_segmentation/tensor_board/plugins/profile/2024_01_23_15_32_25/somayeh-ASUS-TUF-Gaming-F15-FX506HCB-FX506HCB.xplane.pb
# 63/63 [==============================] - ETA: 0s - loss: 0.3069 - dice_coef: 0.6931 - precision: 0.7019 - sensitivity: 0.8597 - iou: 0.5540Number of images: 127
# Number of masks: 127
#
# Epoch 1: val_loss improved from inf to 0.37704, saving model to cxr_reg_Unet_extended_superpixel_chest_SEEDS.best.hdf5
# 63/63 [==============================] - 67s 860ms/step - loss: 0.3069 - dice_coef: 0.6931 - precision: 0.7019 - sensitivity: 0.8597 - iou: 0.5540 - val_loss: 0.3770 - val_dice_coef: 0.6230 - val_precision: 0.5102 - val_sensitivity: 0.9954 - val_iou: 0.4527 - lr: 1.0000e-04
# Epoch 2/50
# 63/63 [==============================] - ETA: 0s - loss: 0.1241 - dice_coef: 0.8762 - precision: 0.9172 - sensitivity: 0.9391 - iou: 0.7801
# Epoch 2: val_loss improved from 0.37704 to 0.19620, saving model to cxr_reg_Unet_extended_superpixel_chest_SEEDS.best.hdf5
# 63/63 [==============================] - 53s 841ms/step - loss: 0.1241 - dice_coef: 0.8762 - precision: 0.9172 - sensitivity: 0.9391 - iou: 0.7801 - val_loss: 0.1962 - val_dice_coef: 0.8038 - val_precision: 0.8051 - val_sensitivity: 0.9661 - val_iou: 0.6722 - lr: 1.0000e-04
# Epoch 3/50
# 63/63 [==============================] - ETA: 0s - loss: 0.1020 - dice_coef: 0.8981 - precision: 0.9303 - sensitivity: 0.9415 - iou: 0.8153
# Epoch 3: val_loss improved from 0.19620 to 0.13764, saving model to cxr_reg_Unet_extended_superpixel_chest_SEEDS.best.hdf5
# 63/63 [==============================] - 50s 808ms/step - loss: 0.1020 - dice_coef: 0.8981 - precision: 0.9303 - sensitivity: 0.9415 - iou: 0.8153 - val_loss: 0.1376 - val_dice_coef: 0.8624 - val_precision: 0.9483 - val_sensitivity: 0.8780 - val_iou: 0.7583 - lr: 1.0000e-04
# Epoch 4/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0904 - dice_coef: 0.9097 - precision: 0.9369 - sensitivity: 0.9430 - iou: 0.8346
# Epoch 4: val_loss did not improve from 0.13764
# 63/63 [==============================] - 50s 804ms/step - loss: 0.0904 - dice_coef: 0.9097 - precision: 0.9369 - sensitivity: 0.9430 - iou: 0.8346 - val_loss: 0.1461 - val_dice_coef: 0.8539 - val_precision: 0.9699 - val_sensitivity: 0.8195 - val_iou: 0.7452 - lr: 1.0000e-04
# Epoch 5/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0840 - dice_coef: 0.9158 - precision: 0.9398 - sensitivity: 0.9439 - iou: 0.8450
# Epoch 5: val_loss did not improve from 0.13764
# 63/63 [==============================] - 50s 800ms/step - loss: 0.0840 - dice_coef: 0.9158 - precision: 0.9398 - sensitivity: 0.9439 - iou: 0.8450 - val_loss: 0.1835 - val_dice_coef: 0.8165 - val_precision: 0.9802 - val_sensitivity: 0.7423 - val_iou: 0.6915 - lr: 1.0000e-04
# Epoch 6/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0780 - dice_coef: 0.9219 - precision: 0.9427 - sensitivity: 0.9447 - iou: 0.8552
# Epoch 6: val_loss did not improve from 0.13764
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 63/63 [==============================] - 50s 797ms/step - loss: 0.0780 - dice_coef: 0.9219 - precision: 0.9427 - sensitivity: 0.9447 - iou: 0.8552 - val_loss: 0.1377 - val_dice_coef: 0.8623 - val_precision: 0.9722 - val_sensitivity: 0.8114 - val_iou: 0.7582 - lr: 1.0000e-04
# Epoch 7/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0724 - dice_coef: 0.9276 - precision: 0.9452 - sensitivity: 0.9490 - iou: 0.8650
# Epoch 7: val_loss did not improve from 0.13764
# 63/63 [==============================] - 53s 844ms/step - loss: 0.0724 - dice_coef: 0.9276 - precision: 0.9452 - sensitivity: 0.9490 - iou: 0.8650 - val_loss: 0.1407 - val_dice_coef: 0.8593 - val_precision: 0.9727 - val_sensitivity: 0.8030 - val_iou: 0.7535 - lr: 5.0000e-05
# Epoch 8/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0703 - dice_coef: 0.9294 - precision: 0.9453 - sensitivity: 0.9500 - iou: 0.8682
# Epoch 8: val_loss improved from 0.13764 to 0.12249, saving model to cxr_reg_Unet_extended_superpixel_chest_SEEDS.best.hdf5
# 63/63 [==============================] - 54s 861ms/step - loss: 0.0703 - dice_coef: 0.9294 - precision: 0.9453 - sensitivity: 0.9500 - iou: 0.8682 - val_loss: 0.1225 - val_dice_coef: 0.8775 - val_precision: 0.9754 - val_sensitivity: 0.8283 - val_iou: 0.7822 - lr: 5.0000e-05
# Epoch 9/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0676 - dice_coef: 0.9324 - precision: 0.9485 - sensitivity: 0.9499 - iou: 0.8734
# Epoch 9: val_loss improved from 0.12249 to 0.10253, saving model to cxr_reg_Unet_extended_superpixel_chest_SEEDS.best.hdf5
# 63/63 [==============================] - 52s 828ms/step - loss: 0.0676 - dice_coef: 0.9324 - precision: 0.9485 - sensitivity: 0.9499 - iou: 0.8734 - val_loss: 0.1025 - val_dice_coef: 0.8975 - val_precision: 0.9639 - val_sensitivity: 0.8705 - val_iou: 0.8142 - lr: 5.0000e-05
# Epoch 10/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0659 - dice_coef: 0.9339 - precision: 0.9474 - sensitivity: 0.9515 - iou: 0.8760
# Epoch 10: val_loss improved from 0.10253 to 0.09660, saving model to cxr_reg_Unet_extended_superpixel_chest_SEEDS.best.hdf5
# 63/63 [==============================] - 50s 805ms/step - loss: 0.0659 - dice_coef: 0.9339 - precision: 0.9474 - sensitivity: 0.9515 - iou: 0.8760 - val_loss: 0.0966 - val_dice_coef: 0.9034 - val_precision: 0.9648 - val_sensitivity: 0.8782 - val_iou: 0.8239 - lr: 5.0000e-05
# Epoch 11/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0630 - dice_coef: 0.9371 - precision: 0.9496 - sensitivity: 0.9532 - iou: 0.8817
# Epoch 11: val_loss improved from 0.09660 to 0.08859, saving model to cxr_reg_Unet_extended_superpixel_chest_SEEDS.best.hdf5
# 63/63 [==============================] - 49s 791ms/step - loss: 0.0630 - dice_coef: 0.9371 - precision: 0.9496 - sensitivity: 0.9532 - iou: 0.8817 - val_loss: 0.0886 - val_dice_coef: 0.9114 - val_precision: 0.9554 - val_sensitivity: 0.8987 - val_iou: 0.8374 - lr: 5.0000e-05
# Epoch 12/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0622 - dice_coef: 0.9378 - precision: 0.9506 - sensitivity: 0.9532 - iou: 0.8830
# Epoch 12: val_loss improved from 0.08859 to 0.08238, saving model to cxr_reg_Unet_extended_superpixel_chest_SEEDS.best.hdf5
# 63/63 [==============================] - 50s 805ms/step - loss: 0.0622 - dice_coef: 0.9378 - precision: 0.9506 - sensitivity: 0.9532 - iou: 0.8830 - val_loss: 0.0824 - val_dice_coef: 0.9176 - val_precision: 0.9510 - val_sensitivity: 0.9128 - val_iou: 0.8480 - lr: 5.0000e-05
# Epoch 13/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0599 - dice_coef: 0.9402 - precision: 0.9511 - sensitivity: 0.9541 - iou: 0.8871
# Epoch 13: val_loss improved from 0.08238 to 0.08083, saving model to cxr_reg_Unet_extended_superpixel_chest_SEEDS.best.hdf5
# 63/63 [==============================] - 51s 814ms/step - loss: 0.0599 - dice_coef: 0.9402 - precision: 0.9511 - sensitivity: 0.9541 - iou: 0.8871 - val_loss: 0.0808 - val_dice_coef: 0.9192 - val_precision: 0.9561 - val_sensitivity: 0.9082 - val_iou: 0.8505 - lr: 5.0000e-05
# Epoch 14/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0583 - dice_coef: 0.9418 - precision: 0.9525 - sensitivity: 0.9548 - iou: 0.8900
# Epoch 14: val_loss improved from 0.08083 to 0.07764, saving model to cxr_reg_Unet_extended_superpixel_chest_SEEDS.best.hdf5
# 63/63 [==============================] - 51s 828ms/step - loss: 0.0583 - dice_coef: 0.9418 - precision: 0.9525 - sensitivity: 0.9548 - iou: 0.8900 - val_loss: 0.0776 - val_dice_coef: 0.9224 - val_precision: 0.9499 - val_sensitivity: 0.9190 - val_iou: 0.8560 - lr: 5.0000e-05
# Epoch 15/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0572 - dice_coef: 0.9428 - precision: 0.9527 - sensitivity: 0.9555 - iou: 0.8919
# Epoch 15: val_loss improved from 0.07764 to 0.07312, saving model to cxr_reg_Unet_extended_superpixel_chest_SEEDS.best.hdf5
# 63/63 [==============================] - 53s 855ms/step - loss: 0.0572 - dice_coef: 0.9428 - precision: 0.9527 - sensitivity: 0.9555 - iou: 0.8919 - val_loss: 0.0731 - val_dice_coef: 0.9269 - val_precision: 0.9484 - val_sensitivity: 0.9276 - val_iou: 0.8638 - lr: 5.0000e-05
# Epoch 16/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0565 - dice_coef: 0.9435 - precision: 0.9533 - sensitivity: 0.9549 - iou: 0.8931
# Epoch 16: val_loss did not improve from 0.07312
# 63/63 [==============================] - 51s 816ms/step - loss: 0.0565 - dice_coef: 0.9435 - precision: 0.9533 - sensitivity: 0.9549 - iou: 0.8931 - val_loss: 0.0737 - val_dice_coef: 0.9263 - val_precision: 0.9439 - val_sensitivity: 0.9302 - val_iou: 0.8628 - lr: 5.0000e-05
# Epoch 17/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0551 - dice_coef: 0.9450 - precision: 0.9542 - sensitivity: 0.9555 - iou: 0.8958
# Epoch 17: val_loss improved from 0.07312 to 0.07163, saving model to cxr_reg_Unet_extended_superpixel_chest_SEEDS.best.hdf5
# 63/63 [==============================] - 47s 761ms/step - loss: 0.0551 - dice_coef: 0.9450 - precision: 0.9542 - sensitivity: 0.9555 - iou: 0.8958 - val_loss: 0.0716 - val_dice_coef: 0.9284 - val_precision: 0.9488 - val_sensitivity: 0.9274 - val_iou: 0.8664 - lr: 5.0000e-05
# Epoch 18/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0540 - dice_coef: 0.9460 - precision: 0.9549 - sensitivity: 0.9564 - iou: 0.8976
# Epoch 18: val_loss did not improve from 0.07163
# 63/63 [==============================] - 49s 784ms/step - loss: 0.0540 - dice_coef: 0.9460 - precision: 0.9549 - sensitivity: 0.9564 - iou: 0.8976 - val_loss: 0.0735 - val_dice_coef: 0.9265 - val_precision: 0.9512 - val_sensitivity: 0.9207 - val_iou: 0.8631 - lr: 5.0000e-05
# Epoch 19/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0530 - dice_coef: 0.9471 - precision: 0.9555 - sensitivity: 0.9567 - iou: 0.8996
# Epoch 19: val_loss improved from 0.07163 to 0.06927, saving model to cxr_reg_Unet_extended_superpixel_chest_SEEDS.best.hdf5
# 63/63 [==============================] - 48s 773ms/step - loss: 0.0530 - dice_coef: 0.9471 - precision: 0.9555 - sensitivity: 0.9567 - iou: 0.8996 - val_loss: 0.0693 - val_dice_coef: 0.9307 - val_precision: 0.9528 - val_sensitivity: 0.9258 - val_iou: 0.8706 - lr: 5.0000e-05
# Epoch 20/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0515 - dice_coef: 0.9486 - precision: 0.9561 - sensitivity: 0.9573 - iou: 0.9022
# Epoch 20: val_loss did not improve from 0.06927
# 63/63 [==============================] - 48s 775ms/step - loss: 0.0515 - dice_coef: 0.9486 - precision: 0.9561 - sensitivity: 0.9573 - iou: 0.9022 - val_loss: 0.0705 - val_dice_coef: 0.9295 - val_precision: 0.9395 - val_sensitivity: 0.9369 - val_iou: 0.8685 - lr: 5.0000e-05
# Epoch 21/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0509 - dice_coef: 0.9491 - precision: 0.9571 - sensitivity: 0.9571 - iou: 0.9033
# Epoch 21: val_loss did not improve from 0.06927
# 63/63 [==============================] - 48s 767ms/step - loss: 0.0509 - dice_coef: 0.9491 - precision: 0.9571 - sensitivity: 0.9571 - iou: 0.9033 - val_loss: 0.0707 - val_dice_coef: 0.9293 - val_precision: 0.9595 - val_sensitivity: 0.9146 - val_iou: 0.8680 - lr: 5.0000e-05
# Epoch 22/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0496 - dice_coef: 0.9503 - precision: 0.9572 - sensitivity: 0.9584 - iou: 0.9054
# Epoch 22: val_loss improved from 0.06927 to 0.06911, saving model to cxr_reg_Unet_extended_superpixel_chest_SEEDS.best.hdf5
# 63/63 [==============================] - 49s 783ms/step - loss: 0.0496 - dice_coef: 0.9503 - precision: 0.9572 - sensitivity: 0.9584 - iou: 0.9054 - val_loss: 0.0691 - val_dice_coef: 0.9309 - val_precision: 0.9445 - val_sensitivity: 0.9323 - val_iou: 0.8708 - lr: 5.0000e-05
# Epoch 23/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0495 - dice_coef: 0.9506 - precision: 0.9579 - sensitivity: 0.9578 - iou: 0.9058
# Epoch 23: val_loss improved from 0.06911 to 0.06854, saving model to cxr_reg_Unet_extended_superpixel_chest_SEEDS.best.hdf5
# 63/63 [==============================] - 47s 761ms/step - loss: 0.0495 - dice_coef: 0.9506 - precision: 0.9579 - sensitivity: 0.9578 - iou: 0.9058 - val_loss: 0.0685 - val_dice_coef: 0.9315 - val_precision: 0.9379 - val_sensitivity: 0.9397 - val_iou: 0.8718 - lr: 5.0000e-05
# Epoch 24/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0482 - dice_coef: 0.9518 - precision: 0.9582 - sensitivity: 0.9584 - iou: 0.9081
# Epoch 24: val_loss did not improve from 0.06854
# 63/63 [==============================] - 48s 774ms/step - loss: 0.0482 - dice_coef: 0.9518 - precision: 0.9582 - sensitivity: 0.9584 - iou: 0.9081 - val_loss: 0.0689 - val_dice_coef: 0.9311 - val_precision: 0.9558 - val_sensitivity: 0.9202 - val_iou: 0.8711 - lr: 5.0000e-05
# Epoch 25/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0479 - dice_coef: 0.9521 - precision: 0.9587 - sensitivity: 0.9589 - iou: 0.9087
# Epoch 25: val_loss improved from 0.06854 to 0.06847, saving model to cxr_reg_Unet_extended_superpixel_chest_SEEDS.best.hdf5
# 63/63 [==============================] - 49s 791ms/step - loss: 0.0479 - dice_coef: 0.9521 - precision: 0.9587 - sensitivity: 0.9589 - iou: 0.9087 - val_loss: 0.0685 - val_dice_coef: 0.9315 - val_precision: 0.9419 - val_sensitivity: 0.9343 - val_iou: 0.8720 - lr: 5.0000e-05
# Epoch 26/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0464 - dice_coef: 0.9536 - precision: 0.9595 - sensitivity: 0.9592 - iou: 0.9113
# Epoch 26: val_loss improved from 0.06847 to 0.06613, saving model to cxr_reg_Unet_extended_superpixel_chest_SEEDS.best.hdf5
# 63/63 [==============================] - 47s 763ms/step - loss: 0.0464 - dice_coef: 0.9536 - precision: 0.9595 - sensitivity: 0.9592 - iou: 0.9113 - val_loss: 0.0661 - val_dice_coef: 0.9339 - val_precision: 0.9464 - val_sensitivity: 0.9334 - val_iou: 0.8760 - lr: 5.0000e-05
# Epoch 27/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0462 - dice_coef: 0.9539 - precision: 0.9603 - sensitivity: 0.9593 - iou: 0.9119
# Epoch 27: val_loss did not improve from 0.06613
# 63/63 [==============================] - 47s 763ms/step - loss: 0.0462 - dice_coef: 0.9539 - precision: 0.9603 - sensitivity: 0.9593 - iou: 0.9119 - val_loss: 0.0662 - val_dice_coef: 0.9338 - val_precision: 0.9537 - val_sensitivity: 0.9255 - val_iou: 0.8760 - lr: 5.0000e-05
# Epoch 28/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0453 - dice_coef: 0.9546 - precision: 0.9599 - sensitivity: 0.9600 - iou: 0.9132
# Epoch 28: val_loss did not improve from 0.06613
# 63/63 [==============================] - 48s 769ms/step - loss: 0.0453 - dice_coef: 0.9546 - precision: 0.9599 - sensitivity: 0.9600 - iou: 0.9132 - val_loss: 0.0668 - val_dice_coef: 0.9332 - val_precision: 0.9404 - val_sensitivity: 0.9375 - val_iou: 0.8748 - lr: 5.0000e-05
# Epoch 29/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0450 - dice_coef: 0.9550 - precision: 0.9609 - sensitivity: 0.9602 - iou: 0.9139
# Epoch 29: val_loss did not improve from 0.06613
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 63/63 [==============================] - 49s 785ms/step - loss: 0.0450 - dice_coef: 0.9550 - precision: 0.9609 - sensitivity: 0.9602 - iou: 0.9139 - val_loss: 0.0663 - val_dice_coef: 0.9337 - val_precision: 0.9515 - val_sensitivity: 0.9265 - val_iou: 0.8758 - lr: 5.0000e-05
# Epoch 30/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0441 - dice_coef: 0.9558 - precision: 0.9613 - sensitivity: 0.9601 - iou: 0.9153
# Epoch 30: val_loss did not improve from 0.06613
# 63/63 [==============================] - 48s 778ms/step - loss: 0.0441 - dice_coef: 0.9558 - precision: 0.9613 - sensitivity: 0.9601 - iou: 0.9153 - val_loss: 0.0681 - val_dice_coef: 0.9319 - val_precision: 0.9312 - val_sensitivity: 0.9450 - val_iou: 0.8727 - lr: 2.5000e-05
# Epoch 31/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0432 - dice_coef: 0.9568 - precision: 0.9623 - sensitivity: 0.9604 - iou: 0.9172
# Epoch 31: val_loss improved from 0.06613 to 0.06507, saving model to cxr_reg_Unet_extended_superpixel_chest_SEEDS.best.hdf5
# 63/63 [==============================] - 48s 776ms/step - loss: 0.0432 - dice_coef: 0.9568 - precision: 0.9623 - sensitivity: 0.9604 - iou: 0.9172 - val_loss: 0.0651 - val_dice_coef: 0.9349 - val_precision: 0.9386 - val_sensitivity: 0.9423 - val_iou: 0.8779 - lr: 2.5000e-05
# Epoch 32/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0429 - dice_coef: 0.9571 - precision: 0.9618 - sensitivity: 0.9620 - iou: 0.9178
# Epoch 32: val_loss did not improve from 0.06507
# 63/63 [==============================] - 48s 775ms/step - loss: 0.0429 - dice_coef: 0.9571 - precision: 0.9618 - sensitivity: 0.9620 - iou: 0.9178 - val_loss: 0.0658 - val_dice_coef: 0.9342 - val_precision: 0.9354 - val_sensitivity: 0.9443 - val_iou: 0.8767 - lr: 2.5000e-05
# Epoch 33/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0430 - dice_coef: 0.9570 - precision: 0.9622 - sensitivity: 0.9607 - iou: 0.9176
# Epoch 33: val_loss did not improve from 0.06507
# 63/63 [==============================] - 46s 747ms/step - loss: 0.0430 - dice_coef: 0.9570 - precision: 0.9622 - sensitivity: 0.9607 - iou: 0.9176 - val_loss: 0.0654 - val_dice_coef: 0.9346 - val_precision: 0.9376 - val_sensitivity: 0.9422 - val_iou: 0.8773 - lr: 2.5000e-05
# Epoch 34/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0432 - dice_coef: 0.9567 - precision: 0.9619 - sensitivity: 0.9613 - iou: 0.9171
# Epoch 34: val_loss did not improve from 0.06507
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 63/63 [==============================] - 49s 791ms/step - loss: 0.0432 - dice_coef: 0.9567 - precision: 0.9619 - sensitivity: 0.9613 - iou: 0.9171 - val_loss: 0.0651 - val_dice_coef: 0.9349 - val_precision: 0.9443 - val_sensitivity: 0.9355 - val_iou: 0.8778 - lr: 2.5000e-05
# Epoch 35/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0423 - dice_coef: 0.9576 - precision: 0.9629 - sensitivity: 0.9611 - iou: 0.9187
# Epoch 35: val_loss did not improve from 0.06507
# 63/63 [==============================] - 50s 800ms/step - loss: 0.0423 - dice_coef: 0.9576 - precision: 0.9629 - sensitivity: 0.9611 - iou: 0.9187 - val_loss: 0.0651 - val_dice_coef: 0.9349 - val_precision: 0.9430 - val_sensitivity: 0.9367 - val_iou: 0.8779 - lr: 1.2500e-05
# Epoch 36/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0425 - dice_coef: 0.9573 - precision: 0.9625 - sensitivity: 0.9617 - iou: 0.9182
# Epoch 36: val_loss improved from 0.06507 to 0.06479, saving model to cxr_reg_Unet_extended_superpixel_chest_SEEDS.best.hdf5
# 63/63 [==============================] - 48s 775ms/step - loss: 0.0425 - dice_coef: 0.9573 - precision: 0.9625 - sensitivity: 0.9617 - iou: 0.9182 - val_loss: 0.0648 - val_dice_coef: 0.9352 - val_precision: 0.9426 - val_sensitivity: 0.9382 - val_iou: 0.8783 - lr: 1.2500e-05
# Epoch 37/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0417 - dice_coef: 0.9581 - precision: 0.9629 - sensitivity: 0.9619 - iou: 0.9196
# Epoch 37: val_loss improved from 0.06479 to 0.06439, saving model to cxr_reg_Unet_extended_superpixel_chest_SEEDS.best.hdf5
# 63/63 [==============================] - 49s 789ms/step - loss: 0.0417 - dice_coef: 0.9581 - precision: 0.9629 - sensitivity: 0.9619 - iou: 0.9196 - val_loss: 0.0644 - val_dice_coef: 0.9356 - val_precision: 0.9455 - val_sensitivity: 0.9357 - val_iou: 0.8791 - lr: 1.2500e-05
# Epoch 38/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0421 - dice_coef: 0.9579 - precision: 0.9629 - sensitivity: 0.9616 - iou: 0.9192
# Epoch 38: val_loss improved from 0.06439 to 0.06437, saving model to cxr_reg_Unet_extended_superpixel_chest_SEEDS.best.hdf5
# 63/63 [==============================] - 50s 804ms/step - loss: 0.0421 - dice_coef: 0.9579 - precision: 0.9629 - sensitivity: 0.9616 - iou: 0.9192 - val_loss: 0.0644 - val_dice_coef: 0.9356 - val_precision: 0.9412 - val_sensitivity: 0.9404 - val_iou: 0.8791 - lr: 1.2500e-05
# Epoch 39/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0419 - dice_coef: 0.9581 - precision: 0.9630 - sensitivity: 0.9621 - iou: 0.9197
# Epoch 39: val_loss did not improve from 0.06437
# 63/63 [==============================] - 48s 768ms/step - loss: 0.0419 - dice_coef: 0.9581 - precision: 0.9630 - sensitivity: 0.9621 - iou: 0.9197 - val_loss: 0.0646 - val_dice_coef: 0.9354 - val_precision: 0.9399 - val_sensitivity: 0.9412 - val_iou: 0.8788 - lr: 1.2500e-05
# Epoch 40/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0416 - dice_coef: 0.9584 - precision: 0.9632 - sensitivity: 0.9619 - iou: 0.9201
# Epoch 40: val_loss did not improve from 0.06437
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1e-05.
# 63/63 [==============================] - 49s 789ms/step - loss: 0.0416 - dice_coef: 0.9584 - precision: 0.9632 - sensitivity: 0.9619 - iou: 0.9201 - val_loss: 0.0644 - val_dice_coef: 0.9356 - val_precision: 0.9443 - val_sensitivity: 0.9365 - val_iou: 0.8791 - lr: 1.2500e-05
# Epoch 41/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0407 - dice_coef: 0.9594 - precision: 0.9637 - sensitivity: 0.9629 - iou: 0.9219
# Epoch 41: val_loss improved from 0.06437 to 0.06409, saving model to cxr_reg_Unet_extended_superpixel_chest_SEEDS.best.hdf5
# 63/63 [==============================] - 49s 786ms/step - loss: 0.0407 - dice_coef: 0.9594 - precision: 0.9637 - sensitivity: 0.9629 - iou: 0.9219 - val_loss: 0.0641 - val_dice_coef: 0.9359 - val_precision: 0.9430 - val_sensitivity: 0.9388 - val_iou: 0.8797 - lr: 1.0000e-05
# Epoch 42/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0411 - dice_coef: 0.9588 - precision: 0.9632 - sensitivity: 0.9629 - iou: 0.9209
# Epoch 42: val_loss improved from 0.06409 to 0.06371, saving model to cxr_reg_Unet_extended_superpixel_chest_SEEDS.best.hdf5
# 63/63 [==============================] - 49s 786ms/step - loss: 0.0411 - dice_coef: 0.9588 - precision: 0.9632 - sensitivity: 0.9629 - iou: 0.9209 - val_loss: 0.0637 - val_dice_coef: 0.9363 - val_precision: 0.9454 - val_sensitivity: 0.9370 - val_iou: 0.8803 - lr: 1.0000e-05
# Epoch 43/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0410 - dice_coef: 0.9590 - precision: 0.9644 - sensitivity: 0.9618 - iou: 0.9213
# Epoch 43: val_loss improved from 0.06371 to 0.06364, saving model to cxr_reg_Unet_extended_superpixel_chest_SEEDS.best.hdf5
# 63/63 [==============================] - 49s 788ms/step - loss: 0.0410 - dice_coef: 0.9590 - precision: 0.9644 - sensitivity: 0.9618 - iou: 0.9213 - val_loss: 0.0636 - val_dice_coef: 0.9364 - val_precision: 0.9450 - val_sensitivity: 0.9371 - val_iou: 0.8806 - lr: 1.0000e-05
# Epoch 44/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0410 - dice_coef: 0.9590 - precision: 0.9634 - sensitivity: 0.9628 - iou: 0.9213
# Epoch 44: val_loss did not improve from 0.06364
# 63/63 [==============================] - 49s 791ms/step - loss: 0.0410 - dice_coef: 0.9590 - precision: 0.9634 - sensitivity: 0.9628 - iou: 0.9213 - val_loss: 0.0640 - val_dice_coef: 0.9360 - val_precision: 0.9455 - val_sensitivity: 0.9358 - val_iou: 0.8797 - lr: 1.0000e-05
# Epoch 45/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0408 - dice_coef: 0.9591 - precision: 0.9634 - sensitivity: 0.9628 - iou: 0.9214
# Epoch 45: val_loss improved from 0.06364 to 0.06361, saving model to cxr_reg_Unet_extended_superpixel_chest_SEEDS.best.hdf5
# 63/63 [==============================] - 49s 791ms/step - loss: 0.0408 - dice_coef: 0.9591 - precision: 0.9634 - sensitivity: 0.9628 - iou: 0.9214 - val_loss: 0.0636 - val_dice_coef: 0.9364 - val_precision: 0.9511 - val_sensitivity: 0.9306 - val_iou: 0.8804 - lr: 1.0000e-05
# Epoch 46/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0405 - dice_coef: 0.9596 - precision: 0.9644 - sensitivity: 0.9626 - iou: 0.9224
# Epoch 46: val_loss improved from 0.06361 to 0.06209, saving model to cxr_reg_Unet_extended_superpixel_chest_SEEDS.best.hdf5
# 63/63 [==============================] - 49s 789ms/step - loss: 0.0405 - dice_coef: 0.9596 - precision: 0.9644 - sensitivity: 0.9626 - iou: 0.9224 - val_loss: 0.0621 - val_dice_coef: 0.9379 - val_precision: 0.9472 - val_sensitivity: 0.9378 - val_iou: 0.8831 - lr: 1.0000e-05
# Epoch 47/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0402 - dice_coef: 0.9597 - precision: 0.9642 - sensitivity: 0.9628 - iou: 0.9226
# Epoch 47: val_loss did not improve from 0.06209
# 63/63 [==============================] - 49s 785ms/step - loss: 0.0402 - dice_coef: 0.9597 - precision: 0.9642 - sensitivity: 0.9628 - iou: 0.9226 - val_loss: 0.0636 - val_dice_coef: 0.9364 - val_precision: 0.9445 - val_sensitivity: 0.9375 - val_iou: 0.8805 - lr: 1.0000e-05
# Epoch 48/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0407 - dice_coef: 0.9593 - precision: 0.9637 - sensitivity: 0.9628 - iou: 0.9218
# Epoch 48: val_loss did not improve from 0.06209
# 63/63 [==============================] - 49s 782ms/step - loss: 0.0407 - dice_coef: 0.9593 - precision: 0.9637 - sensitivity: 0.9628 - iou: 0.9218 - val_loss: 0.0633 - val_dice_coef: 0.9367 - val_precision: 0.9466 - val_sensitivity: 0.9358 - val_iou: 0.8810 - lr: 1.0000e-05
# Epoch 49/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0406 - dice_coef: 0.9593 - precision: 0.9640 - sensitivity: 0.9626 - iou: 0.9219
# Epoch 49: val_loss did not improve from 0.06209
# 63/63 [==============================] - 48s 769ms/step - loss: 0.0406 - dice_coef: 0.9593 - precision: 0.9640 - sensitivity: 0.9626 - iou: 0.9219 - val_loss: 0.0631 - val_dice_coef: 0.9369 - val_precision: 0.9430 - val_sensitivity: 0.9403 - val_iou: 0.8814 - lr: 1.0000e-05
# Epoch 50/50
# 63/63 [==============================] - ETA: 0s - loss: 0.0401 - dice_coef: 0.9598 - precision: 0.9645 - sensitivity: 0.9628 - iou: 0.9228
# Epoch 50: val_loss did not improve from 0.06209
# 63/63 [==============================] - 49s 793ms/step - loss: 0.0401 - dice_coef: 0.9598 - precision: 0.9645 - sensitivity: 0.9628 - iou: 0.9228 - val_loss: 0.0644 - val_dice_coef: 0.9356 - val_precision: 0.9401 - val_sensitivity: 0.9408 - val_iou: 0.8792 - lr: 1.0000e-05

# %%
test_images = []
ground_truth_test_images = []

test_paths = glob.glob("/home/somayeh/PycharmProjects/superpixel_segmentation/archive (3)/data/Lung Segmentation/test_original/*.png")
test_mask_paths = glob.glob("/home/somayeh/PycharmProjects/superpixel_segmentation/archive (3)/data/Lung Segmentation/test_mask/*.png")

# %%
for test_path, test_mask_path in zip(test_paths, test_mask_paths):
    # read the image and mask using OpenCV
    test_image = cv2.imread(test_path)
    ground_truth_test_image = cv2.imread(test_mask_path, 0)  # read the mask as grayscale

    # resize the image and mask to the desired dimensions
    test_image = cv2.resize(test_image, (128, 128))
    ground_truth_test_image = cv2.resize(ground_truth_test_image, (128, 128))

# normalize the image and mask to have values between 0 and 1

    test_image = test_image / 255.0
    ground_truth_test_image= ground_truth_test_image / 255.0

    # add the image and mask to the corresponding arrays
    test_images.append(test_image)
    ground_truth_test_images.append(ground_truth_test_image)


#by the end of this line, I have superpixeled images.
# convert the images and masks to numpy arrays
test_images = np.array(test_images)
ground_truth_test_images = np.array(ground_truth_test_images)
print(test_images.shape)
print(ground_truth_test_images.shape)
# add a channel dimension to the masks
# ground_truth_test_images = np.expand_dims(ground_truth_test_images, axis=-1)


# Make predictions
# predicted_masks = model.predict(test_images)
tf.config.run_functions_eagerly(True)
predicted_masks = model.predict(
    test_images,
    batch_size=1,
    verbose=1,
    steps=None,
    callbacks=None
)

predicted_mask_array = np.array(predicted_masks)
print(predicted_mask_array.shape)

# Convert the NumPy array to uint8 format
predicted_mask_array = (predicted_mask_array * 255).astype(np.uint8)
print(predicted_mask_array.shape)

#
dst = np.empty([predicted_mask_array.shape[0],predicted_mask_array.shape[1],predicted_mask_array.shape[2]])
kernel = np.ones((5,5),np.float64)/25
# dst = predicted_mask_array

#
for i in range(predicted_mask_array.shape[0]):

        threshold_value = 1
        _, dst[i] = cv2.threshold(predicted_mask_array[i], threshold_value, 255, cv2.THRESH_BINARY)
        dst[i] = np.array(dst[i])
        dst[i] = tf.convert_to_tensor(dst[i] / 255.0,dtype=predicted_masks.dtype)

print(dst.shape)

## Cast the input tensor to a double tensor
ground_truth_test_images = tf.cast(ground_truth_test_images, dtype=tf.float64)
predicted_masks = tf.cast(dst, dtype=tf.float64)
# predicted_masks = tf.cast(predicted_mask_array, dtype=tf.float64)
# Apply thresholding


dice_scores = []  # List to store the dice coefficients
precision_scores = []
sensitivity_scores = []
iou_scores = []

# Iterate over the images and calculate the dice coefficient
for i in range(len(ground_truth_test_images)):
    y_true = ground_truth_test_images[i]
    y_pred = predicted_masks[i]

    dice = dice_coef(y_true, y_pred)
    dice_scores.append(dice)

# Compute the average dice coefficient
average_dice = np.mean(dice_scores)

for i in range(len(ground_truth_test_images)):
    y_true = ground_truth_test_images[i]
    y_pred = predicted_masks[i]

    precision_value = precision(y_true, y_pred)
    precision_scores.append(precision_value)

# Compute the average dice coefficient
average_precision = np.mean(precision_scores)

for i in range(len(ground_truth_test_images)):
    y_true = ground_truth_test_images[i]
    y_pred = predicted_masks[i]

    sensitivity_value = sensitivity(y_true, y_pred)
    sensitivity_scores.append(sensitivity_value)

# Compute the average dice coefficient
average_sensitivity = np.mean(sensitivity_scores)

for i in range(len(ground_truth_test_images)):
    y_true = ground_truth_test_images[i]
    y_pred = predicted_masks[i]

    iou_value = iou(y_true, y_pred)
    iou_scores.append(iou_value)

# Compute the average dice coefficient
average_iou = np.mean(iou_scores)


print("Dices:", dice_scores)
print("Dice coefficient:", average_dice)
print("Precision:", average_precision)
print("Sensitivity:", average_sensitivity)
print("IoU:", average_iou)

n =35 # number of images to show
for i in range(n):
    fig, ax = plt.subplots(1, 3, figsize=(10, 5))
    ax[0].imshow(test_images[i])
    ax[0].set_title('Original Image')
    ax[1].imshow(ground_truth_test_images[i])
    ax[1].set_title('Original Mask')
    ax[2].imshow(dst[i])
    ax[2].set_title('Predicted Mask')
    plt.show()
# Out:
# (70, 128, 128, 3)
# (70, 128, 128)
# /home/somayeh/PycharmProjects/superpixel_segmentation/venv/lib/python3.8/site-packages/tensorflow/python/data/ops/structured_function.py:256: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 70/70 [==============================] - 3s 32ms/step
# (70, 128, 128, 1)
# (70, 128, 128, 1)
# (70, 128, 128)
# Dices: [<tf.Tensor: shape=(), dtype=float64, numpy=0.9528422700906045>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8584452875271025>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9507285753739582>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9459012664374896>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9315141512044932>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9260895701138173>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9379261510454349>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9259073628814494>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9275688868465558>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9480177824244373>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9265783092120499>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8688346710185639>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9265837422721681>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8841730971471761>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9244199518306406>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9377341727150195>, <tf.Tensor: shape=(), dtype=float64, numpy=0.897275966128723>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9339917821609934>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8918720105927561>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9515363780597937>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9288387247191177>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8681014259071516>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9520577574116539>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9515857982668477>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9124508899380775>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9109023581382315>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9530201825837435>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9116890706388896>, <tf.Tensor: shape=(), dtype=float64, numpy=0.931913939618237>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9119194463820627>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9210172482564395>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9377217833932139>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9414726942598026>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9002099736857565>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9313318443251631>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9321615256706636>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9283459553237878>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9312377102171555>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9314764355072334>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8786778032647119>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9674129069654523>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9044988129157534>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9596866932564309>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9283221879046406>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8747662135594996>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9656333247905049>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9386252961318086>, <tf.Tensor: shape=(), dtype=float64, numpy=0.854133878413551>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9114081575133767>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8716079530251664>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9544811579331303>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9563983763250468>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9428808329102406>, <tf.Tensor: shape=(), dtype=float64, numpy=0.872559605044451>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9098952751324371>, <tf.Tensor: shape=(), dtype=float64, numpy=0.92929364915071>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9556515600760587>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9302013907716343>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9497079274318792>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9503052411378023>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9204872221054028>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9289849945090913>, <tf.Tensor: shape=(), dtype=fl ...
# Dice coefficient: 0.9247620154708175
# Precision: 0.8795646020027529
# Sensitivity: 0.9775989720174874
# IoU: 0.8612491254180634

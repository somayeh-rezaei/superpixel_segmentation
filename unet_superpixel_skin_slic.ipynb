# %%
# import os
# os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
from skimage.color import label2rgb, rgb2gray
from skimage.segmentation import mark_boundaries
import numpy as np
import tensorflow as tf
import os
import cv2
import glob
import matplotlib.pyplot as plt
from keras.layers import *
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from skimage.morphology import binary_erosion, disk
import keras.backend as K
from skimage.segmentation import felzenszwalb, slic, quickshift, watershed
from keras.callbacks import TensorBoard
from keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate
from keras.models import Model
from tqdm import tqdm

# %%
image_paths = glob.glob("/home/somayeh/PycharmProjects/superpixel_segmentation/ISIC2018_SKIN_DATA/ISIC2018_Task1-2_Training_Input/*.png")
mask_paths = glob.glob("/home/somayeh/PycharmProjects/superpixel_segmentation/ISIC2018_SKIN_DATA/ISIC2018_Task1_Training_GroundTruth/*.png")

# %%
# initialize empty arrays to hold the images and masks
images = []
masks = []
images_superpixel = []
binary_masks = []
masks_superpixel = []
masks_result = []
binary = []

# %%
def create_superpixel_ground_truth(img, ground_truth):

    # Perform superpixel segmentation
    num_segments = 800
    segments = slic(img, n_segments=num_segments, compactness=10)

    image_superpixel = label2rgb(segments, img, kind='avg')
    image_superpixel = rgb2gray(image_superpixel)
    num_superpixels = len(np.unique(segments))

    image_boundaries = mark_boundaries(img, segments, color=(255, 0, 0))
    labels = segments.astype(np.int32)

    # Overlay superpixels with ground truth
    inside_mask = (ground_truth == 255)  # White pixels in ground truth are inside the region
    outside_mask = (ground_truth == 0)  # Black pixels in ground truth are outside the region
    boundary_mask = cv2.morphologyEx(ground_truth, cv2.MORPH_GRADIENT, np.ones((3, 3), np.uint8)) > 0

    inside_superpixels = set(np.unique(labels[inside_mask]))
    outside_superpixels = set(np.unique(labels[outside_mask]))
    boundary_superpixels = set(np.unique(labels[boundary_mask]))

    # Exclude boundary superpixels
    valid_superpixels = list(outside_superpixels.union(inside_superpixels) - boundary_superpixels)

    for label in boundary_superpixels:
        mask = (labels == label)
        # Check if the superpixel intersects with the boundary
        if np.any(mask[0, :]) or np.any(mask[-1, :]) or np.any(mask[:, 0]) or np.any(mask[:, -1]):
            boundary_mask_ = binary_erosion(boundary_mask, disk(3))
            valid_superpixels = list(outside_superpixels.union(inside_superpixels) - set(labels[boundary_mask_]))

    num_segments_result = len(np.unique(valid_superpixels))

    # Assign labels and color superpixels
    result = np.zeros_like(img)
    inside_labels = []
    outside_labels = []
    for label in valid_superpixels:
        mask = (labels == label)
        if label in inside_superpixels:
            color = (255, 255, 255)  # Yellow for inside superpixels
            inside_labels.append(label)
        else:
            color = (0, 0, 0)
            # color = (128, 128, 128)  # Blue for outside superpixels
            outside_labels.append(label)
        result[mask] = color

    # Count superpixels that intersect with the boundary
    boundary_intersecting_superpixels = np.unique(labels[boundary_mask])
    num_boundary_intersecting_superpixels = len(boundary_intersecting_superpixels)

    return result

# %%
def dice_coef_one_class(y_true, y_pred, smooth=1e-7):
    y_true_inside = K.cast(y_true == 1, 'float32')
    y_pred_inside = y_pred[..., 1]  # Assuming class 1 is the one inside the boundaries.

    intersection = K.sum(y_true_inside * y_pred_inside)
    denom = K.sum(y_true_inside) + K.sum(y_pred_inside)

    return (2. * intersection + smooth) / (denom + smooth)

# %%
def iou_one_class(y_true, y_pred, class_index=1, smooth=1):
    y_true_inside = K.cast(y_true == class_index, 'float32')
    y_pred_inside = y_pred[..., class_index]

    intersection = K.sum(y_true_inside * y_pred_inside)
    union = K.sum(y_true_inside) + K.sum(y_pred_inside) - intersection
    iou_score = (intersection + smooth) / (union + smooth)

    return iou_score

# %%
def precision_one_class(y_true, y_pred):
    y_true_inside = K.cast(y_true == 1, 'float32')
    y_pred_inside = y_pred[..., 1]  # Assuming class 1 is the one inside the boundaries.

    true_positives = K.sum(K.round(K.clip(y_true_inside * y_pred_inside, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred_inside, 0, 1)))
    
    precision = true_positives / (predicted_positives + K.epsilon())

    return precision

# %%
def sensitivity_one_class(gt_mask, pred_mask, class_index=1):
    gt_mask_class = K.cast(gt_mask == class_index, 'float32')
    pred_mask_class = pred_mask [..., 1]

    TP = K.sum(gt_mask_class * pred_mask_class)
    FN = K.sum(gt_mask_class * (1 - pred_mask_class))

    if TP + FN == 0:
        sensitivity_score = 0.0
    else:
        sensitivity_score = TP / (TP + FN)

    return sensitivity_score

# %%
def dice_loss(y_true, y_pred):
    return 1 - dice_coef_one_class(y_true, y_pred, smooth=1e-7)

# %%
batch_size = 8
threshold_value = 128
def data_generator(image_paths, mask_paths, batch_size):

    assert len(image_paths) == len(mask_paths), "Number of images and masks must be the same."

    num_samples = len(image_paths)
    print("Number of images:", num_samples)
    num_masks = len(mask_paths)
    print("Number of masks:", num_masks)

    while True:
        indices = np.arange(num_samples)
        np.random.shuffle(indices)

        for i in range(0, num_samples, batch_size):
            batch_indices = indices[i : i + batch_size]
            batch_images = []
            batch_masks = []

            for index in batch_indices:
                image_path = image_paths[index]
                mask_path = mask_paths[index]

                img = cv2.imread(image_path)
                img = cv2.resize(img, (128, 128))

                filename = os.path.join("/home/somayeh/PycharmProjects/superpixel_segmentation/"
                                        "newgt/newgt_superpixel_skin_slic800_2label", os.path.basename(mask_path))
                if not os.path.exists(filename):

                    mask = cv2.imread(mask_path,0)
                    mask = cv2.resize(mask, (128, 128))

                    result = create_superpixel_ground_truth(img, mask)
                    # result = ground_truth_superpixel_3(img, mask)

                    # result = cv2.cvtColor(result, cv2.COLOR_BGR2GRAY)
                    # plt.subplot(1, 2, 2)
                    # plt.imshow(result)
                    # plt.title("hggh")

                    # soft_label = binary_to_soft_label(result, threshold_value=threshold_value)
                    # cv2.imshow("kjkj",soft_label)
                    # cv2.waitKey(0)
                    # result = cv2.cvtColor(result, cv2.COLOR_BGR2GRAY)

                    cv2.imwrite(filename, result)

                else:
                    result = cv2.imread(filename, 0)
                # print(result.type)
                # img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                # soft_label = binary_to_soft_label(result)

                # normalize the image and mask to have values between 0 and 1
                # img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                img = img / 255.0
                result= result/ 255.0
                # result = result / 255.0
                # print(soft_label.shape)
                # cv2.imshow("dfg", soft_label)
                # cv2.waitKey(0)
                # Append the preprocessed data to the respective lists

                batch_images.append(img)
                batch_masks.append(result)

            # Yield the batch data
            batch_images = np.array(batch_images)
            batch_masks = np.array(batch_masks)

            # Visualize the images and masks in the batch
            # for j in range(batch_images.shape[0]):
            #     plt.subplot(1, 2, 1)
            #     plt.imshow(batch_images[j])
            #     plt.title("Image")
            #
            #     plt.subplot(1, 2, 2)
            #     plt.imshow(batch_masks[j])
            #     plt.title("Mask")
            #
            #     plt.show()

            yield batch_images, batch_masks


generator = data_generator(image_paths, mask_paths, 1)

for _,imgpath in tqdm(enumerate(image_paths)):
   batch = next(generator)
# Out:
# 0it [00:00, ?it/s]
# Number of images: 2594
# Number of masks: 2594
# 2594it [19:51,  2.18it/s]

# %%
mask_path_superpixel_label = glob.glob("/home/somayeh/PycharmProjects/superpixel_segmentation/newgt/newgt_superpixel_skin_slic800/*.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 mask_path_superpixel_label = glob.glob("/home/somayeh/PycharmProjects/superpixel_segmentation/newgt/newgt_superpixel_skin_slic800/*.png")
#
# NameError: name 'glob' is not defined

# %%
assert len(image_paths) == len(mask_path_superpixel_label), "Number of images and masks must be the same."
# Split the data into training and validation sets
train_image_paths, val_image_paths, train_mask_paths, val_mask_paths = train_test_split(
    image_paths, mask_path_superpixel_label, test_size=0.2, random_state=2023
)

# Define the batch size
batch_size = 8

# Create separate generators for training and validation sets
train_generator = data_generator(train_image_paths, train_mask_paths, batch_size)
val_generator = data_generator(val_image_paths, val_mask_paths, batch_size)

# batch_size = 5  # Number of batches to visualize

# for _ in range(batch_size):
#     batch = next(train_generator)

# Determine the number of steps per epoch for training and validation
train_steps_per_epoch = len(train_image_paths) // batch_size
val_steps_per_epoch = len(val_image_paths) // batch_size

print(train_steps_per_epoch)
print(val_steps_per_epoch)
# Out:
# 259
# 64

# %%
from keras.applications import MobileNetV2

IMAGE_SIZE = 128
# Function for conv2d_block (to be used for building decoder of unet)
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size), kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

# Function for unet model creation
def unet(n_filters = 16, batchnorm = True, dropout = 0.1, num_classes=3):

    # Contracting Path (encoder)
    inputs = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3), name="input_image")
    encoder = MobileNetV2(input_tensor=inputs, include_top=False)


    BASE_WEIGHT_PATH = ('https://github.com/fchollet/deep-learning-models/releases/download/v0.6/')
    model_name = 'mobilenet_%s_%d_tf_no_top.h5' % ('1_0', 224)
    weight_path = BASE_WEIGHT_PATH + model_name
    weights_path = tf.keras.utils.get_file(model_name, weight_path)


    encoder.load_weights(weights_path, by_name=True, skip_mismatch=True)

    skip_connection_names = ["input_image", "block_1_expand_relu", "block_3_expand_relu", "block_6_expand_relu"]
    encoder_output = encoder.get_layer("block_13_expand_relu").output

    x = encoder_output
    x_skip_1 = encoder.get_layer(skip_connection_names[-1]).output # 224x224
    x_skip_2 = encoder.get_layer(skip_connection_names[-2]).output # 112x112
    x_skip_3 = encoder.get_layer(skip_connection_names[-3]).output # 56x56
    x_skip_4 = encoder.get_layer(skip_connection_names[-4]).output # 28x28


    # Expansive Path (decoder)
    u6 = Conv2DTranspose(n_filters * 13, (3, 3), strides = (2, 2), padding = 'same')(x)
    u6 = concatenate([u6, x_skip_1])
    c6 = conv2d_block(u6, n_filters * 13, kernel_size = 3, batchnorm = batchnorm)
    p6 = Dropout(dropout)(c6)

    u7 = Conv2DTranspose(n_filters * 12, (3, 3), strides = (2, 2), padding = 'same')(c6)
    u7 = concatenate([u7, x_skip_2])
    c7 = conv2d_block(u7, n_filters * 12, kernel_size = 3, batchnorm = batchnorm)
    p7 = Dropout(dropout)(c7)

    u8 = Conv2DTranspose(n_filters * 11, (3, 3), strides = (2, 2), padding = 'same')(p7)
    u8 = concatenate([u8, x_skip_3])
    c8 = conv2d_block(u8, n_filters * 11, kernel_size = 3, batchnorm = batchnorm)
    p7 = Dropout(dropout)(c8)

    u9 = Conv2DTranspose(n_filters * 10, (3, 3), strides = (2, 2), padding = 'same')(c8)
    u9 = concatenate([u9, x_skip_4])
    c9 = conv2d_block(u9, n_filters * 10, kernel_size = 3, batchnorm = batchnorm)
    
    outputs = Conv2D(num_classes, (1, 1), activation='softmax')(c9)

    model = Model(inputs=inputs, outputs=outputs)
    
    return model

# %%
# !rm -rf '/home/somayeh/PycharmProjects/superpixel_segmentation/tensor_board'

# %%
# %load_ext tensorboard
log_folder = '/home/somayeh/PycharmProjects/superpixel_segmentation/tensor_board'

# %%
weight_path="{}_Unet_superpixel_skin_slic800.best.hdf5".format('cxr_reg')


checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1,
                             save_best_only=True, mode='min', save_weights_only = True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                                   patience=3,
                                   verbose=1, mode='min', epsilon=0.0001, cooldown=2, min_lr=1e-5)
early = EarlyStopping(monitor="val_loss",
                      mode="min",
                      patience=10) # probably needs to be more patient, but kaggle time is limited

tbcallback = TensorBoard(log_dir=log_folder,
                         histogram_freq=1,
                         write_graph=True,
                         write_images=True,
                         update_freq='epoch',
                         profile_batch=2,
                         embeddings_freq=1)

callbacks_list = [checkpoint, early, reduceLROnPlat, tbcallback]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 weight_path="{}_Unet_superpixel_skin_slic800.best.hdf5".format('cxr_reg')
# ----> 4 checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1,
#       5                              save_best_only=True, mode='min', save_weights_only = True)
#       7 reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.5,
#       8                                    patience=3,
#       9                                    verbose=1, mode='min', epsilon=0.0001, cooldown=2, min_lr=1e-5)
#      10 early = EarlyStopping(monitor="val_loss",
#      11                       mode="min",
#      12                       patience=10) # probably needs to be more patient, but kaggle time is limited
#
# NameError: name 'ModelCheckpoint' is not defined

# %%
model =unet(n_filters = 8, batchnorm = True, dropout = 0.1, num_classes=3)
opt = tf.keras.optimizers.experimental.AdamW(learning_rate=0.0001)
model.compile(optimizer=opt, loss=dice_loss, metrics= [dice_coef_one_class, precision_one_class, sensitivity_one_class, iou_one_class],  run_eagerly=True)
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model =unet(n_filters = 8, batchnorm = True, dropout = 0.1, num_classes=3)
#       2 opt = tf.keras.optimizers.experimental.AdamW(learning_rate=0.0001)
#       3 model.compile(optimizer=opt, loss=dice_loss, metrics= [dice_coef_one_class, precision_one_class, sensitivity_one_class, iou_one_class],  run_eagerly=True)
#
# NameError: name 'unet' is not defined

# %%
loss_history = model.fit_generator(
    train_generator,
    steps_per_epoch=train_steps_per_epoch,
    validation_data=val_generator,
    validation_steps=val_steps_per_epoch,
    epochs=50,
    callbacks =callbacks_list
)

model.save("unet_super_pixel_skin_slic800.h5")
# Out:
# /tmp/ipykernel_13330/4057172441.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   loss_history = model.fit_generator(
# Number of images: 2075
# Number of masks: 2075
# Epoch 1/50
# 2023-10-27 19:46:53.239801: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8902
# 2023-10-27 19:46:54.904990: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:46:54.908524: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:234] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.6
# 2023-10-27 19:46:54.908561: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:237] Used ptxas at ptxas
# 2023-10-27 19:46:54.908700: W tensorflow/compiler/xla/stream_executor/gpu/redzone_allocator.cc:318] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2023-10-27 19:46:55.159828: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-10-27 19:46:56.003823: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.21GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-27 19:46:56.004254: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.21GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-27 19:46:56.208350: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.61GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-27 19:46:56.208454: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.61GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-27 19:46:56.719699: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.60GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-27 19:46:56.719824: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.60GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-27 19:46:56.902791: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-27 19:46:56.902907: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-27 19:46:57.096670: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.11GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-27 19:46:57.096768: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.11GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-27 19:46:58.448726: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x83fd97c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-27 19:46:58.448799: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6
# 2023-10-27 19:46:58.461812: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-27 19:46:58.675602: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:46:58.681636: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-10-27 19:46:58.980660: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:46:59.543534: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7f83e84b25e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7f83e84b25e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2023-10-27 19:47:00.398707: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:00.752837: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:01.333328: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:01.683635: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:03.602718: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:03.952267: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:04.524051: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:04.866105: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:05.458753: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:08.896076: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:09.659502: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:09.923350: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:10.472094: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:16.202995: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:16.991087: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:26.253502: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:26.781023: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:31.450642: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:31.722305: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:32.009576: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:33.070776: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:33.640512: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:34.704405: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:34.978601: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:35.264160: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:36.397730: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:36.700639: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:36.976474: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:38.035310: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-27 19:47:38.305781: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
#   1/259 [..............................] - ETA: 3:26:28 - loss: 0.8504 - dice_coef_one_class: 0.1496 - precision_one_class: 0.1222 - sensitivity_one_class: 0.3798 - iou_one_class: 0.0809
# 2023-10-27 19:47:38.750353: I tensorflow/core/profiler/lib/profiler_session.cc:101] Profiler session initializing.
# 2023-10-27 19:47:38.750412: I tensorflow/core/profiler/lib/profiler_session.cc:116] Profiler session started.
# 2023-10-27 19:47:40.846898: I tensorflow/core/profiler/lib/profiler_session.cc:67] Profiler session collecting data.
# 2023-10-27 19:47:40.906902: I tensorflow/core/profiler/backends/gpu/cupti_tracer.cc:1798] CUPTI activity buffer flushed
# 2023-10-27 19:47:41.023443: I tensorflow/core/profiler/backends/gpu/cupti_collector.cc:522]  GpuTracer has collected 1671 callback api events and 1768 activity events.
#   2/259 [..............................] - ETA: 10:02 - loss: 0.7718 - dice_coef_one_class: 0.2282 - precision_one_class: 0.2199 - sensitivity_one_class: 0.3860 - iou_one_class: 0.1310
# 2023-10-27 19:47:41.062373: I tensorflow/core/profiler/lib/profiler_session.cc:128] Profiler session tear down.
# 2023-10-27 19:47:41.065191: I tensorflow/core/profiler/rpc/client/save_profile.cc:164] Collecting XSpace to repository: /home/somayeh/PycharmProjects/superpixel_segmentation/tensor_board/plugins/profile/2023_10_27_19_47_41/somayeh-ASUS-TUF-Gaming-F15-FX506HCB-FX506HCB.xplane.pb
# 259/259 [==============================] - ETA: 0s - loss: 0.2887 - dice_coef_one_class: 0.7113 - precision_one_class: 0.7368 - sensitivity_one_class: 0.7871 - iou_one_class: 0.5732Number of images: 519
# Number of masks: 519
#
# Epoch 1: val_loss improved from inf to 0.40010, saving model to cxr_reg_Unet_superpixel_skin_slic800.best.hdf5
# 259/259 [==============================] - 832s 3s/step - loss: 0.2887 - dice_coef_one_class: 0.7113 - precision_one_class: 0.7368 - sensitivity_one_class: 0.7871 - iou_one_class: 0.5732 - val_loss: 0.4001 - val_dice_coef_one_class: 0.5999 - val_precision_one_class: 0.9675 - val_sensitivity_one_class: 0.4579 - val_iou_one_class: 0.4438 - lr: 1.0000e-04
# Epoch 2/50
# 259/259 [==============================] - ETA: 0s - loss: 0.1861 - dice_coef_one_class: 0.8138 - precision_one_class: 0.8372 - sensitivity_one_class: 0.8334 - iou_one_class: 0.6943
# Epoch 2: val_loss did not improve from 0.40010
# 259/259 [==============================] - 733s 3s/step - loss: 0.1861 - dice_coef_one_class: 0.8138 - precision_one_class: 0.8372 - sensitivity_one_class: 0.8334 - iou_one_class: 0.6943 - val_loss: 0.4694 - val_dice_coef_one_class: 0.5306 - val_precision_one_class: 0.9873 - val_sensitivity_one_class: 0.3789 - val_iou_one_class: 0.3753 - lr: 1.0000e-04
# Epoch 3/50
# 259/259 [==============================] - ETA: 0s - loss: 0.1588 - dice_coef_one_class: 0.8413 - precision_one_class: 0.8644 - sensitivity_one_class: 0.8509 - iou_one_class: 0.7325
# Epoch 3: val_loss improved from 0.40010 to 0.36307, saving model to cxr_reg_Unet_superpixel_skin_slic800.best.hdf5
# 259/259 [==============================] - 738s 3s/step - loss: 0.1588 - dice_coef_one_class: 0.8413 - precision_one_class: 0.8644 - sensitivity_one_class: 0.8509 - iou_one_class: 0.7325 - val_loss: 0.3631 - val_dice_coef_one_class: 0.6369 - val_precision_one_class: 0.9768 - val_sensitivity_one_class: 0.4919 - val_iou_one_class: 0.4837 - lr: 1.0000e-04
# Epoch 4/50
# 259/259 [==============================] - ETA: 0s - loss: 0.1461 - dice_coef_one_class: 0.8541 - precision_one_class: 0.8665 - sensitivity_one_class: 0.8694 - iou_one_class: 0.7508
# Epoch 4: val_loss improved from 0.36307 to 0.24085, saving model to cxr_reg_Unet_superpixel_skin_slic800.best.hdf5
# 259/259 [==============================] - 732s 3s/step - loss: 0.1461 - dice_coef_one_class: 0.8541 - precision_one_class: 0.8665 - sensitivity_one_class: 0.8694 - iou_one_class: 0.7508 - val_loss: 0.2408 - val_dice_coef_one_class: 0.7592 - val_precision_one_class: 0.9569 - val_sensitivity_one_class: 0.6493 - val_iou_one_class: 0.6246 - lr: 1.0000e-04
# Epoch 5/50
# 259/259 [==============================] - ETA: 0s - loss: 0.1351 - dice_coef_one_class: 0.8649 - precision_one_class: 0.8769 - sensitivity_one_class: 0.8752 - iou_one_class: 0.7662
# Epoch 5: val_loss improved from 0.24085 to 0.19699, saving model to cxr_reg_Unet_superpixel_skin_slic800.best.hdf5
# 259/259 [==============================] - 1273s 5s/step - loss: 0.1351 - dice_coef_one_class: 0.8649 - precision_one_class: 0.8769 - sensitivity_one_class: 0.8752 - iou_one_class: 0.7662 - val_loss: 0.1970 - val_dice_coef_one_class: 0.8030 - val_precision_one_class: 0.9163 - val_sensitivity_one_class: 0.7308 - val_iou_one_class: 0.6777 - lr: 1.0000e-04
# Epoch 6/50
# 259/259 [==============================] - ETA: 0s - loss: 0.1195 - dice_coef_one_class: 0.8802 - precision_one_class: 0.8908 - sensitivity_one_class: 0.8853 - iou_one_class: 0.7891
# Epoch 6: val_loss improved from 0.19699 to 0.15272, saving model to cxr_reg_Unet_superpixel_skin_slic800.best.hdf5
# 259/259 [==============================] - 2111s 8s/step - loss: 0.1195 - dice_coef_one_class: 0.8802 - precision_one_class: 0.8908 - sensitivity_one_class: 0.8853 - iou_one_class: 0.7891 - val_loss: 0.1527 - val_dice_coef_one_class: 0.8473 - val_precision_one_class: 0.8949 - val_sensitivity_one_class: 0.8163 - val_iou_one_class: 0.7384 - lr: 1.0000e-04
# Epoch 7/50
# 259/259 [==============================] - ETA: 0s - loss: 0.1143 - dice_coef_one_class: 0.8856 - precision_one_class: 0.8940 - sensitivity_one_class: 0.8917 - iou_one_class: 0.7978
# Epoch 7: val_loss improved from 0.15272 to 0.15040, saving model to cxr_reg_Unet_superpixel_skin_slic800.best.hdf5
# 259/259 [==============================] - 751s 3s/step - loss: 0.1143 - dice_coef_one_class: 0.8856 - precision_one_class: 0.8940 - sensitivity_one_class: 0.8917 - iou_one_class: 0.7978 - val_loss: 0.1504 - val_dice_coef_one_class: 0.8496 - val_precision_one_class: 0.9071 - val_sensitivity_one_class: 0.8095 - val_iou_one_class: 0.7433 - lr: 1.0000e-04
# Epoch 8/50
# 259/259 [==============================] - ETA: 0s - loss: 0.1043 - dice_coef_one_class: 0.8955 - precision_one_class: 0.9003 - sensitivity_one_class: 0.9015 - iou_one_class: 0.8129
# Epoch 8: val_loss did not improve from 0.15040
# 259/259 [==============================] - 741s 3s/step - loss: 0.1043 - dice_coef_one_class: 0.8955 - precision_one_class: 0.9003 - sensitivity_one_class: 0.9015 - iou_one_class: 0.8129 - val_loss: 0.1532 - val_dice_coef_one_class: 0.8468 - val_precision_one_class: 0.9175 - val_sensitivity_one_class: 0.7974 - val_iou_one_class: 0.7391 - lr: 1.0000e-04
# Epoch 9/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0968 - dice_coef_one_class: 0.9031 - precision_one_class: 0.9061 - sensitivity_one_class: 0.9082 - iou_one_class: 0.8249
# Epoch 9: val_loss improved from 0.15040 to 0.14046, saving model to cxr_reg_Unet_superpixel_skin_slic800.best.hdf5
# 259/259 [==============================] - 769s 3s/step - loss: 0.0968 - dice_coef_one_class: 0.9031 - precision_one_class: 0.9061 - sensitivity_one_class: 0.9082 - iou_one_class: 0.8249 - val_loss: 0.1405 - val_dice_coef_one_class: 0.8595 - val_precision_one_class: 0.8941 - val_sensitivity_one_class: 0.8376 - val_iou_one_class: 0.7574 - lr: 1.0000e-04
# Epoch 10/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0913 - dice_coef_one_class: 0.9086 - precision_one_class: 0.9108 - sensitivity_one_class: 0.9134 - iou_one_class: 0.8339
# Epoch 10: val_loss did not improve from 0.14046
# 259/259 [==============================] - 799s 3s/step - loss: 0.0913 - dice_coef_one_class: 0.9086 - precision_one_class: 0.9108 - sensitivity_one_class: 0.9134 - iou_one_class: 0.8339 - val_loss: 0.1432 - val_dice_coef_one_class: 0.8568 - val_precision_one_class: 0.9043 - val_sensitivity_one_class: 0.8219 - val_iou_one_class: 0.7533 - lr: 1.0000e-04
# Epoch 11/50
#  65/259 [======>.......................] - ETA: 8:06 - loss: 0.0894 - dice_coef_one_class: 0.9097 - precision_one_class: 0.9146 - sensitivity_one_class: 0.9134 - iou_one_class: 0.8367
# Epoch 11: val_loss improved from 0.14046 to 0.13976, saving model to cxr_reg_Unet_superpixel_skin_slic800.best.hdf5
# 259/259 [==============================] - 778s 3s/step - loss: 0.0913 - dice_coef_one_class: 0.9084 - precision_one_class: 0.9106 - sensitivity_one_class: 0.9151 - iou_one_class: 0.8354 - val_loss: 0.1398 - val_dice_coef_one_class: 0.8602 - val_precision_one_class: 0.8984 - val_sensitivity_one_class: 0.8353 - val_iou_one_class: 0.7599 - lr: 1.0000e-04
# Epoch 12/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0818 - dice_coef_one_class: 0.9178 - precision_one_class: 0.9168 - sensitivity_one_class: 0.9249 - iou_one_class: 0.8498
# Epoch 12: val_loss did not improve from 0.13976
# 259/259 [==============================] - 771s 3s/step - loss: 0.0818 - dice_coef_one_class: 0.9178 - precision_one_class: 0.9168 - sensitivity_one_class: 0.9249 - iou_one_class: 0.8498 - val_loss: 0.1492 - val_dice_coef_one_class: 0.8508 - val_precision_one_class: 0.9127 - val_sensitivity_one_class: 0.8078 - val_iou_one_class: 0.7461 - lr: 1.0000e-04
# Epoch 13/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0805 - dice_coef_one_class: 0.9195 - precision_one_class: 0.9203 - sensitivity_one_class: 0.9246 - iou_one_class: 0.8526
# Epoch 13: val_loss did not improve from 0.13976
# 259/259 [==============================] - 1053s 4s/step - loss: 0.0805 - dice_coef_one_class: 0.9195 - precision_one_class: 0.9203 - sensitivity_one_class: 0.9246 - iou_one_class: 0.8526 - val_loss: 0.1411 - val_dice_coef_one_class: 0.8589 - val_precision_one_class: 0.9051 - val_sensitivity_one_class: 0.8243 - val_iou_one_class: 0.7589 - lr: 1.0000e-04
# Epoch 14/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0785 - dice_coef_one_class: 0.9215 - precision_one_class: 0.9221 - sensitivity_one_class: 0.9260 - iou_one_class: 0.8559
# Epoch 14: val_loss did not improve from 0.13976
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 259/259 [==============================] - 2501s 10s/step - loss: 0.0785 - dice_coef_one_class: 0.9215 - precision_one_class: 0.9221 - sensitivity_one_class: 0.9260 - iou_one_class: 0.8559 - val_loss: 0.1407 - val_dice_coef_one_class: 0.8593 - val_precision_one_class: 0.8573 - val_sensitivity_one_class: 0.8742 - val_iou_one_class: 0.7584 - lr: 1.0000e-04
# Epoch 15/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0739 - dice_coef_one_class: 0.9260 - precision_one_class: 0.9252 - sensitivity_one_class: 0.9312 - iou_one_class: 0.8636
# Epoch 15: val_loss did not improve from 0.13976
# 259/259 [==============================] - 887s 3s/step - loss: 0.0739 - dice_coef_one_class: 0.9260 - precision_one_class: 0.9252 - sensitivity_one_class: 0.9312 - iou_one_class: 0.8636 - val_loss: 0.1403 - val_dice_coef_one_class: 0.8597 - val_precision_one_class: 0.8658 - val_sensitivity_one_class: 0.8621 - val_iou_one_class: 0.7595 - lr: 5.0000e-05
# Epoch 16/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0720 - dice_coef_one_class: 0.9281 - precision_one_class: 0.9273 - sensitivity_one_class: 0.9332 - iou_one_class: 0.8673
# Epoch 16: val_loss improved from 0.13976 to 0.13898, saving model to cxr_reg_Unet_superpixel_skin_slic800.best.hdf5
# 259/259 [==============================] - 853s 3s/step - loss: 0.0720 - dice_coef_one_class: 0.9281 - precision_one_class: 0.9273 - sensitivity_one_class: 0.9332 - iou_one_class: 0.8673 - val_loss: 0.1390 - val_dice_coef_one_class: 0.8610 - val_precision_one_class: 0.8692 - val_sensitivity_one_class: 0.8667 - val_iou_one_class: 0.7609 - lr: 5.0000e-05
# Epoch 17/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0693 - dice_coef_one_class: 0.9306 - precision_one_class: 0.9299 - sensitivity_one_class: 0.9350 - iou_one_class: 0.8714
# Epoch 17: val_loss improved from 0.13898 to 0.13405, saving model to cxr_reg_Unet_superpixel_skin_slic800.best.hdf5
# 259/259 [==============================] - 827s 3s/step - loss: 0.0693 - dice_coef_one_class: 0.9306 - precision_one_class: 0.9299 - sensitivity_one_class: 0.9350 - iou_one_class: 0.8714 - val_loss: 0.1341 - val_dice_coef_one_class: 0.8659 - val_precision_one_class: 0.8607 - val_sensitivity_one_class: 0.8817 - val_iou_one_class: 0.7676 - lr: 5.0000e-05
# Epoch 18/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0667 - dice_coef_one_class: 0.9333 - precision_one_class: 0.9319 - sensitivity_one_class: 0.9380 - iou_one_class: 0.8758
# Epoch 18: val_loss did not improve from 0.13405
# 259/259 [==============================] - 873s 3s/step - loss: 0.0667 - dice_coef_one_class: 0.9333 - precision_one_class: 0.9319 - sensitivity_one_class: 0.9380 - iou_one_class: 0.8758 - val_loss: 0.1514 - val_dice_coef_one_class: 0.8486 - val_precision_one_class: 0.9079 - val_sensitivity_one_class: 0.8076 - val_iou_one_class: 0.7452 - lr: 5.0000e-05
# Epoch 19/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0632 - dice_coef_one_class: 0.9369 - precision_one_class: 0.9362 - sensitivity_one_class: 0.9402 - iou_one_class: 0.8821
# Epoch 19: val_loss did not improve from 0.13405
# 259/259 [==============================] - 870s 3s/step - loss: 0.0632 - dice_coef_one_class: 0.9369 - precision_one_class: 0.9362 - sensitivity_one_class: 0.9402 - iou_one_class: 0.8821 - val_loss: 0.1398 - val_dice_coef_one_class: 0.8602 - val_precision_one_class: 0.8851 - val_sensitivity_one_class: 0.8461 - val_iou_one_class: 0.7593 - lr: 5.0000e-05
# Epoch 20/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0637 - dice_coef_one_class: 0.9363 - precision_one_class: 0.9347 - sensitivity_one_class: 0.9407 - iou_one_class: 0.8809
# Epoch 20: val_loss did not improve from 0.13405
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 259/259 [==============================] - 844s 3s/step - loss: 0.0637 - dice_coef_one_class: 0.9363 - precision_one_class: 0.9347 - sensitivity_one_class: 0.9407 - iou_one_class: 0.8809 - val_loss: 0.1360 - val_dice_coef_one_class: 0.8640 - val_precision_one_class: 0.8650 - val_sensitivity_one_class: 0.8718 - val_iou_one_class: 0.7645 - lr: 5.0000e-05
# Epoch 21/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0602 - dice_coef_one_class: 0.9397 - precision_one_class: 0.9382 - sensitivity_one_class: 0.9436 - iou_one_class: 0.8869
# Epoch 21: val_loss did not improve from 0.13405
# 259/259 [==============================] - 812s 3s/step - loss: 0.0602 - dice_coef_one_class: 0.9397 - precision_one_class: 0.9382 - sensitivity_one_class: 0.9436 - iou_one_class: 0.8869 - val_loss: 0.1425 - val_dice_coef_one_class: 0.8575 - val_precision_one_class: 0.8838 - val_sensitivity_one_class: 0.8470 - val_iou_one_class: 0.7578 - lr: 2.5000e-05
# Epoch 22/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0604 - dice_coef_one_class: 0.9397 - precision_one_class: 0.9383 - sensitivity_one_class: 0.9435 - iou_one_class: 0.8869
# Epoch 22: val_loss did not improve from 0.13405
# 259/259 [==============================] - 878s 3s/step - loss: 0.0604 - dice_coef_one_class: 0.9397 - precision_one_class: 0.9383 - sensitivity_one_class: 0.9435 - iou_one_class: 0.8869 - val_loss: 0.1349 - val_dice_coef_one_class: 0.8651 - val_precision_one_class: 0.8783 - val_sensitivity_one_class: 0.8632 - val_iou_one_class: 0.7661 - lr: 2.5000e-05
# Epoch 23/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0629 - dice_coef_one_class: 0.9371 - precision_one_class: 0.9344 - sensitivity_one_class: 0.9439 - iou_one_class: 0.8836
# Epoch 23: val_loss did not improve from 0.13405
# 259/259 [==============================] - 843s 3s/step - loss: 0.0629 - dice_coef_one_class: 0.9371 - precision_one_class: 0.9344 - sensitivity_one_class: 0.9439 - iou_one_class: 0.8836 - val_loss: 0.1414 - val_dice_coef_one_class: 0.8586 - val_precision_one_class: 0.8744 - val_sensitivity_one_class: 0.8532 - val_iou_one_class: 0.7576 - lr: 2.5000e-05
# Epoch 24/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0576 - dice_coef_one_class: 0.9420 - precision_one_class: 0.9407 - sensitivity_one_class: 0.9459 - iou_one_class: 0.8912
# Epoch 24: val_loss did not improve from 0.13405
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 259/259 [==============================] - 817s 3s/step - loss: 0.0576 - dice_coef_one_class: 0.9420 - precision_one_class: 0.9407 - sensitivity_one_class: 0.9459 - iou_one_class: 0.8912 - val_loss: 0.1357 - val_dice_coef_one_class: 0.8643 - val_precision_one_class: 0.8894 - val_sensitivity_one_class: 0.8508 - val_iou_one_class: 0.7652 - lr: 2.5000e-05
# Epoch 25/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0574 - dice_coef_one_class: 0.9405 - precision_one_class: 0.9386 - sensitivity_one_class: 0.9480 - iou_one_class: 0.8909
# Epoch 25: val_loss did not improve from 0.13405
# 259/259 [==============================] - 751s 3s/step - loss: 0.0574 - dice_coef_one_class: 0.9405 - precision_one_class: 0.9386 - sensitivity_one_class: 0.9480 - iou_one_class: 0.8909 - val_loss: 0.1365 - val_dice_coef_one_class: 0.8635 - val_precision_one_class: 0.8992 - val_sensitivity_one_class: 0.8394 - val_iou_one_class: 0.7629 - lr: 1.2500e-05
# Epoch 26/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0575 - dice_coef_one_class: 0.9424 - precision_one_class: 0.9412 - sensitivity_one_class: 0.9461 - iou_one_class: 0.8920
# Epoch 26: val_loss did not improve from 0.13405
# 259/259 [==============================] - 866s 3s/step - loss: 0.0575 - dice_coef_one_class: 0.9424 - precision_one_class: 0.9412 - sensitivity_one_class: 0.9461 - iou_one_class: 0.8920 - val_loss: 0.1406 - val_dice_coef_one_class: 0.8594 - val_precision_one_class: 0.8864 - val_sensitivity_one_class: 0.8464 - val_iou_one_class: 0.7584 - lr: 1.2500e-05
# Epoch 27/50
# 259/259 [==============================] - ETA: 0s - loss: 0.0563 - dice_coef_one_class: 0.9437 - precision_one_class: 0.9416 - sensitivity_one_class: 0.9485 - iou_one_class: 0.8944
# Epoch 27: val_loss did not improve from 0.13405
# 259/259 [==============================] - 881s 3s/step - loss: 0.0563 - dice_coef_one_class: 0.9437 - precision_one_class: 0.9416 - sensitivity_one_class: 0.9485 - iou_one_class: 0.8944 - val_loss: 0.1483 - val_dice_coef_one_class: 0.8517 - val_precision_one_class: 0.9028 - val_sensitivity_one_class: 0.8157 - val_iou_one_class: 0.7466 - lr: 1.2500e-05

# %%
test_images = []
ground_truth_test_images = []

# define the paths to the images and their ground truths
test_paths = glob.glob('/home/somayeh/PycharmProjects/superpixel_segmentation/ISIC2018_SKIN_DATA/ISIC2018_Task1-2_Test_Input/*.png')
test_mask_paths = glob.glob("/home/somayeh/PycharmProjects/superpixel_segmentation/ISIC2018_SKIN_DATA/ISIC2018_Task1_Test_GroundTruth/*.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       2 ground_truth_test_images = []
#       4 # define the paths to the images and their ground truths
# ----> 5 test_paths = glob.glob('/home/somayeh/PycharmProjects/superpixel_segmentation/ISIC2018_SKIN_DATA/ISIC2018_Task1-2_Test_Input/*.png')
#       6 test_mask_paths = glob.glob("/home/somayeh/PycharmProjects/superpixel_segmentation/ISIC2018_SKIN_DATA/ISIC2018_Task1_Test_GroundTruth/*.png")
#
# NameError: name 'glob' is not defined

# %%
model.load_weights("{}_Unet_superpixel_skin_slic800.best.hdf5".format('cxr_reg'))
import random
dice_scores = []
import matplotlib.colors as mcolors

for test_path, test_mask_path in zip(test_paths, test_mask_paths):
    # read the image and mask using OpenCV
    test_image = cv2.imread(test_path)
    ground_truth_test_image = cv2.imread(test_mask_path, 0)  # read the mask as grayscale

    # resize the image and mask to the desired dimensions
    test_image = cv2.resize(test_image, (128, 128))
    ground_truth_test_image = cv2.resize(ground_truth_test_image, (128, 128))

    # normalize the image and mask to have values between 0 and 1
    test_image = test_image / 255.0
    ground_truth_test_image = ground_truth_test_image / 255.0

    # add the image and mask to the corresponding arrays
    test_images.append(test_image)
    ground_truth_test_images.append(ground_truth_test_image)

# Convert the images and masks to numpy arrays
test_images = np.array(test_images)
ground_truth_test_images = np.array(ground_truth_test_images)

model.load_weights("{}_Unet_superpixel_skin_slic800.best.hdf5".format('cxr_reg'))

# Make predictions
predicted_masks = model.predict(test_images)

threshold = 0.6  # You can adjust this threshold as needed

# Create an empty list to store the binary masks
binary_masks = []

# Convert the predicted masks to grayscale
# grayscale_mask = np.mean(predicted_masks, axis=-1)

# Apply the threshold to each predicted mask
for i in range(len(predicted_masks)):
    binary_mask = (predicted_masks[i] > threshold).astype(np.uint8)
    binary_masks.append(binary_mask)

# Convert the list of binary masks to a numpy array
binary_masks = np.array(binary_masks)


print("predicted mask grayscale shape:",binary_masks.shape)  # Shape after conversion

print("predicted mask shape:", predicted_masks.shape)
print("test images shape :", test_images.shape)
print ("ground truth test images shape:", ground_truth_test_images.shape)

dice_scores = []  # List to store the dice coefficients
precision_scores = []
sensitivity_scores = []
iou_scores = []

# Iterate over the images and calculate the dice coefficient
for i in range(len(ground_truth_test_images)):
    y_true = ground_truth_test_images[i]
    y_pred = predicted_masks[i]

    dice = dice_coef_one_class(y_true, y_pred)
    dice_scores.append(dice)

# Compute the average dice coefficient
average_dice = np.mean(dice_scores)


for i in range(len(ground_truth_test_images)):
    y_true = ground_truth_test_images[i]
    y_pred = predicted_masks[i]

    precision_value = precision_one_class(y_true, y_pred)
    precision_scores.append(precision_value)

# Compute the average dice coefficient
average_precision = np.mean(precision_scores)

for i in range(len(ground_truth_test_images)):
    y_true = ground_truth_test_images[i]
    y_pred = predicted_masks[i]

    sensitivity_value = sensitivity_one_class(y_true, y_pred)
    sensitivity_scores.append(sensitivity_value)

# Compute the average dice coefficient
average_sensitivity = np.mean(sensitivity_scores)

for i in range(len(ground_truth_test_images)):
    y_true = ground_truth_test_images[i]
    y_pred = predicted_masks[i]

    iou_value = iou_one_class(y_true, y_pred)
    iou_scores.append(iou_value)

# Compute the average dice coefficient
average_iou = np.mean(iou_scores)

print("Dices:", dice_scores)
print("Dice coefficient:", average_dice)
print("Precision:", average_precision)
print("Sensitivity:", average_sensitivity)
print("IoU:", average_iou)


# Define a custom colormap
cmap_binary = mcolors.ListedColormap(['white', 'black'])  # 'black' for foreground, 'white' for background
n = 15
# Visualize the results for a subset of images

for i in range(n):

    fig, ax = plt.subplots(1, 3, figsize=(10, 5))
    ax[0].imshow(test_images[i])
    ax[0].set_title('Original Image')
    ax[1].imshow(ground_truth_test_images[i], cmap='gray')
    ax[1].set_title('Original Mask')
    # ax[2].imshow(predicted_masks[i], cmap="gray")
    # ax[2].set_title('Predicted Mask')
    ax[2].imshow(binary_masks[i], cmap="gray")
    ax[2].set_title('Predicted Mask binary')
    plt.show()
# Out:
# 2023-10-31 14:59:36.475889: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8902
# 2023-10-31 14:59:37.239174: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-10-31 14:59:37.240213: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:234] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.6
# 2023-10-31 14:59:37.240223: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:237] Used ptxas at ptxas
# 2023-10-31 14:59:37.240285: W tensorflow/compiler/xla/stream_executor/gpu/redzone_allocator.cc:318] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2023-10-31 14:59:37.273784: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-10-31 14:59:37.962546: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.75GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-31 14:59:37.963034: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.75GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
#  2/32 [>.............................] - ETA: 1s
# 2023-10-31 14:59:38.242718: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.47GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-31 14:59:38.242766: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.47GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 32/32 [==============================] - 6s 101ms/step
# 2023-10-31 14:59:41.277100: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.21GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-31 14:59:41.277129: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.21GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-31 14:59:41.407239: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.61GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-10-31 14:59:41.407268: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.61GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# predicted mask grayscale shape: (1000, 128, 128, 3)
# predicted mask shape: (1000, 128, 128, 3)
# test images shape : (1000, 128, 128, 3)
# ground truth test images shape: (1000, 128, 128)
# Dices: [<tf.Tensor: shape=(), dtype=float32, numpy=0.886182>, <tf.Tensor: shape=(), dtype=float32, numpy=0.7408148>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8837579>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8710052>, <tf.Tensor: shape=(), dtype=float32, numpy=0.77155864>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8081504>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8351669>, <tf.Tensor: shape=(), dtype=float32, numpy=0.843555>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8287002>, <tf.Tensor: shape=(), dtype=float32, numpy=0.85809463>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9354639>, <tf.Tensor: shape=(), dtype=float32, numpy=0.82858175>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9420954>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8904706>, <tf.Tensor: shape=(), dtype=float32, numpy=0.85635674>, <tf.Tensor: shape=(), dtype=float32, numpy=0.6748027>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9665005>, <tf.Tensor: shape=(), dtype=float32, numpy=0.87403387>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9712406>, <tf.Tensor: shape=(), dtype=float32, numpy=0.94669116>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9241495>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8061177>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9239584>, <tf.Tensor: shape=(), dtype=float32, numpy=0.77239865>, <tf.Tensor: shape=(), dtype=float32, numpy=0.921008>, <tf.Tensor: shape=(), dtype=float32, numpy=0.76073253>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8087949>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8941396>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8493732>, <tf.Tensor: shape=(), dtype=float32, numpy=0.93317807>, <tf.Tensor: shape=(), dtype=float32, numpy=0.82000726>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9282714>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9025296>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9267288>, <tf.Tensor: shape=(), dtype=float32, numpy=0.79466915>, <tf.Tensor: shape=(), dtype=float32, numpy=0.83584315>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9494405>, <tf.Tensor: shape=(), dtype=float32, numpy=0.88897836>, <tf.Tensor: shape=(), dtype=float32, numpy=0.810894>, <tf.Tensor: shape=(), dtype=float32, numpy=0.40855575>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9415698>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9645725>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9729491>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9569437>, <tf.Tensor: shape=(), dtype=float32, numpy=0.87190634>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8719462>, <tf.Tensor: shape=(), dtype=float32, numpy=0.7396971>, <tf.Tensor: shape=(), dtype=float32, numpy=0.87287945>, <tf.Tensor: shape=(), dtype=float32, numpy=0.6681878>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9046178>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9050058>, <tf.Tensor: shape=(), dtype=float32, numpy=0.84905726>, <tf.Tensor: shape=(), dtype=float32, numpy=0.97883296>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9095019>, <tf.Tensor: shape=(), dtype=float32, numpy=0.78124404>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9713862>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9684627>, <tf.Tensor: shape=(), dtype=float32, numpy=0.9000836>, <tf.Tensor: shape=(), dtype=float32, numpy=0.3172622>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8385305>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8363022>, <tf.Tensor: shape=(), dtype=float32, numpy=0.88752884>, <tf.Tensor: shape=(), dtype=float32, numpy=0.34150085>, <tf.Tensor: shape=(), dtype=float32, numpy=0.86299133>, <tf.Tensor: shape=(), dtype=float32, numpy=0.955822>, <tf.Tensor: shape=(), dtype=float32, numpy=0.7358595>, <tf.Tensor: shape=(), dtype=float32, numpy=0.639734>, <tf.Tensor: shape=(), dtype=float32, numpy=0.7589803>, <tf.Tensor: shape=(), dtype=float32, numpy=0.19542694>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8988284>, <tf.Tensor: shape=(), dtype=float32, numpy=0.7384901>, <tf.Tensor: shape=(), dtype=float32, numpy=0.8337533>, <tf.Tensor: sha ...
# Dice coefficient: 0.8406446
# Precision: 0.8587324
# Sensitivity: 0.87431186
# IoU: 0.7494873

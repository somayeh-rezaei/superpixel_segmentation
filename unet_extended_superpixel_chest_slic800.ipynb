# %%
from skimage.color import label2rgb, rgb2gray
from skimage.segmentation import mark_boundaries
import numpy as np
import tensorflow as tf
import os
import cv2
from glob import glob
import matplotlib.pyplot as plt
from keras.layers import *
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from skimage.morphology import binary_erosion, disk
import keras.backend as K
from skimage.segmentation import felzenszwalb, slic, quickshift, watershed
from keras.callbacks import TensorBoard
from keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate
from keras.models import Model
from tqdm import tqdm
import glob
# Out:
# 2024-01-27 20:04:34.358801: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-27 20:04:34.556596: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-01-27 20:04:35.380353: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-01-27 20:04:35.380448: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-01-27 20:04:35.380454: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# image_paths = glob.glob('/home/somayeh/PycharmProjects/superpixel_segmentation/archive (3)/data/Lung Segmentation/train_validation_original/*.png' )
# mask_paths = glob.glob('/home/somayeh/PycharmProjects/superpixel_segmentation/archive (3)/data/Lung Segmentation/train_validation_mask/*.png')
# image_paths = glob.glob('/home/somayeh/PycharmProjects/superpixel_segmentation/archive (2)/Dataset_BUSI_with_GT/breast_train/*.png')
# mask_paths = glob.glob('/home/somayeh/PycharmProjects/superpixel_segmentation/archive (2)/Dataset_BUSI_with_GT/breast_train_mask/*.png')
image_paths = glob.glob('/home/somayeh/PycharmProjects/superpixel_segmentation/new_data_breast/train/image/*.jpg')
mask_paths = glob.glob('/home/somayeh/PycharmProjects/superpixel_segmentation/new_data_breast/train/mask/*.jpg')

# %%
# initialize empty arrays to hold the images and masks
images = []
masks = []
images_superpixel = []
binary_masks = []
masks_superpixel = []
masks_result = []
binary = []

# %%
def extended_superpixel(img, ground_truth):
    # Perform SLIC superpixel segmentation
    num_segments = 1200
    segments = slic(img, n_segments=num_segments, compactness=10)


    # Find superpixels intersecting with the image boundaries
    boundary_mask = cv2.morphologyEx(ground_truth, cv2.MORPH_GRADIENT, np.ones((5, 5), np.uint8)) > 0
    boundary_superpixels = set(segments[boundary_mask])

    # Show the number of superpixels with intersection with image boundaries
    num_boundary_superpixels = len(boundary_superpixels)
    # print(f'The number of superpixels with intersection with image boundaries: {num_boundary_superpixels}')

    # Overlay superpixels with ground truth
    labels = segments.astype(np.int32)

    inside_mask = (ground_truth == 255)  # white pixels in ground truth are inside the chest region
    outside_mask = (ground_truth == 0)  # black pixels in ground truth are outside the chest region

    inside_superpixels = set(np.unique(labels[inside_mask]))
    outside_superpixels = set(np.unique(labels[outside_mask]))

    # Assign labels and color superpixels
    result = np.zeros_like(img)
    for label in outside_superpixels:
        mask = (labels == label)
        result[mask] = (0, 0, 0)  # Set label 0 (black) for superpixels outside the boundary

    for label in inside_superpixels:
        mask = (labels == label)
        result[mask] = (255, 255, 255)  # Set label 1 (white) for superpixels inside the boundary

    for label in boundary_superpixels:
        mask = (labels == label)
        num_pixels_inside = np.sum(mask & inside_mask)
        num_pixels_outside = np.sum(mask & outside_mask)

        if num_pixels_outside > num_pixels_inside:
            result[mask] = (0, 0, 0)  # Set label 0 (black) for superpixels with more pixels outside the boundary
        elif num_pixels_outside < num_pixels_inside:
            result[mask] = (255, 255, 255)  # Set label 1 (white) for superpixels with more pixels inside the boundary
        else:
            d1 = cv2.distanceTransform((mask & outside_mask).astype(np.uint8), cv2.DIST_L2, 5)
            d2 = cv2.distanceTransform((mask & inside_mask).astype(np.uint8), cv2.DIST_L2, 5)

            d1_sorted = np.sort(d1[mask & boundary_mask])
            d2_sorted = np.sort(d2[mask & boundary_mask])

            threshold_idx = len(d1_sorted) // 2
            if np.sum(d1_sorted[:threshold_idx]) > np.sum(d1_sorted[threshold_idx:]):
                result[mask] = (0, 0, 0)  # Set label 0 (black) for superpixels with larger distance to outside
            else:
                result[mask] = (255, 255, 255)  # Set label 1 (white) for superpixels with larger distance to inside

    # cv2.imshow('Result', result)
    # cv2.waitKey(0)
    # cv2.destroyAllWindows()

    return result

# %%
def iou(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    iou_score = (intersection + smooth) / (union + smooth)
    return iou_score

def precision(y_true, y_pred):
    y_true_flat = K.flatten(y_true)
    y_pred_flat = K.flatten(y_pred)
    true_positives = K.sum(K.round(K.clip(y_true_flat * y_pred_flat, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred_flat, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())

    return precision

def sensitivity(gt_mask, pred_mask):

    gt_mask_flat = K.flatten(gt_mask)
    pred_mask_flat = K.flatten(pred_mask)

    # compute true positive (TP) and false negative (FN) counts
    TP = K.sum(gt_mask_flat * pred_mask_flat)
    FN = K.sum(gt_mask_flat * (1 - pred_mask_flat))

    # compute sensitivity (recall)
    if TP + FN == 0:
        sensitivity_score = 0.0
    else:
        sensitivity_score = TP / (TP + FN)

    return sensitivity_score

def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %%
def dice_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred, smooth=1)

# %%
batch_size = 8
threshold_value = 128
def data_generator(image_paths, mask_paths, batch_size):

    assert len(image_paths) == len(mask_paths), "Number of images and masks must be the same."

    num_samples = len(image_paths)
    print("Number of images:", num_samples)
    num_masks = len(mask_paths)
    print("Number of masks:", num_masks)

    while True:
        indices = np.arange(num_samples)
        np.random.shuffle(indices)

        for i in range(0, num_samples, batch_size):
            batch_indices = indices[i : i + batch_size]
            batch_images = []
            batch_masks = []

            for index in batch_indices:
                image_path = image_paths[index]
                mask_path = mask_paths[index]

                img = cv2.imread(image_path)
                img = cv2.resize(img, (128, 128))

                filename = os.path.join("/home/somayeh/PycharmProjects/superpixel_segmentation/"
                                        "newgt/newgt_extended_superpixel_breast_128_slic1200", os.path.basename(mask_path))
                if not os.path.exists(filename):

                    mask = cv2.imread(mask_path,0)
                    mask = cv2.resize(mask, (128, 128))

                    result = extended_superpixel(img, mask)
                    # result = ground_truth_superpixel_3(img, mask)

                    # result = cv2.cvtColor(result, cv2.COLOR_BGR2GRAY)
                    # plt.subplot(1, 2, 2)
                    # plt.imshow(result)
                    # plt.title("hggh")

                    # soft_label = binary_to_soft_label(result, threshold_value=threshold_value)
                    # cv2.imshow("kjkj",soft_label)
                    # cv2.waitKey(0)
                    # result = cv2.cvtColor(result, cv2.COLOR_BGR2GRAY)

                    cv2.imwrite(filename, result)

                else:
                    result = cv2.imread(filename, 0)
                # print(result.type)
                # img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                # soft_label = binary_to_soft_label(result)

                # normalize the image and mask to have values between 0 and 1
                # img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                img = img / 255.0
                result= result/ 255.0
                # result = result / 255.0
                # print(soft_label.shape)
                # cv2.imshow("dfg", soft_label)
                # cv2.waitKey(0)
                # Append the preprocessed data to the respective lists

                batch_images.append(img)
                batch_masks.append(result)

            # Yield the batch data
            batch_images = np.array(batch_images)
            batch_masks = np.array(batch_masks)

            # Visualize the images and masks in the batch
            # for j in range(batch_images.shape[0]):
            #     plt.subplot(1, 2, 1)
            #     plt.imshow(batch_images[j])
            #     plt.title("Image")
            #
            #     plt.subplot(1, 2, 2)
            #     plt.imshow(batch_masks[j])
            #     plt.title("Mask")
            #
            #     plt.show()

            yield batch_images, batch_masks

# 
# generator = data_generator(image_paths, mask_paths, 1)
# 
# for _,imgpath in tqdm(enumerate(image_paths)):
#    batch = next(generator)

# %%
mask_path_superpixel_label = glob.glob("/home/somayeh/PycharmProjects/superpixel_segmentation/newgt/newgt_extended_superpixel_breast_128_slic1200/*.jpg")

# %%
assert len(image_paths) == len(mask_path_superpixel_label), "Number of images and masks must be the same."
# Split the data into training and validation sets
train_image_paths, val_image_paths, train_mask_paths, val_mask_paths = train_test_split(
    image_paths, mask_path_superpixel_label, test_size=0.2, random_state=2023
)


# Create separate generators for training and validation sets
train_generator = data_generator(train_image_paths, train_mask_paths, batch_size)
val_generator = data_generator(val_image_paths, val_mask_paths, batch_size)

# batch_size = 5  # Number of batches to visualize

# for _ in range(batch_size):
#     batch = next(train_generator)

# Determine the number of steps per epoch for training and validation
train_steps_per_epoch = len(train_image_paths) // batch_size
val_steps_per_epoch = len(val_image_paths) // batch_size

print(train_steps_per_epoch)
print(val_steps_per_epoch)
# Out:
# 1294
# 323

# %%
from keras.applications import MobileNetV2

IMAGE_SIZE = 128
# Function for conv2d_block (to be used for building decoder of unet)
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size), kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def unet(n_filters=16, batchnorm=True, dropout=0.1, num_classes=1):
    # Contracting Path (encoder)
    inputs = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3), name="input_image")
    encoder = MobileNetV2(input_tensor=inputs, include_top=False)

    BASE_WEIGHT_PATH = ('https://github.com/fchollet/deep-learning-models/releases/download/v0.6/')
    model_name = 'mobilenet_%s_%d_tf_no_top.h5' % ('1_0', 224)
    weight_path = BASE_WEIGHT_PATH + model_name
    weights_path = tf.keras.utils.get_file(model_name, weight_path)

    encoder.load_weights(weights_path, by_name=True, skip_mismatch=True)

    skip_connection_names = ["input_image", "block_1_expand_relu", "block_3_expand_relu", "block_6_expand_relu"]
    encoder_output = encoder.get_layer("block_13_expand_relu").output

    x = encoder_output
    x_skip_1 = encoder.get_layer(skip_connection_names[-1]).output
    x_skip_2 = encoder.get_layer(skip_connection_names[-2]).output
    x_skip_3 = encoder.get_layer(skip_connection_names[-3]).output
    x_skip_4 = encoder.get_layer(skip_connection_names[-4]).output

    # Expansive Path (decoder)
    u6 = Conv2DTranspose(n_filters * 13, (3, 3), strides=(2, 2), padding='same')(x)
    u6 = concatenate([u6, x_skip_1])
    c6 = conv2d_block(u6, n_filters * 13, kernel_size=3, batchnorm=batchnorm)
    p6 = Dropout(dropout)(c6)

    u7 = Conv2DTranspose(n_filters * 12, (3, 3), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, x_skip_2])
    c7 = conv2d_block(u7, n_filters * 12, kernel_size=3, batchnorm=batchnorm)
    p7 = Dropout(dropout)(c7)

    u8 = Conv2DTranspose(n_filters * 11, (3, 3), strides=(2, 2), padding='same')(p7)
    u8 = concatenate([u8, x_skip_3])
    c8 = conv2d_block(u8, n_filters * 11, kernel_size=3, batchnorm=batchnorm)
    p7 = Dropout(dropout)(c8)

    u9 = Conv2DTranspose(n_filters * 10, (3, 3), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, x_skip_4])
    c9 = conv2d_block(u9, n_filters * 10, kernel_size=3, batchnorm=batchnorm)

    # Output layer with sigmoid activation for binary segmentation
    outputs = Conv2D(num_classes, (1, 1), activation='sigmoid')(c9)

    model = Model(inputs=inputs, outputs=outputs)

    return model

# %%
# !rm -rf '/home/somayeh/PycharmProjects/superpixel_segmentation/tensor_board'

# %%
# %load_ext tensorboard
log_folder = '/home/somayeh/PycharmProjects/superpixel_segmentation/tensor_board'

# %%
# weight_path="{}_Unet_extended_superpixel_chest_slic800.best.hdf5".format('cxr_reg')
weight_path="{}_Unet_extended_superpixel_breast_slic800.best.hdf5".format('cxr_reg')


checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1,
                             save_best_only=True, mode='min', save_weights_only = True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                                   patience=3,
                                   verbose=1, mode='min', epsilon=0.0001, cooldown=2, min_lr=1e-5)
early = EarlyStopping(monitor="val_loss",
                      mode="min",
                      patience=20) # probably needs to be more patient, but kaggle time is limited

tbcallback = TensorBoard(log_dir=log_folder,
                         histogram_freq=1,
                         write_graph=True,
                         write_images=True,
                         update_freq='epoch',
                         profile_batch=2,
                         embeddings_freq=1)

callbacks_list = [checkpoint, early, reduceLROnPlat, tbcallback]
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# 2024-01-27 20:06:06.511037: I tensorflow/core/profiler/lib/profiler_session.cc:101] Profiler session initializing.
# 2024-01-27 20:06:06.511071: I tensorflow/core/profiler/lib/profiler_session.cc:116] Profiler session started.
# 2024-01-27 20:06:06.587622: I tensorflow/core/profiler/backends/gpu/cupti_tracer.cc:1664] Profiler found 1 GPUs
# 2024-01-27 20:06:06.588241: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcupti.so.11.2'; dlerror: libcupti.so.11.2: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/somayeh/PycharmProjects/superpixel_segmentation/venv/lib/python3.8/site-packages/cv2/../../lib64:
# 2024-01-27 20:06:06.639505: I tensorflow/core/profiler/lib/profiler_session.cc:128] Profiler session tear down.
# 2024-01-27 20:06:06.639633: I tensorflow/core/profiler/backends/gpu/cupti_tracer.cc:1798] CUPTI activity buffer flushed

# %%
model =unet(n_filters = 8, batchnorm = True, dropout = 0.1, num_classes=1)
opt = tf.keras.optimizers.experimental.AdamW(learning_rate=0.0001)
model.compile(optimizer=opt, loss=dice_loss, metrics= [dice_coef, precision, sensitivity, iou],  run_eagerly=True)
model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# 2024-01-27 20:06:11.903556: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-27 20:06:12.006468: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-27 20:06:12.006646: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-27 20:06:12.007504: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-27 20:06:12.008195: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-27 20:06:12.008424: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-27 20:06:12.008521: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-27 20:06:12.801350: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-27 20:06:12.802518: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-27 20:06:12.802769: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-01-27 20:06:12.802900: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2111 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_image (InputLayer)       [(None, 128, 128, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 64, 64, 32)   864         ['input_image[0][0]']
#
#  bn_Conv1 (BatchNormalization)  (None, 64, 64, 32)   128         ['Conv1[0][0]']
#
#  Conv1_relu (ReLU)              (None, 64, 64, 32)   0           ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (Depth  (None, 64, 64, 32)  288         ['Conv1_relu[0][0]']
#  wiseConv2D)
#
#  expanded_conv_depthwise_BN (Ba  (None, 64, 64, 32)  128         ['expanded_conv_depthwise[0][0]']
#  tchNormalization)
#
#  expanded_conv_depthwise_relu (  (None, 64, 64, 32)  0           ['expanded_conv_depthwise_BN[0][0
#  ReLU)                                                           ]']
#
#  expanded_conv_project (Conv2D)  (None, 64, 64, 16)  512         ['expanded_conv_depthwise_relu[0]
#                                                                  [0]']
#
#  expanded_conv_project_BN (Batc  (None, 64, 64, 16)  64          ['expanded_conv_project[0][0]']
#  hNormalization)
#
#  block_1_expand (Conv2D)        (None, 64, 64, 96)   1536        ['expanded_conv_project_BN[0][0]'
#                                                                  ]
#
#  block_1_expand_BN (BatchNormal  (None, 64, 64, 96)  384         ['block_1_expand[0][0]']
#  ization)
#
#  block_1_expand_relu (ReLU)     (None, 64, 64, 96)   0           ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D)    (None, 65, 65, 96)   0           ['block_1_expand_relu[0][0]']
#
#  block_1_depthwise (DepthwiseCo  (None, 32, 32, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 32, 32, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 32, 32, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 32, 32, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 32, 32, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 32, 32, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 32, 32, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 32, 32, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 32, 32, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 32, 32, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 32, 32, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 32, 32, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 32, 32, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 32, 32, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 32, 32, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 32, 32, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 32, 32, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 33, 33, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 16, 16, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 16, 16, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 16, 16, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 16, 16, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 16, 16, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 16, 16, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 16, 16, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 16, 16, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 16, 16, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 16, 16, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 16, 16, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 16, 16, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 16, 16, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 16, 16, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 16, 16, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 16, 16, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 16, 16, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 16, 16, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 16, 16, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 16, 16, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 16, 16, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 16, 16, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 16, 16, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 16, 16, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 16, 16, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 16, 16, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 17, 17, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 8, 8, 192)   1728        ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 8, 8, 192)   768         ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 8, 8, 192)    0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 8, 8, 64)     12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 8, 8, 64)    256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 8, 8, 384)    24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 8, 8, 384)   1536        ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 8, 8, 384)    0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 8, 8, 384)   3456        ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 8, 8, 384)   1536        ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 8, 8, 384)    0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 8, 8, 64)     24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 8, 8, 64)    256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 8, 8, 64)     0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 8, 8, 384)    24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 8, 8, 384)   1536        ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 8, 8, 384)    0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 8, 8, 384)   3456        ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 8, 8, 384)   1536        ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 8, 8, 384)    0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 8, 8, 64)     24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 8, 8, 64)    256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 8, 8, 64)     0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 8, 8, 384)    24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 8, 8, 384)   1536        ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 8, 8, 384)    0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 8, 8, 384)   3456        ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 8, 8, 384)   1536        ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 8, 8, 384)    0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 8, 8, 64)     24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 8, 8, 64)    256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 8, 8, 64)     0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 8, 8, 384)    24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 8, 8, 384)   1536        ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 8, 8, 384)    0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 8, 8, 384)   3456        ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 8, 8, 384)   1536        ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 8, 8, 384)   0           ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 8, 8, 96)     36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 8, 8, 96)    384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 8, 8, 576)    55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 8, 8, 576)   2304        ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 8, 8, 576)    0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 8, 8, 576)   5184        ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 8, 8, 576)   2304        ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 8, 8, 576)   0           ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 8, 8, 96)     55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 8, 8, 96)    384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 8, 8, 96)     0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 8, 8, 576)    55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 8, 8, 576)   2304        ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 8, 8, 576)    0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 8, 8, 576)   5184        ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 8, 8, 576)   2304        ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 8, 8, 576)   0           ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 8, 8, 96)     55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 8, 8, 96)    384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 8, 8, 96)     0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 8, 8, 576)    55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 8, 8, 576)   2304        ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 8, 8, 576)    0           ['block_13_expand_BN[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 104)  539240     ['block_13_expand_relu[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 16, 16, 296)  0           ['conv2d_transpose[0][0]',
#                                                                   'block_6_expand_relu[0][0]']
#
#  conv2d (Conv2D)                (None, 16, 16, 104)  277160      ['concatenate[0][0]']
#
#  batch_normalization (BatchNorm  (None, 16, 16, 104)  416        ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 16, 16, 104)  0           ['batch_normalization[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 96)  89952       ['activation[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 240)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'block_3_expand_relu[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 96)   207456      ['concatenate_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 96)  384         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 32, 32, 96)   0           ['batch_normalization_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 32, 32, 96)   0           ['activation_1[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 88)  76120       ['dropout_1[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 184)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'block_1_expand_relu[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 88)   145816      ['concatenate_2[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 88)  352         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 64, 64, 88)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 80  63440      ['activation_2[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 83  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'input_image[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 80  59840       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 80  320        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 128, 128, 80  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 1)  81          ['activation_3[0][0]']
#
# ==================================================================================================
# Total params: 2,076,833
# Trainable params: 2,058,817
# Non-trainable params: 18,016
# __________________________________________________________________________________________________

# %%
loss_history = model.fit_generator(
    train_generator,
    steps_per_epoch=train_steps_per_epoch,
    validation_data=val_generator,
    validation_steps=val_steps_per_epoch,
    epochs=50,
    callbacks =callbacks_list
)

# model.save("unet_extended_superpixel_chest_slic800.h5")
model.save("unet_extended_superpixel_breast_slic800.h5")
# Out:
# Number of images: 10358
# Number of masks: 10358
# Epoch 1/50
# /tmp/ipykernel_5253/3604466995.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   loss_history = model.fit_generator(
# 2024-01-27 20:06:36.827620: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8902
# 2024-01-27 20:06:37.662724: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:37.663865: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:234] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.6
# 2024-01-27 20:06:37.663894: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:237] Used ptxas at ptxas
# 2024-01-27 20:06:37.663947: W tensorflow/compiler/xla/stream_executor/gpu/redzone_allocator.cc:318] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2024-01-27 20:06:37.769570: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-01-27 20:06:38.269801: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.21GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-01-27 20:06:38.269834: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.21GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-01-27 20:06:38.403711: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.61GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-01-27 20:06:38.403740: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.61GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-01-27 20:06:38.562265: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.60GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-01-27 20:06:38.562296: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.60GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-01-27 20:06:38.690100: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-01-27 20:06:38.690150: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.32GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-01-27 20:06:38.826182: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.11GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-01-27 20:06:38.826223: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.11GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-01-27 20:06:39.370126: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x842ada20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-01-27 20:06:39.370153: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6
# 2024-01-27 20:06:39.384617: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-01-27 20:06:39.517177: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:39.518866: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2024-01-27 20:06:39.589265: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:39.750085: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7f7384509c10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7f7384509c10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2024-01-27 20:06:39.975380: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:40.066139: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:40.214160: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:40.294724: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:40.616634: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:40.701585: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:40.867302: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:40.939801: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:41.092603: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:41.864272: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:42.052087: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:42.124259: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:42.247686: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:43.589813: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:43.778834: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:45.981953: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:46.107289: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:47.335145: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:47.401235: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:47.475402: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:47.738289: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:47.884144: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:48.171296: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:48.243082: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:48.308927: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:48.570660: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:48.643818: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:48.709153: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
#    1/1294 [..............................] - ETA: 4:56:41 - loss: 0.8847 - dice_coef: 0.1153 - precision: 0.0644 - sensitivity: 0.5352 - iou: 0.0612
# 2024-01-27 20:06:49.055490: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2024-01-27 20:06:49.167331: I tensorflow/core/profiler/lib/profiler_session.cc:101] Profiler session initializing.
# 2024-01-27 20:06:49.167352: I tensorflow/core/profiler/lib/profiler_session.cc:116] Profiler session started.
#    2/1294 [..............................] - ETA: 15:22 - loss: 0.8303 - dice_coef: 0.1697 - precision: 0.1038 - sensitivity: 0.5390 - iou: 0.0937
# 2024-01-27 20:06:49.787144: I tensorflow/core/profiler/lib/profiler_session.cc:67] Profiler session collecting data.
# 2024-01-27 20:06:49.803872: I tensorflow/core/profiler/backends/gpu/cupti_tracer.cc:1798] CUPTI activity buffer flushed
# 2024-01-27 20:06:49.853654: I tensorflow/core/profiler/backends/gpu/cupti_collector.cc:522]  GpuTracer has collected 1645 callback api events and 1742 activity events.
# 2024-01-27 20:06:49.866164: I tensorflow/core/profiler/lib/profiler_session.cc:128] Profiler session tear down.
# 2024-01-27 20:06:49.867790: I tensorflow/core/profiler/rpc/client/save_profile.cc:164] Collecting XSpace to repository: /home/somayeh/PycharmProjects/superpixel_segmentation/tensor_board/plugins/profile/2024_01_27_20_06_49/somayeh-ASUS-TUF-Gaming-F15-FX506HCB-FX506HCB.xplane.pb
# 1294/1294 [==============================] - ETA: 0s - loss: 0.3374 - dice_coef: 0.6626 - precision: 0.6939 - sensitivity: 0.7742 - iou: 0.5166Number of images: 2590
# Number of masks: 2590
#
# Epoch 1: val_loss improved from inf to 0.36031, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 250s 183ms/step - loss: 0.3374 - dice_coef: 0.6626 - precision: 0.6939 - sensitivity: 0.7742 - iou: 0.5166 - val_loss: 0.3603 - val_dice_coef: 0.6397 - val_precision: 0.8955 - val_sensitivity: 0.5467 - val_iou: 0.4852 - lr: 1.0000e-04
# Epoch 2/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.1945 - dice_coef: 0.8056 - precision: 0.8442 - sensitivity: 0.8090 - iou: 0.6853
# Epoch 2: val_loss improved from 0.36031 to 0.21689, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 235s 181ms/step - loss: 0.1945 - dice_coef: 0.8056 - precision: 0.8442 - sensitivity: 0.8090 - iou: 0.6853 - val_loss: 0.2169 - val_dice_coef: 0.7831 - val_precision: 0.7988 - val_sensitivity: 0.8026 - val_iou: 0.6553 - lr: 1.0000e-04
# Epoch 3/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.1597 - dice_coef: 0.8402 - precision: 0.8746 - sensitivity: 0.8311 - iou: 0.7328
# Epoch 3: val_loss improved from 0.21689 to 0.17034, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 231s 179ms/step - loss: 0.1597 - dice_coef: 0.8402 - precision: 0.8746 - sensitivity: 0.8311 - iou: 0.7328 - val_loss: 0.1703 - val_dice_coef: 0.8297 - val_precision: 0.8224 - val_sensitivity: 0.8597 - val_iou: 0.7214 - lr: 1.0000e-04
# Epoch 4/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.1395 - dice_coef: 0.8605 - precision: 0.8908 - sensitivity: 0.8470 - iou: 0.7619
# Epoch 4: val_loss improved from 0.17034 to 0.16156, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 231s 178ms/step - loss: 0.1395 - dice_coef: 0.8605 - precision: 0.8908 - sensitivity: 0.8470 - iou: 0.7619 - val_loss: 0.1616 - val_dice_coef: 0.8384 - val_precision: 0.8187 - val_sensitivity: 0.8817 - val_iou: 0.7315 - lr: 1.0000e-04
# Epoch 5/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.1249 - dice_coef: 0.8751 - precision: 0.9005 - sensitivity: 0.8635 - iou: 0.7843
# Epoch 5: val_loss improved from 0.16156 to 0.13891, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 232s 179ms/step - loss: 0.1249 - dice_coef: 0.8751 - precision: 0.9005 - sensitivity: 0.8635 - iou: 0.7843 - val_loss: 0.1389 - val_dice_coef: 0.8611 - val_precision: 0.9225 - val_sensitivity: 0.8226 - val_iou: 0.7660 - lr: 1.0000e-04
# Epoch 6/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.1130 - dice_coef: 0.8870 - precision: 0.9077 - sensitivity: 0.8769 - iou: 0.8023
# Epoch 6: val_loss improved from 0.13891 to 0.13084, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 231s 179ms/step - loss: 0.1130 - dice_coef: 0.8870 - precision: 0.9077 - sensitivity: 0.8769 - iou: 0.8023 - val_loss: 0.1308 - val_dice_coef: 0.8692 - val_precision: 0.9006 - val_sensitivity: 0.8515 - val_iou: 0.7771 - lr: 1.0000e-04
# Epoch 7/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.1067 - dice_coef: 0.8933 - precision: 0.9142 - sensitivity: 0.8818 - iou: 0.8126
# Epoch 7: val_loss did not improve from 0.13084
# 1294/1294 [==============================] - 232s 180ms/step - loss: 0.1067 - dice_coef: 0.8933 - precision: 0.9142 - sensitivity: 0.8818 - iou: 0.8126 - val_loss: 0.1411 - val_dice_coef: 0.8589 - val_precision: 0.8291 - val_sensitivity: 0.9077 - val_iou: 0.7599 - lr: 1.0000e-04
# Epoch 8/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0967 - dice_coef: 0.9033 - precision: 0.9211 - sensitivity: 0.8928 - iou: 0.8275
# Epoch 8: val_loss improved from 0.13084 to 0.12767, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 231s 179ms/step - loss: 0.0967 - dice_coef: 0.9033 - precision: 0.9211 - sensitivity: 0.8928 - iou: 0.8275 - val_loss: 0.1277 - val_dice_coef: 0.8723 - val_precision: 0.8719 - val_sensitivity: 0.8867 - val_iou: 0.7819 - lr: 1.0000e-04
# Epoch 9/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0922 - dice_coef: 0.9078 - precision: 0.9257 - sensitivity: 0.8971 - iou: 0.8349
# Epoch 9: val_loss improved from 0.12767 to 0.12092, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 233s 180ms/step - loss: 0.0922 - dice_coef: 0.9078 - precision: 0.9257 - sensitivity: 0.8971 - iou: 0.8349 - val_loss: 0.1209 - val_dice_coef: 0.8791 - val_precision: 0.9372 - val_sensitivity: 0.8384 - val_iou: 0.7920 - lr: 1.0000e-04
# Epoch 10/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0870 - dice_coef: 0.9130 - precision: 0.9282 - sensitivity: 0.9038 - iou: 0.8434
# Epoch 10: val_loss improved from 0.12092 to 0.11495, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 232s 180ms/step - loss: 0.0870 - dice_coef: 0.9130 - precision: 0.9282 - sensitivity: 0.9038 - iou: 0.8434 - val_loss: 0.1149 - val_dice_coef: 0.8851 - val_precision: 0.8816 - val_sensitivity: 0.8998 - val_iou: 0.8007 - lr: 1.0000e-04
# Epoch 11/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0838 - dice_coef: 0.9162 - precision: 0.9315 - sensitivity: 0.9071 - iou: 0.8489
# Epoch 11: val_loss improved from 0.11495 to 0.11404, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 233s 180ms/step - loss: 0.0838 - dice_coef: 0.9162 - precision: 0.9315 - sensitivity: 0.9071 - iou: 0.8489 - val_loss: 0.1140 - val_dice_coef: 0.8860 - val_precision: 0.8933 - val_sensitivity: 0.8896 - val_iou: 0.8036 - lr: 1.0000e-04
# Epoch 12/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0809 - dice_coef: 0.9191 - precision: 0.9334 - sensitivity: 0.9103 - iou: 0.8533
# Epoch 12: val_loss did not improve from 0.11404
# 1294/1294 [==============================] - 232s 179ms/step - loss: 0.0809 - dice_coef: 0.9191 - precision: 0.9334 - sensitivity: 0.9103 - iou: 0.8533 - val_loss: 0.1169 - val_dice_coef: 0.8831 - val_precision: 0.9364 - val_sensitivity: 0.8470 - val_iou: 0.7993 - lr: 1.0000e-04
# Epoch 13/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0756 - dice_coef: 0.9245 - precision: 0.9381 - sensitivity: 0.9155 - iou: 0.8621
# Epoch 13: val_loss improved from 0.11404 to 0.11038, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 233s 180ms/step - loss: 0.0756 - dice_coef: 0.9245 - precision: 0.9381 - sensitivity: 0.9155 - iou: 0.8621 - val_loss: 0.1104 - val_dice_coef: 0.8896 - val_precision: 0.8936 - val_sensitivity: 0.8987 - val_iou: 0.8097 - lr: 1.0000e-04
# Epoch 14/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0738 - dice_coef: 0.9262 - precision: 0.9393 - sensitivity: 0.9178 - iou: 0.8652
# Epoch 14: val_loss improved from 0.11038 to 0.10478, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 234s 181ms/step - loss: 0.0738 - dice_coef: 0.9262 - precision: 0.9393 - sensitivity: 0.9178 - iou: 0.8652 - val_loss: 0.1048 - val_dice_coef: 0.8952 - val_precision: 0.9276 - val_sensitivity: 0.8757 - val_iou: 0.8187 - lr: 1.0000e-04
# Epoch 15/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0695 - dice_coef: 0.9305 - precision: 0.9428 - sensitivity: 0.9222 - iou: 0.8723
# Epoch 15: val_loss improved from 0.10478 to 0.10027, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 233s 180ms/step - loss: 0.0695 - dice_coef: 0.9305 - precision: 0.9428 - sensitivity: 0.9222 - iou: 0.8723 - val_loss: 0.1003 - val_dice_coef: 0.8997 - val_precision: 0.9053 - val_sensitivity: 0.9046 - val_iou: 0.8248 - lr: 1.0000e-04
# Epoch 16/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0680 - dice_coef: 0.9320 - precision: 0.9430 - sensitivity: 0.9247 - iou: 0.8747
# Epoch 16: val_loss did not improve from 0.10027
# 1294/1294 [==============================] - 233s 180ms/step - loss: 0.0680 - dice_coef: 0.9320 - precision: 0.9430 - sensitivity: 0.9247 - iou: 0.8747 - val_loss: 0.1008 - val_dice_coef: 0.8992 - val_precision: 0.9383 - val_sensitivity: 0.8731 - val_iou: 0.8252 - lr: 1.0000e-04
# Epoch 17/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0657 - dice_coef: 0.9343 - precision: 0.9450 - sensitivity: 0.9271 - iou: 0.8787
# Epoch 17: val_loss improved from 0.10027 to 0.09700, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 234s 180ms/step - loss: 0.0657 - dice_coef: 0.9343 - precision: 0.9450 - sensitivity: 0.9271 - iou: 0.8787 - val_loss: 0.0970 - val_dice_coef: 0.9030 - val_precision: 0.9518 - val_sensitivity: 0.8672 - val_iou: 0.8297 - lr: 1.0000e-04
# Epoch 18/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0650 - dice_coef: 0.9350 - precision: 0.9449 - sensitivity: 0.9295 - iou: 0.8804
# Epoch 18: val_loss improved from 0.09700 to 0.09300, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 232s 180ms/step - loss: 0.0650 - dice_coef: 0.9350 - precision: 0.9449 - sensitivity: 0.9295 - iou: 0.8804 - val_loss: 0.0930 - val_dice_coef: 0.9070 - val_precision: 0.9174 - val_sensitivity: 0.9057 - val_iou: 0.8362 - lr: 1.0000e-04
# Epoch 19/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0602 - dice_coef: 0.9398 - precision: 0.9504 - sensitivity: 0.9327 - iou: 0.8885
# Epoch 19: val_loss did not improve from 0.09300
# 1294/1294 [==============================] - 234s 181ms/step - loss: 0.0602 - dice_coef: 0.9398 - precision: 0.9504 - sensitivity: 0.9327 - iou: 0.8885 - val_loss: 0.0978 - val_dice_coef: 0.9022 - val_precision: 0.9321 - val_sensitivity: 0.8845 - val_iou: 0.8295 - lr: 1.0000e-04
# Epoch 20/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0599 - dice_coef: 0.9401 - precision: 0.9499 - sensitivity: 0.9332 - iou: 0.8887
# Epoch 20: val_loss did not improve from 0.09300
# 1294/1294 [==============================] - 233s 180ms/step - loss: 0.0599 - dice_coef: 0.9401 - precision: 0.9499 - sensitivity: 0.9332 - iou: 0.8887 - val_loss: 0.0938 - val_dice_coef: 0.9062 - val_precision: 0.9396 - val_sensitivity: 0.8840 - val_iou: 0.8356 - lr: 1.0000e-04
# Epoch 21/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0592 - dice_coef: 0.9408 - precision: 0.9504 - sensitivity: 0.9344 - iou: 0.8901
# Epoch 21: val_loss improved from 0.09300 to 0.09263, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 234s 181ms/step - loss: 0.0592 - dice_coef: 0.9408 - precision: 0.9504 - sensitivity: 0.9344 - iou: 0.8901 - val_loss: 0.0926 - val_dice_coef: 0.9074 - val_precision: 0.9363 - val_sensitivity: 0.8887 - val_iou: 0.8383 - lr: 1.0000e-04
# Epoch 22/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0576 - dice_coef: 0.9424 - precision: 0.9516 - sensitivity: 0.9364 - iou: 0.8929
# Epoch 22: val_loss did not improve from 0.09263
# 1294/1294 [==============================] - 232s 180ms/step - loss: 0.0576 - dice_coef: 0.9424 - precision: 0.9516 - sensitivity: 0.9364 - iou: 0.8929 - val_loss: 0.1044 - val_dice_coef: 0.8956 - val_precision: 0.8885 - val_sensitivity: 0.9147 - val_iou: 0.8184 - lr: 1.0000e-04
# Epoch 23/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0566 - dice_coef: 0.9434 - precision: 0.9524 - sensitivity: 0.9375 - iou: 0.8946
# Epoch 23: val_loss improved from 0.09263 to 0.09065, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 233s 180ms/step - loss: 0.0566 - dice_coef: 0.9434 - precision: 0.9524 - sensitivity: 0.9375 - iou: 0.8946 - val_loss: 0.0906 - val_dice_coef: 0.9094 - val_precision: 0.9376 - val_sensitivity: 0.8910 - val_iou: 0.8413 - lr: 1.0000e-04
# Epoch 24/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0525 - dice_coef: 0.9475 - precision: 0.9562 - sensitivity: 0.9414 - iou: 0.9017
# Epoch 24: val_loss did not improve from 0.09065
# 1294/1294 [==============================] - 233s 180ms/step - loss: 0.0525 - dice_coef: 0.9475 - precision: 0.9562 - sensitivity: 0.9414 - iou: 0.9017 - val_loss: 0.0916 - val_dice_coef: 0.9084 - val_precision: 0.9333 - val_sensitivity: 0.8939 - val_iou: 0.8397 - lr: 1.0000e-04
# Epoch 25/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0545 - dice_coef: 0.9455 - precision: 0.9547 - sensitivity: 0.9392 - iou: 0.8983
# Epoch 25: val_loss improved from 0.09065 to 0.08904, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 232s 180ms/step - loss: 0.0545 - dice_coef: 0.9455 - precision: 0.9547 - sensitivity: 0.9392 - iou: 0.8983 - val_loss: 0.0890 - val_dice_coef: 0.9110 - val_precision: 0.9391 - val_sensitivity: 0.8934 - val_iou: 0.8439 - lr: 1.0000e-04
# Epoch 26/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0502 - dice_coef: 0.9498 - precision: 0.9583 - sensitivity: 0.9437 - iou: 0.9057
# Epoch 26: val_loss improved from 0.08904 to 0.08634, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 234s 181ms/step - loss: 0.0502 - dice_coef: 0.9498 - precision: 0.9583 - sensitivity: 0.9437 - iou: 0.9057 - val_loss: 0.0863 - val_dice_coef: 0.9137 - val_precision: 0.9279 - val_sensitivity: 0.9088 - val_iou: 0.8486 - lr: 1.0000e-04
# Epoch 27/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0530 - dice_coef: 0.9470 - precision: 0.9563 - sensitivity: 0.9408 - iou: 0.9010
# Epoch 27: val_loss did not improve from 0.08634
# 1294/1294 [==============================] - 234s 181ms/step - loss: 0.0530 - dice_coef: 0.9470 - precision: 0.9563 - sensitivity: 0.9408 - iou: 0.9010 - val_loss: 0.0869 - val_dice_coef: 0.9131 - val_precision: 0.9435 - val_sensitivity: 0.8926 - val_iou: 0.8466 - lr: 1.0000e-04
# Epoch 28/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0503 - dice_coef: 0.9497 - precision: 0.9578 - sensitivity: 0.9441 - iou: 0.9056
# Epoch 28: val_loss improved from 0.08634 to 0.08568, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 235s 181ms/step - loss: 0.0503 - dice_coef: 0.9497 - precision: 0.9578 - sensitivity: 0.9441 - iou: 0.9056 - val_loss: 0.0857 - val_dice_coef: 0.9143 - val_precision: 0.9495 - val_sensitivity: 0.8897 - val_iou: 0.8492 - lr: 1.0000e-04
# Epoch 29/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0481 - dice_coef: 0.9519 - precision: 0.9599 - sensitivity: 0.9464 - iou: 0.9095
# Epoch 29: val_loss did not improve from 0.08568
# 1294/1294 [==============================] - 233s 180ms/step - loss: 0.0481 - dice_coef: 0.9519 - precision: 0.9599 - sensitivity: 0.9464 - iou: 0.9095 - val_loss: 0.0872 - val_dice_coef: 0.9128 - val_precision: 0.9458 - val_sensitivity: 0.8902 - val_iou: 0.8472 - lr: 1.0000e-04
# Epoch 30/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0495 - dice_coef: 0.9505 - precision: 0.9586 - sensitivity: 0.9448 - iou: 0.9071
# Epoch 30: val_loss improved from 0.08568 to 0.08447, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 233s 180ms/step - loss: 0.0495 - dice_coef: 0.9505 - precision: 0.9586 - sensitivity: 0.9448 - iou: 0.9071 - val_loss: 0.0845 - val_dice_coef: 0.9155 - val_precision: 0.9306 - val_sensitivity: 0.9085 - val_iou: 0.8503 - lr: 1.0000e-04
# Epoch 31/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0482 - dice_coef: 0.9517 - precision: 0.9597 - sensitivity: 0.9461 - iou: 0.9091
# Epoch 31: val_loss improved from 0.08447 to 0.08119, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 233s 180ms/step - loss: 0.0482 - dice_coef: 0.9517 - precision: 0.9597 - sensitivity: 0.9461 - iou: 0.9091 - val_loss: 0.0812 - val_dice_coef: 0.9188 - val_precision: 0.9441 - val_sensitivity: 0.9019 - val_iou: 0.8554 - lr: 1.0000e-04
# Epoch 32/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0474 - dice_coef: 0.9526 - precision: 0.9607 - sensitivity: 0.9470 - iou: 0.9110
# Epoch 32: val_loss did not improve from 0.08119
# 1294/1294 [==============================] - 233s 180ms/step - loss: 0.0474 - dice_coef: 0.9526 - precision: 0.9607 - sensitivity: 0.9470 - iou: 0.9110 - val_loss: 0.0822 - val_dice_coef: 0.9178 - val_precision: 0.9465 - val_sensitivity: 0.8988 - val_iou: 0.8546 - lr: 1.0000e-04
# Epoch 33/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0464 - dice_coef: 0.9536 - precision: 0.9608 - sensitivity: 0.9485 - iou: 0.9125
# Epoch 33: val_loss did not improve from 0.08119
# 1294/1294 [==============================] - 233s 180ms/step - loss: 0.0464 - dice_coef: 0.9536 - precision: 0.9608 - sensitivity: 0.9485 - iou: 0.9125 - val_loss: 0.0840 - val_dice_coef: 0.9160 - val_precision: 0.9451 - val_sensitivity: 0.8966 - val_iou: 0.8512 - lr: 1.0000e-04
# Epoch 34/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0464 - dice_coef: 0.9536 - precision: 0.9611 - sensitivity: 0.9486 - iou: 0.9128
# Epoch 34: val_loss did not improve from 0.08119
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 1294/1294 [==============================] - 234s 181ms/step - loss: 0.0464 - dice_coef: 0.9536 - precision: 0.9611 - sensitivity: 0.9486 - iou: 0.9128 - val_loss: 0.0884 - val_dice_coef: 0.9116 - val_precision: 0.9604 - val_sensitivity: 0.8748 - val_iou: 0.8443 - lr: 1.0000e-04
# Epoch 35/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0405 - dice_coef: 0.9596 - precision: 0.9659 - sensitivity: 0.9550 - iou: 0.9231
# Epoch 35: val_loss improved from 0.08119 to 0.07608, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 234s 181ms/step - loss: 0.0405 - dice_coef: 0.9596 - precision: 0.9659 - sensitivity: 0.9550 - iou: 0.9231 - val_loss: 0.0761 - val_dice_coef: 0.9239 - val_precision: 0.9532 - val_sensitivity: 0.9045 - val_iou: 0.8651 - lr: 5.0000e-05
# Epoch 36/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0390 - dice_coef: 0.9610 - precision: 0.9676 - sensitivity: 0.9562 - iou: 0.9258
# Epoch 36: val_loss improved from 0.07608 to 0.07445, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 234s 181ms/step - loss: 0.0390 - dice_coef: 0.9610 - precision: 0.9676 - sensitivity: 0.9562 - iou: 0.9258 - val_loss: 0.0745 - val_dice_coef: 0.9255 - val_precision: 0.9528 - val_sensitivity: 0.9075 - val_iou: 0.8683 - lr: 5.0000e-05
# Epoch 37/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0383 - dice_coef: 0.9617 - precision: 0.9683 - sensitivity: 0.9569 - iou: 0.9270
# Epoch 37: val_loss did not improve from 0.07445
# 1294/1294 [==============================] - 235s 181ms/step - loss: 0.0383 - dice_coef: 0.9617 - precision: 0.9683 - sensitivity: 0.9569 - iou: 0.9270 - val_loss: 0.0745 - val_dice_coef: 0.9255 - val_precision: 0.9462 - val_sensitivity: 0.9134 - val_iou: 0.8681 - lr: 5.0000e-05
# Epoch 38/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0381 - dice_coef: 0.9619 - precision: 0.9686 - sensitivity: 0.9570 - iou: 0.9275
# Epoch 38: val_loss improved from 0.07445 to 0.07181, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 234s 181ms/step - loss: 0.0381 - dice_coef: 0.9619 - precision: 0.9686 - sensitivity: 0.9570 - iou: 0.9275 - val_loss: 0.0718 - val_dice_coef: 0.9282 - val_precision: 0.9500 - val_sensitivity: 0.9139 - val_iou: 0.8710 - lr: 5.0000e-05
# Epoch 39/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0373 - dice_coef: 0.9627 - precision: 0.9693 - sensitivity: 0.9581 - iou: 0.9291
# Epoch 39: val_loss did not improve from 0.07181
# 1294/1294 [==============================] - 235s 181ms/step - loss: 0.0373 - dice_coef: 0.9627 - precision: 0.9693 - sensitivity: 0.9581 - iou: 0.9291 - val_loss: 0.0755 - val_dice_coef: 0.9245 - val_precision: 0.9523 - val_sensitivity: 0.9066 - val_iou: 0.8666 - lr: 5.0000e-05
# Epoch 40/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0363 - dice_coef: 0.9637 - precision: 0.9695 - sensitivity: 0.9596 - iou: 0.9306
# Epoch 40: val_loss did not improve from 0.07181
# 1294/1294 [==============================] - 234s 181ms/step - loss: 0.0363 - dice_coef: 0.9637 - precision: 0.9695 - sensitivity: 0.9596 - iou: 0.9306 - val_loss: 0.0746 - val_dice_coef: 0.9254 - val_precision: 0.9438 - val_sensitivity: 0.9148 - val_iou: 0.8670 - lr: 5.0000e-05
# Epoch 41/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0364 - dice_coef: 0.9636 - precision: 0.9701 - sensitivity: 0.9590 - iou: 0.9307
# Epoch 41: val_loss did not improve from 0.07181
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 1294/1294 [==============================] - 235s 182ms/step - loss: 0.0364 - dice_coef: 0.9636 - precision: 0.9701 - sensitivity: 0.9590 - iou: 0.9307 - val_loss: 0.0756 - val_dice_coef: 0.9244 - val_precision: 0.9563 - val_sensitivity: 0.9016 - val_iou: 0.8662 - lr: 5.0000e-05
# Epoch 42/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0345 - dice_coef: 0.9655 - precision: 0.9717 - sensitivity: 0.9611 - iou: 0.9341
# Epoch 42: val_loss did not improve from 0.07181
# 1294/1294 [==============================] - 236s 182ms/step - loss: 0.0345 - dice_coef: 0.9655 - precision: 0.9717 - sensitivity: 0.9611 - iou: 0.9341 - val_loss: 0.0725 - val_dice_coef: 0.9275 - val_precision: 0.9500 - val_sensitivity: 0.9130 - val_iou: 0.8708 - lr: 2.5000e-05
# Epoch 43/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0334 - dice_coef: 0.9666 - precision: 0.9722 - sensitivity: 0.9626 - iou: 0.9360
# Epoch 43: val_loss improved from 0.07181 to 0.07086, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 235s 182ms/step - loss: 0.0334 - dice_coef: 0.9666 - precision: 0.9722 - sensitivity: 0.9626 - iou: 0.9360 - val_loss: 0.0709 - val_dice_coef: 0.9291 - val_precision: 0.9444 - val_sensitivity: 0.9209 - val_iou: 0.8732 - lr: 2.5000e-05
# Epoch 44/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0338 - dice_coef: 0.9662 - precision: 0.9725 - sensitivity: 0.9617 - iou: 0.9354
# Epoch 44: val_loss improved from 0.07086 to 0.07082, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 235s 182ms/step - loss: 0.0338 - dice_coef: 0.9662 - precision: 0.9725 - sensitivity: 0.9617 - iou: 0.9354 - val_loss: 0.0708 - val_dice_coef: 0.9292 - val_precision: 0.9512 - val_sensitivity: 0.9151 - val_iou: 0.8735 - lr: 2.5000e-05
# Epoch 45/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0329 - dice_coef: 0.9671 - precision: 0.9728 - sensitivity: 0.9629 - iou: 0.9369
# Epoch 45: val_loss did not improve from 0.07082
# 1294/1294 [==============================] - 236s 182ms/step - loss: 0.0329 - dice_coef: 0.9671 - precision: 0.9728 - sensitivity: 0.9629 - iou: 0.9369 - val_loss: 0.0713 - val_dice_coef: 0.9287 - val_precision: 0.9525 - val_sensitivity: 0.9136 - val_iou: 0.8732 - lr: 2.5000e-05
# Epoch 46/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0327 - dice_coef: 0.9673 - precision: 0.9731 - sensitivity: 0.9631 - iou: 0.9373
# Epoch 46: val_loss did not improve from 0.07082
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 1294/1294 [==============================] - 236s 182ms/step - loss: 0.0327 - dice_coef: 0.9673 - precision: 0.9731 - sensitivity: 0.9631 - iou: 0.9373 - val_loss: 0.0714 - val_dice_coef: 0.9286 - val_precision: 0.9492 - val_sensitivity: 0.9152 - val_iou: 0.8725 - lr: 2.5000e-05
# Epoch 47/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0322 - dice_coef: 0.9678 - precision: 0.9735 - sensitivity: 0.9638 - iou: 0.9384
# Epoch 47: val_loss improved from 0.07082 to 0.06912, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 237s 183ms/step - loss: 0.0322 - dice_coef: 0.9678 - precision: 0.9735 - sensitivity: 0.9638 - iou: 0.9384 - val_loss: 0.0691 - val_dice_coef: 0.9309 - val_precision: 0.9524 - val_sensitivity: 0.9167 - val_iou: 0.8762 - lr: 1.2500e-05
# Epoch 48/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0317 - dice_coef: 0.9683 - precision: 0.9737 - sensitivity: 0.9644 - iou: 0.9392
# Epoch 48: val_loss did not improve from 0.06912
# 1294/1294 [==============================] - 236s 182ms/step - loss: 0.0317 - dice_coef: 0.9683 - precision: 0.9737 - sensitivity: 0.9644 - iou: 0.9392 - val_loss: 0.0697 - val_dice_coef: 0.9303 - val_precision: 0.9510 - val_sensitivity: 0.9174 - val_iou: 0.8754 - lr: 1.2500e-05
# Epoch 49/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0310 - dice_coef: 0.9690 - precision: 0.9742 - sensitivity: 0.9652 - iou: 0.9404
# Epoch 49: val_loss did not improve from 0.06912
# 1294/1294 [==============================] - 236s 183ms/step - loss: 0.0310 - dice_coef: 0.9690 - precision: 0.9742 - sensitivity: 0.9652 - iou: 0.9404 - val_loss: 0.0718 - val_dice_coef: 0.9282 - val_precision: 0.9553 - val_sensitivity: 0.9099 - val_iou: 0.8729 - lr: 1.2500e-05
# Epoch 50/50
# 1294/1294 [==============================] - ETA: 0s - loss: 0.0312 - dice_coef: 0.9688 - precision: 0.9741 - sensitivity: 0.9651 - iou: 0.9402
# Epoch 50: val_loss improved from 0.06912 to 0.06890, saving model to cxr_reg_Unet_extended_superpixel_breast_slic800.best.hdf5
# 1294/1294 [==============================] - 237s 183ms/step - loss: 0.0312 - dice_coef: 0.9688 - precision: 0.9741 - sensitivity: 0.9651 - iou: 0.9402 - val_loss: 0.0689 - val_dice_coef: 0.9311 - val_precision: 0.9543 - val_sensitivity: 0.9155 - val_iou: 0.8767 - lr: 1.2500e-05

# %%
test_images = []
ground_truth_test_images = []

# test_paths = glob.glob("/home/somayeh/PycharmProjects/superpixel_segmentation/archive (3)/data/Lung Segmentation/test_original/*.png")
# test_mask_paths = glob.glob("/home/somayeh/PycharmProjects/superpixel_segmentation/archive (3)/data/Lung Segmentation/test_mask/*.png")
test_paths = glob.glob("/home/somayeh/PycharmProjects/superpixel_segmentation/archive (2)/Dataset_BUSI_with_GT/breast_test/*.png")
test_mask_paths = glob.glob("/home/somayeh/PycharmProjects/superpixel_segmentation/archive (2)/Dataset_BUSI_with_GT/breast_test_mask/*.png")

# %%
# model.load_weights("{}_Unet_extended_superpixel_chest_slic800.best.hdf5".format('cxr_reg'))
model.load_weights("{}_Unet_extended_superpixel_breast_slic800.best.hdf5".format('cxr_reg'))

# %%
dice_scores = []  # List to store the dice coefficients
precision_scores = []
sensitivity_scores = []
iou_scores = []

# %%
for test_path, test_mask_path in zip(test_paths, test_mask_paths):
    # read the image and mask using OpenCV
    test_image = cv2.imread(test_path)
    ground_truth_test_image = cv2.imread(test_mask_path, 0)  # read the mask as grayscale

    # resize the image and mask to the desired dimensions
    test_image = cv2.resize(test_image, (128, 128))
    ground_truth_test_image = cv2.resize(ground_truth_test_image, (128, 128))

# normalize the image and mask to have values between 0 and 1

    test_image = test_image / 255.0
    ground_truth_test_image= ground_truth_test_image / 255.0

    # add the image and mask to the corresponding arrays
    test_images.append(test_image)
    ground_truth_test_images.append(ground_truth_test_image)


#by the end of this line, I have superpixeled images.
# convert the images and masks to numpy arrays
test_images = np.array(test_images)
ground_truth_test_images = np.array(ground_truth_test_images)
print(test_images.shape)
print(ground_truth_test_images.shape)
# add a channel dimension to the masks
# ground_truth_test_images = np.expand_dims(ground_truth_test_images, axis=-1)


# Make predictions
# predicted_masks = model.predict(test_images)
tf.config.run_functions_eagerly(True)
predicted_masks = model.predict(
    test_images,
    batch_size=1,
    verbose=1,
    steps=None,
    callbacks=None
)

predicted_mask_array = np.array(predicted_masks)
print(predicted_mask_array.shape)

# Convert the NumPy array to uint8 format
predicted_mask_array = (predicted_mask_array * 255).astype(np.uint8)
print(predicted_mask_array.shape)

#
dst = np.empty([predicted_mask_array.shape[0],predicted_mask_array.shape[1],predicted_mask_array.shape[2]])
kernel = np.ones((5,5),np.float64)/25
# dst = predicted_mask_array

#
for i in range(predicted_mask_array.shape[0]):

        threshold_value = 1
        _, dst[i] = cv2.threshold(predicted_mask_array[i], threshold_value, 255, cv2.THRESH_BINARY)
        dst[i] = np.array(dst[i])
        dst[i] = tf.convert_to_tensor(dst[i] / 255.0,dtype=predicted_masks.dtype)

print(dst.shape)

## Cast the input tensor to a double tensor
ground_truth_test_images = tf.cast(ground_truth_test_images, dtype=tf.float64)
predicted_masks = tf.cast(dst, dtype=tf.float64)
# predicted_masks = tf.cast(predicted_mask_array, dtype=tf.float64)
# Apply thresholding

dice_scores = []  # List to store the dice coefficients
precision_scores = []
sensitivity_scores = []
iou_scores = []

# Iterate over the images and calculate the dice coefficient
for i in range(len(ground_truth_test_images)):
    y_true = ground_truth_test_images[i]
    y_pred = predicted_masks[i]

    dice = dice_coef(y_true, y_pred)
    dice_scores.append(dice)

# Compute the average dice coefficient
average_dice = np.mean(dice_scores)

for i in range(len(ground_truth_test_images)):
    y_true = ground_truth_test_images[i]
    y_pred = predicted_masks[i]

    precision_value = precision(y_true, y_pred)
    precision_scores.append(precision_value)

# Compute the average dice coefficient
average_precision = np.mean(precision_scores)

for i in range(len(ground_truth_test_images)):
    y_true = ground_truth_test_images[i]
    y_pred = predicted_masks[i]

    sensitivity_value = sensitivity(y_true, y_pred)
    sensitivity_scores.append(sensitivity_value)

# Compute the average dice coefficient
average_sensitivity = np.mean(sensitivity_scores)

for i in range(len(ground_truth_test_images)):
    y_true = ground_truth_test_images[i]
    y_pred = predicted_masks[i]

    iou_value = iou(y_true, y_pred)
    iou_scores.append(iou_value)

# Compute the average dice coefficient
average_iou = np.mean(iou_scores)


print("Dices:", dice_scores)
print("Dice coefficient:", average_dice)
print("Precision:", average_precision)
print("Sensitivity:", average_sensitivity)
print("IoU:", average_iou)

n =35 # number of images to show
for i in range(n):
    fig, ax = plt.subplots(1, 3, figsize=(10, 5))
    ax[0].imshow(test_images[i])
    ax[0].set_title('Original Image')
    ax[1].imshow(ground_truth_test_images[i])
    ax[1].set_title('Original Mask')
    ax[2].imshow(dst[i])
    ax[2].set_title('Predicted Mask')
    plt.show()
# Out:
# (69, 128, 128, 3)
# (69, 128, 128)
# /home/somayeh/PycharmProjects/superpixel_segmentation/venv/lib/python3.8/site-packages/tensorflow/python/data/ops/structured_function.py:256: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 69/69 [==============================] - 3s 32ms/step
# (69, 128, 128, 1)
# (69, 128, 128, 1)
# (69, 128, 128)
# Dices: [<tf.Tensor: shape=(), dtype=float64, numpy=0.6570464457887377>, <tf.Tensor: shape=(), dtype=float64, numpy=0.22199703957834743>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9445649622680428>, <tf.Tensor: shape=(), dtype=float64, numpy=0.334524796018298>, <tf.Tensor: shape=(), dtype=float64, numpy=0.1135433300623355>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9014755610205963>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8835715968524712>, <tf.Tensor: shape=(), dtype=float64, numpy=0.892215351367058>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9323459331425268>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8924111354938568>, <tf.Tensor: shape=(), dtype=float64, numpy=0.913212138822803>, <tf.Tensor: shape=(), dtype=float64, numpy=0.7806688508295242>, <tf.Tensor: shape=(), dtype=float64, numpy=0.7503492681999621>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8240047104822978>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9645803352348612>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8652790539350342>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9608490147564739>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8021467686352263>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9470300979347493>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8578050193435832>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9012366480626028>, <tf.Tensor: shape=(), dtype=float64, numpy=0.783548102996732>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9170370400995566>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8938087837080002>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8292472647534342>, <tf.Tensor: shape=(), dtype=float64, numpy=0.659461369901746>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8852278276826543>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8285403989507444>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8850220846596981>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9571535667415761>, <tf.Tensor: shape=(), dtype=float64, numpy=0.407004304137074>, <tf.Tensor: shape=(), dtype=float64, numpy=0.7349242026988213>, <tf.Tensor: shape=(), dtype=float64, numpy=0.889272900649221>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9163854486552153>, <tf.Tensor: shape=(), dtype=float64, numpy=0.7458349715244089>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8223295207993838>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9116311653287825>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8592618800539803>, <tf.Tensor: shape=(), dtype=float64, numpy=0.5643095975106225>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8134122973427274>, <tf.Tensor: shape=(), dtype=float64, numpy=0.890561446415338>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9598775671738564>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8260514185998584>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9278719717304881>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8970281165103173>, <tf.Tensor: shape=(), dtype=float64, numpy=0.693389785283777>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8844753947978418>, <tf.Tensor: shape=(), dtype=float64, numpy=0.45273868080179336>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8615745398011575>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9020344340200105>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8189304450136468>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9161095615632489>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9091999247578142>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8428136297045773>, <tf.Tensor: shape=(), dtype=float64, numpy=0.9392662892662893>, <tf.Tensor: shape=(), dtype=float64, numpy=0.4494768076398363>, <tf.Tensor: shape=(), dtype=float64, numpy=0.8614980414636477>, <tf.Tensor: shape=(), dtype=float64, numpy=0.46698616775343116>, <tf.Tensor: shape=(), dtype=float64, numpy=0.7656102667369868>, <tf.Tensor: shape=(), dtype=float64, numpy=0.7752935143804168>, <tf.Tensor: shape=(), dtype=float64, numpy=0.955472710834411>, <tf.Tensor: shape=(), dtype=float64, numpy=0.08760774040899104>, <tf.Tensor: shape=(), dtype=fl ...
# Dice coefficient: 0.7859737882424975
# Precision: 0.790627570908115
# Sensitivity: 0.8364987679534343
# IoU: 0.6879656567989861
